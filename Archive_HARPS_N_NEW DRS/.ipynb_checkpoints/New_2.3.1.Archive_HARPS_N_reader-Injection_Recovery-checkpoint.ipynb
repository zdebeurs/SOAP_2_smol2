# %%
import numpy as np
#import tensorflow as tf
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.io.fits import getheader
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
import mpyfit
from astropy.io import fits
from scipy.signal import argrelextrema
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
import csv
import pickle
import math as m
import os
import pandas as pd
import mpyfit
import datetime
from astropy.time import Time

from tqdm import tqdm
# check headers

#globally change font size for plots
plt.rcParams['font.size'] =17
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
# define function that converts bjd dates to UTC times
def time_bjd_isot(time_array):
    tm = Time(time_array-2400000, format='mjd')
    return tm.isot

# %%
outfile = 'NEW_DRS2_3_1_10s_all_index_header_rvaxis.npz'#'NEW_DRS2_3_1_10s_norm.npz'

npzfile = np.load(outfile)

for i in npzfile['all_ccfs_list'][0:10]:
    plt.plot(i)#-0.5)/0.5)

npzfile.files
# Out:
# ['d_normalized_ccf_list',
#  'd_bjd_list',
#  'd_rvh_list',
#  'd_vrad_raw_list',
#  'd_berv_list',
#  'd_rvext_list',
#  'd_fwhm_list',
#  'd_cont_list',
#  'd_bis_list',
#  'd_qflag_list',
#  'd_sig_vrad_list',
#  'd_sig_fwhm_list',
#  'd_sig_contrast_list',
#  'd_sig_bis_span_list',
#  'all_ccfs_list',
#  'all_bjds_list',
#  'i_list',
#  'DRS_header_rv_list']

# %%
np.where(np.abs(npzfile["d_bjd_list"]-2458206.5)<1)

npzfile["d_bjd_list"][484]
# Out:
# 2458206.9886805983

# %%
fig, ax = plt.subplots(2,1, figsize=(10, 5))
ax[0].plot(npzfile["d_bjd_list"],(npzfile['d_rvh_list']-np.mean(npzfile['d_rvh_list']))*1000, ".")
ax[0].set_ylabel("RV (m/s)")

ax[1].plot(npzfile["d_bjd_list"],(npzfile['d_berv_list']-np.mean(npzfile['d_berv_list']))*1000, ".")
ax[1].set_ylabel("RV (m/s)")

print(time_bjd_isot(np.min(npzfile['d_bjd_list'])))
print(time_bjd_isot(np.max(npzfile['d_bjd_list'])))
np.max(npzfile['d_bjd_list'])
# Out:
# 2015-07-19T23:54:03.645
# 2018-07-15T23:41:29.850
# 2458314.987151045

# %%
bjd = npzfile['d_bjd_list']
ccfBary =  npzfile['d_normalized_ccf_list']
rvh = npzfile['d_rvh_list']
a_vrad_raw_list = npzfile['d_vrad_raw_list']
bsrv = npzfile['d_berv_list']
fwhm = npzfile['d_fwhm_list']
cont = npzfile['d_fwhm_list']
bis = npzfile['d_bis_list']
ext = npzfile['d_rvext_list']
ccfall = npzfile['all_ccfs_list']
bjdall = npzfile['all_bjds_list']
indexes = npzfile["i_list"]
DRS_rvh = npzfile["DRS_header_rv_list"]

# %%
a_vrad_raw_list
# Out:
# array([0.09601729, 0.09405144, 0.09129902, 0.0953359 , 0.10198516,
#        0.10301195, 0.09496629, 0.10324829, 0.0931954 , 0.09368811,
#        0.1023781 , 0.09476435, 0.11221902, 0.11333017, 0.11090057,
#        0.09887773, 0.112192  , 0.09632388, 0.11125867, 0.09301499,
#        0.11300108, 0.09528286, 0.10552191, 0.09583221, 0.10587743,
#        0.10686596, 0.10476883, 0.1066481 , 0.10448233, 0.10442326,
#        0.10244086, 0.1031623 , 0.10177152, 0.0934587 , 0.101379  ,
#        0.10436429, 0.088738  , 0.10680607, 0.10654526, 0.0862071 ,
#        0.10826777, 0.10758814, 0.09973033, 0.09951131, 0.10445649,
#        0.08763744, 0.10335726, 0.08857135, 0.09853843, 0.08644993,
#        0.10473873, 0.09884353, 0.08800679, 0.10824503, 0.10000047,
#        0.08622565, 0.10363332, 0.10313129, 0.09988991, 0.10328343,
#        0.10920422, 0.09160699, 0.09507797, 0.10915801, 0.09082831,
#        0.09591453, 0.10794572, 0.08782889, 0.11098778, 0.09605876,
#        0.09328385, 0.09028497, 0.08744735, 0.08772852, 0.09119467,
#        0.09521698, 0.08786322, 0.09068057, 0.0882996 , 0.08921201,
#        0.08654624, 0.0912006 , 0.08836839, 0.11024322, 0.08878045,
#        0.10763498, 0.10514638, 0.09562874, 0.10678923, 0.10274725,
#        0.08993369, 0.10434902, 0.08665586, 0.09812961, 0.10479982,
#        0.09817839, 0.10735832, 0.10826419, 0.10765883, 0.09729232,
#        0.08683842, 0.10909619, 0.10535216, 0.10273846, 0.08739042,
#        0.10155315, 0.08710707, 0.09907196, 0.08554681, 0.09818907,
#        0.1014447 , 0.10279193, 0.10282689, 0.08685791, 0.09280417,
#        0.09081718, 0.09528068, 0.10720655, 0.10699405, 0.10718788,
#        0.09463654, 0.09073404, 0.09188   ])

# %% [markdown]
# ## Testing shifting (including injection) at each step (Feb 27, 2022)

# %%
# Define gaussian function
def gauss(x, p):
    return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

# A simple minimization function:
def least(p, args):
    x, y = args
    return gauss(x, p) - y

def planet(K, p, bjd): #K is in km/s
    return K*np.sin(2*np.pi/p*bjd)

# %%
removed_planet_rvs = -bsrv
injected_planet_rvs = planet(5/1000, 30, bjd)

perfectly_sampled_bjds = np.arange(np.min(bjd), np.max(bjd), 1)
#injected_planet_rvs_sampled = planet(3/1000, 30, perfectly_sampled_bjds)

given_rvs = removed_planet_rvs + injected_planet_rvs

fig, axes = plt.subplots(1,1, figsize=(10, 6))
plt.plot(bjd, removed_planet_rvs*1000, ".",label="removed SS planets RVs")
plt.plot(bjd, injected_planet_rvs*1000, ".",label="Injected planet RVs")
#plt.plot(perfectly_sampled_bjds, injected_planet_rvs_sampled, ".", label="Injected planet RVs, sampled")
plt.plot(bjd, given_rvs*1000, ".",label="sum")
plt.legend()

# %%
# DON'T RUN THIS CELL
# Shift CCFs by injected planet signal

removed_planet_rvs = injected_planet_rvs#-bsrv
number_of_ccfs = len(ccfBary)

# HARPS direct data lists
BJD_list = []
og_ccf_list = []
rv_from_HARPS_list = []
v_rad_raw_list = []

# mpyfit lists
#mu_og_list = []
mu_jup_list = []
mu_planet_list = []
mu_zero_list = []
CCF_normalized_list = []

# CCF lists
compiled_ccf_list = []
jup_shifted_CCF_data_list = []
shifted_CCF_list = []
final_ccf_list = []

spline_method = 'quadratic'
for i in range(0, number_of_ccfs):
    day_of_observation = bjd[i]
    BJD_list.append(day_of_observation)

    # extracts the CCF data and rv from fits
    CCF_data = ccfBary[i]
    og_ccf_list.append(CCF_data)
    rv_from_HARPS = rvh[i]  # - bsrv[i]
    rv_from_HARPS_list.append(rv_from_HARPS)

    rv_range = np.std(a_vrad_raw_list-bsrv)

    parinfo = [{'fixed': False, 'step': 1e-3},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-3}]

    jupiter_shift = removed_planet_rvs[i]
    v_rad_raw = rvh[i] + removed_planet_rvs[i]
    v_rad_raw_list.append(v_rad_raw)

    # planet removal shift
    rv_data = np.linspace(-19.58, 19.78, 49)
    rv_data_jupiter_shift = rv_data + jupiter_shift  # minus sign
    f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind=spline_method, fill_value='extrapolate')
    jupiter_shifted_CCF_data = f_jup(rv_data)
    jup_shifted_CCF_data_list.append(jupiter_shifted_CCF_data.tolist())
    compiled_ccf_list.append(jupiter_shifted_CCF_data.tolist())

    # fits the shifted by planets removed data
    p_shifted_jup = [.6, 0.091 + jupiter_shift, 3., 1.0]  #0.6, 0.091, 3, 1.0]
    pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)
    mu_og = pfit_jup[1]
    mu_jup_list.append(mu_og)


injected_ccfs = compiled_ccf_list

# %%
fig, axes = plt.subplots(2,1, figsize=(10, 12))

ax = axes[0]
#ax.plot(daily_average_df["bjds"],daily_average_df["rvraws"]-daily_average_df["rvSSs"], ".", label="Annelies rvext RVs, Daily")
ax.plot(BJD_list, a_vrad_raw_list, ".", label="Annelies SS shifted RVs, Daily")
ax.plot(BJD_list, mu_jup_list, ".", label="mpyfit injected planet shifted RVs, Daily")
ax.legend()


ax = axes[1]
ax.plot(BJD_list, mu_jup_list-(a_vrad_raw_list-injected_planet_rvs), ".", label="Difference between mpyfit and (rvraw-rvSS)")
#ax.plot(BJD_list, np.array(mu_og_list)*5e-3-5.2e-4, ".", label="Jupiter x 1e-5")

#ax.set_title("offset of 0.1 km/s subtracted")
ax.legend()

# %%
 # Raw RV mpyfit from CCFs (not binned)
    
number_of_ccfs = len(ccfall)
p_no = [0.6, 0.091, 3, 1.0]

# HARPS direct data lists
BJD_list = []
og_ccf_list = []
rv_from_HARPS_list = []
v_rad_raw_list = []

# mpyfit lists
mu_og_list = []
mu_jup_list = []
mu_planet_list = []
mu_zero_list = []
CCF_normalized_list = []

# CCF lists
compiled_ccf_list = []
jup_shifted_CCF_data_list = []
shifted_CCF_list = []
final_ccf_list = []

spline_method = 'quadratic'
for i in range(0, number_of_ccfs):
    day_of_observation = bjdall[i]
    BJD_list.append(day_of_observation)

    # extracts the CCF data and rv from fits
    CCF_data = ccfall[i]
    og_ccf_list.append(CCF_data)
    #rv_from_HARPS = rvh[i]  # - bsrv[i]
    #rv_from_HARPS_list.append(rv_from_HARPS)
    
    rv_range = np.max(a_vrad_raw_list)-np.min(a_vrad_raw_list)

    parinfo = [{'fixed': False, 'step': 1e-7},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-9}]

    # no_shift fit
    rv_data = rv_axis = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, len(ccfBary[0]))
    p_no_shifted = p_no
    pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
    mu_og = pfit_no_shift[1]
    mu_og_list.append(mu_og)
    compiled_ccf_list.append(CCF_data)

# %%
rv_range
# Out:
# 0.0326984760623997

# %%
np.max(a_vrad_raw_list)-np.min(a_vrad_raw_list)
# Out:
# 0.0326984760623997

# %%
fig, axes = plt.subplots(2,1, figsize=(10, 10))

ax = axes[0]
ax.plot(BJD_list,DRS_rvh, ".", label="DRS Raw RVs")
ax.plot(BJD_list, mu_og_list, ".", label="mpyfit raw RVs")
ax.set_ylabel("RV (km/s)")
ax.set_title("Raw - out of CCFs, DRS")
ax.legend()



ax = axes[1]
ax.plot(BJD_list,DRS_rvh-mu_og_list, ".", label="Difference between mpyfit and rvraw")
#ax.plot(BJD_list, mu_og_list, ".", label="mpyfit raw RVs")
ax.set_ylabel("RV (km/s)")
#ax.set_title("offset of 0.1 km/s subtracted")
ax.legend()

#len(BJD_list)-len(daily_average_df["bjds"])

# %%
# Raw RV mpyfit daily averages

p_no = [0.6, 0.091, 3, 1.0]
number_of_ccfs = len(ccfBary)

# HARPS direct data lists
BJD_list = []
og_ccf_list = []
rv_from_HARPS_list = []
v_rad_raw_list = []

# mpyfit lists
mu_og_list = []
mu_jup_list = []
mu_planet_list = []
mu_zero_list = []
CCF_normalized_list = []

# CCF lists
compiled_ccf_list = []
jup_shifted_CCF_data_list = []
shifted_CCF_list = []
final_ccf_list = []

spline_method = 'quadratic'
for i in range(0, number_of_ccfs):
    day_of_observation = bjd[i]
    BJD_list.append(day_of_observation)

    # extracts the CCF data and rv from fits
    CCF_data = ccfBary[i]
    og_ccf_list.append(CCF_data)
    rv_from_HARPS = rvh[i]  # - bsrv[i]
    rv_from_HARPS_list.append(rv_from_HARPS)
    
    rv_range = np.max(a_vrad_raw_list)-np.min(a_vrad_raw_list)

    parinfo = [{'fixed': False, 'step': 1e-7},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-6}]

    # no_shift fit
    rv_data = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, len(ccfBary[0]))
    p_no_shifted = p_no
    pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
    mu_og = pfit_no_shift[1]
    mu_og_list.append(mu_og)
    compiled_ccf_list.append(CCF_data)

# %%
rv_data
# Out:
# array([-19.58, -18.76, -17.94, -17.12, -16.3 , -15.48, -14.66, -13.84,
#        -13.02, -12.2 , -11.38, -10.56,  -9.74,  -8.92,  -8.1 ,  -7.28,
#         -6.46,  -5.64,  -4.82,  -4.  ,  -3.18,  -2.36,  -1.54,  -0.72,
#          0.1 ,   0.92,   1.74,   2.56,   3.38,   4.2 ,   5.02,   5.84,
#          6.66,   7.48,   8.3 ,   9.12,   9.94,  10.76,  11.58,  12.4 ,
#         13.22,  14.04,  14.86,  15.68,  16.5 ,  17.32,  18.14,  18.96,
#         19.78])

# %%
fig, axes = plt.subplots(2,1, figsize=(10, 12))

ax = axes[0]
#ax.plot(daily_average_df["bjds"],daily_average_df["rvraws"], ".", label="Annelies Raw RVs, Daily")
ax.plot(BJD_list,a_vrad_raw_list, ".", label="Annelies Raw RVs, Daily")
ax.plot(BJD_list, mu_og_list, ".", label="mpyfit raw RVs, Daily")
ax.legend()


ax = axes[1]
#ax.plot(daily_average_df["bjds"],daily_average_df["rvraws"], ".", label="Annelies Raw RVs,, Daily")
#ax.plot(bjd, a_vrad_raw_list, ".", label="Annelies Raw RVs,, Daily")
ax.plot(BJD_list, mu_og_list-a_vrad_raw_list, ".", label="Difference between mpyfit and rvraw")
#ax.set_title("offset of 0.1 km/s subtracted")
ax.legend()

# %%
removed_planet_rvs = -bsrv
injected_planet_rvs = planet(5/1000, 30, bjd)

given_rvs = removed_planet_rvs + injected_planet_rvs

# %%
# Shift by SS and injected planet

removed_planet_rvs = given_rvs#-bsrv
number_of_ccfs = len(ccfBary)

# HARPS direct data lists
BJD_list = []
og_ccf_list = []
rv_from_HARPS_list = []
v_rad_raw_list = []

# mpyfit lists
#mu_og_list = []
mu_jup_list = []
mu_planet_list = []
mu_zero_list = []
CCF_normalized_list = []

# CCF lists
compiled_ccf_list = []
jup_shifted_CCF_data_list = []
shifted_CCF_list = []
final_ccf_list = []

spline_method = 'quadratic'
for i in range(0, number_of_ccfs):
    day_of_observation = bjd[i]
    BJD_list.append(day_of_observation)

    # extracts the CCF data and rv from fits
    CCF_data = ccfBary[i]
    og_ccf_list.append(CCF_data)
    rv_from_HARPS = rvh[i]  # - bsrv[i]
    rv_from_HARPS_list.append(rv_from_HARPS)

    rv_range = np.std(a_vrad_raw_list-bsrv)

    parinfo = [{'fixed': False, 'step': 1e-3},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-3}]

    jupiter_shift = removed_planet_rvs[i]
    v_rad_raw = rvh[i] + removed_planet_rvs[i]
    v_rad_raw_list.append(v_rad_raw)

    # planet removal shift
    rv_data = np.linspace(-19.58, 19.78, 49)
    rv_data_jupiter_shift = rv_data + jupiter_shift  # minus sign
    f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind=spline_method, fill_value='extrapolate')
    jupiter_shifted_CCF_data = f_jup(rv_data)
    jup_shifted_CCF_data_list.append(jupiter_shifted_CCF_data.tolist())
    compiled_ccf_list.append(jupiter_shifted_CCF_data.tolist())

    # fits the shifted by planets removed data
    p_shifted_jup = [.6, 0.091 + jupiter_shift, 3., 1.0]  #0.6, 0.091, 3, 1.0]
    pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)
    mu_og = pfit_jup[1]
    mu_jup_list.append(mu_og)

#   0.9950438319850508,
#   0.9951269413284424,
#   0.9953464343327865,
#   0.9957642567100915,
#   0.9959907316398446,
#   0.9956753642288251,
#   0.9942319448226097,
#   0.9904616320377995,
#   0.9825215937204188,
#   0.9677835293223583,
#   0.9430276274368803,
#   0.9043238106534349,
#   0.8487513903853156,
#   0.7753698916922557,
#   0.6882555834829843,
#   0.5964104088082012,
#   0.5133103689308225,
#   0.45362329211680436,
#   0.4297562941197123,
#   0.448223717765725,
#   0.5062902144413418,
#   0.5923677822599906,
#   0.6891163288664102,
#   0.7802738081803924,
#   0.8554595573368986,
#   0.911465379887973,
#   0.9498688184623975,
#   0.9744353090021468,
#   0.9888976510327196,
#   0.9967753738349182,
#   1.0003681412231513,
#   1.001549196071204,
#   1.0014461771765668,
#   1.0008877843086978,
#   1.0004170587569974,
#   1.000095488696107,
#   0.9999103089406798,
#   1.0000888104672854,
#   1.0004180445691464,
#   1.0008937142061314,
#   1.0013401650328944,
#   1.0017447209322854,
#   1.001934769095339],
#  [1.0010429346146332,
#   0.9994998809517465,
#   0.9980743618953116,
#   0.9967371208095617,
#   0.9956862872838808,
#   0.9950916197825418,
#   0.9948769712967451,
#   0.9949842977230616,
#   0.9952494646119139,
#   0.9956388881894985,
#   0.9958629173819213,
#   0.995669785593414,
#   0.994251677977715,
#   0.9904656475636339,
#   0.9825207823234705,
#   0.967802982692028,
#   0.9429966652587096,
#   0.9043348257693563,
#   0.8486962816865249,
#   0.7753666134808535,
#   0.6882027510078051,
#   0.5963126360725403,
#   0.513228242899622,
#   0.45365691778430584,
#   0.4298700373641245,
#   0.4482592956731359,
#   0.5062819448243884,
#   0.592236319410558,
#   0.6889580383246989,
#   0.7800231148113553,
#   0.8552307803792932,
#   0.9112423752812774,
#   0.9497038696822859,
#   0.9742558808781987,
#   0.9887970811770123,
#   0.9966142010925729,
#   1.000189568796227,
#   1.0014493826539541,
#   1.001464515954214,
#   1.0009887021414958,
#   1.0004082590675647,
#   1.0000574208143287,
#   0.9999430792275111,
#   1.0001230061213175,
#   1.0004251357506055,
#   1.000842557330163,
#   1.001318827472143,
#   1.001710839258296,
#   1.0019234646582758]]

# %%
print(jupiter_shift)
plt.plot(rv_data[10:38], gauss(rv_data[10:38], p_shifted_jup), label="model")
plt.plot(rv_data, jupiter_shifted_CCF_data)
plt.xlabel("km/s")
plt.legend()
# Out:
# 0.0023590021874920182

# %%
rv_data[10]-rv_data[0]
# Out:
# 8.2

# %%
rv_data[48]-rv_data[45]
# Out:
# 2.460000000000001

# %%
rv_data[1]-rv_data[0]
# Out:
# 0.8200000000000003

# %%
fig, axes = plt.subplots(2,1, figsize=(10, 12))

ax = axes[0]
#ax.plot(daily_average_df["bjds"],daily_average_df["rvraws"]-daily_average_df["rvSSs"], ".", label="Annelies rvext RVs, Daily")
ax.plot(BJD_list, a_vrad_raw_list-bsrv, ".", label="Annelies SS shifted RVs, Daily")
ax.plot(BJD_list, mu_jup_list, ".", label="mpyfit SS shifted RVs, Daily")
ax.legend()


ax = axes[1]
ax.plot(BJD_list, mu_jup_list-(a_vrad_raw_list-bsrv), ".", label="Difference between mpyfit and (rvraw-rvSS)")
#ax.plot(BJD_list, np.array(mu_og_list)*5e-3-5.2e-4, ".", label="Jupiter x 1e-5")

#ax.set_title("offset of 0.1 km/s subtracted")
ax.legend()

# %%
6e-5*1e5
# Out:
# 6.0

# %%
# Shift by ext

removed_planet_rvs = ext
number_of_ccfs = len(ccfBary)

# HARPS direct data lists
BJD_list = []
og_ccf_list = []
rv_from_HARPS_list = []
v_rad_raw_list = []

# mpyfit lists
mu_og_list = []
mu_ext_list = []
mu_planet_list = []
mu_zero_list = []
CCF_normalized_list = []

# CCF lists
#compiled_ccf_list = []
ext_shifted_CCF_data_list = []
shifted_CCF_list = []
final_ccf_list = []

#ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

spline_method = 'quadratic'
for i in range(0, number_of_ccfs):
    day_of_observation = bjd[i]
    BJD_list.append(day_of_observation)

    # extracts the CCF data and rv from fits
    CCF_data = compiled_ccf_list[i]#ccfBary[i]
    og_ccf_list.append(CCF_data)
    rv_from_HARPS = rvh[i]  # - bsrv[i]
    rv_from_HARPS_list.append(rv_from_HARPS)

    rv_range = np.std(a_vrad_raw_list-bsrv)

    parinfo = [{'fixed': False, 'step': 1e-3},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-5*rv_range},
               {'fixed': False, 'step': 1e-3}]

    ext_shift = ext[i]
    #v_rad_raw = rvh[i] + removed_planet_rvs[i]
    #v_rad_raw_list.append(v_rad_raw)
    
    ccf_to_use = compiled_ccf_list[i]

    # ext removal shift
    rv_data = np.linspace(-19.58, 19.78, 49)
    rv_data_ext_shift = rv_data - ext_shift  # minus sign
    f_ext = interp1d(rv_data_ext_shift, ccf_to_use, kind=spline_method, fill_value='extrapolate')
    ext_shifted_CCF_data = f_ext(rv_data)
    ext_shifted_CCF_data_list.append(ext_shifted_CCF_data)
    compiled_ccf_list.append(ext_shifted_CCF_data_list)

    # fits the shifted by planets removed data
    p_shifted_ext = [.6, 0.091 + ext_shift, 3., 1.0]
    pfit_jup, results_jup = mpyfit.fit(least, p_shifted_ext, (rv_data, ext_shifted_CCF_data), parinfo)
    mu_og = pfit_jup[1]
    mu_ext_list.append(mu_og)

# %%
fig, axes = plt.subplots(2,1, figsize=(10, 12))

ax = axes[0]
#ax.plot(daily_average_df["bjds"],daily_average_df["rvraws"]-daily_average_df["rvSSs"]-daily_average_df["rvexts"], ".", label="Annelies shifted by ext RVs")
ax.plot(BJD_list, mu_ext_list, ".", label="mpyfit ext RVs")
ax.legend()


ax = axes[1]
#ax.plot(daily_average_df["bjds"],daily_average_df["rvraws"]-daily_average_df["rvSSs"]-daily_average_df["rvexts"]-0.1, ".", label="Annelies shifted by ext RVs")
ax.plot(BJD_list, mu_ext_list-(a_vrad_raw_list-bsrv-ext), ".", label="Difference between mpyfit and (rvraw-rvSS-ext)")
#ax.plot(BJD_list, mu_ext_list, ".", label="mpyfit ext RVs")
#ax.set_title("offset of 0.1 km/s subtracted")
ax.legend()

# %%
ext_shifted_CCF_data
# Out:
# array([1.0010522 , 0.99950841, 0.99808239, 0.99674417, 0.99569107,
#        0.9950939 , 0.9948772 , 0.99498316, 0.99524747, 0.99563693,
#        0.99586246, 0.9956737 , 0.99426562, 0.99049781, 0.98258386,
#        0.96791415, 0.94317679, 0.90460481, 0.84906875, 0.77583371,
#        0.68872718, 0.5968277 , 0.51364994, 0.45390488, 0.4298879 ,
#        0.44803442, 0.5058565 , 0.59169719, 0.68840668, 0.77953869,
#        0.85485179, 0.91097186, 0.94952481, 0.97414566, 0.98873459,
#        0.99658289, 1.00017667, 1.00144632, 1.00146624, 1.000992  ,
#        1.00041107, 1.00005878, 0.99994285, 1.00012154, 1.00042306,
#        1.0008399 , 1.00131623, 1.00170906, 1.00192279])

# %%
    # run shifted CCFs through pipeline and rvs with injected planet through the pipeline
    
    bjd = bjd
    ccfBary =  injected_ccfs #ccfBary
    rvh = rvh #- injected_planet_rvs
    ref_frame_shift="off" #"off" or a specific value in km/s
    removed_planet_rvs= given_rvs#-bsrv #array of rv values for planet signal in km/s
    zero_or_median = "median"
    p_no = [0.6, 0.0, 3, 1.0] #[0.6, 0.0, 2.7, 1.0],
    shift_by_rv = "prov_rvs"
    fwhm = fwhm
    cont = cont 
    bis = bis
    index_cut_num = 18.76
    
    number_of_ccfs = len(ccfBary)

    # HARPS direct data lists
    BJD_list = []
    og_ccf_list = []
    rv_from_HARPS_list = []
    v_rad_raw_list = []

    # mpyfit lists
    mu_og_list = []
    mu_ext_list = []
    mu_jup_list = []
    mu_planet_list = []
    mu_zero_list = []
    CCF_normalized_list = []

    # CCF lists
    compiled_ccf_list = []
    jup_shifted_CCF_data_list = []
    ext_shifted_CCF_data_list = []
    shifted_CCF_list = []
    final_ccf_list = []

    spline_method = 'quadratic'
    for i in range(0, number_of_ccfs):
        day_of_observation = bjd[i]
        BJD_list.append(day_of_observation)

        # extracts the CCF data and rv from fits
        CCF_data = ccfBary[i]
        og_ccf_list.append(CCF_data)
        rv_from_HARPS = rvh[i]  # - bsrv[i]
        rv_from_HARPS_list.append(rv_from_HARPS)

        # Finds the local minima using a Gaussian fit
        # Define the actual function where     A = p[0], mu = p[1], sigma = p[2], c = p[3]
        def gauss(x, p):
            return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

        # A simple minimization function:
        def least(p, args):
            x, y = args
            return gauss(x, p) - y

        rv_range = np.max(a_vrad_raw_list)-np.min(a_vrad_raw_list)#np.max(final_df["rvraw"])-np.min(final_df["rvraw"])

        parinfo = [{'fixed': False, 'step': 1e-7},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-9}]

        # no_shift fit
        rv_data = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, len(ccfBary[0]))
        p_no_shifted = p_no
        pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
        mu_og = pfit_no_shift[1]
        mu_og_list.append(mu_og)
        compiled_ccf_list.append(CCF_data)

        # Add in reference frame shift

        if removed_planet_rvs[0] != "NULL":  # Remove known planet signals *a priori*
            jupiter_shift = removed_planet_rvs[i]
            v_rad_raw = rvh[i] + removed_planet_rvs[i]
            v_rad_raw_list.append(v_rad_raw)

            # planet removal shift
            rv_data_jupiter_shift = rv_data + jupiter_shift  # minus sign
            f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind=spline_method, fill_value='extrapolate')
            jupiter_shifted_CCF_data = f_jup(rv_data)
            jup_shifted_CCF_data_list.append(jupiter_shifted_CCF_data)
            compiled_ccf_list.append(jupiter_shifted_CCF_data)

            # fits the shifted by planets removed data
            p_shifted_jup = [.6, 0.091 + jupiter_shift, 3., 1.0] 
            pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)
            mu_og = pfit_jup[1]
            mu_jup_list.append(mu_og)
            
            # ext removal shift
            ext_shift = ext[i]
            rv_data_ext_shift = rv_data - ext_shift  # minus sign
            f_ext = interp1d(rv_data_ext_shift, jupiter_shifted_CCF_data, kind=spline_method, fill_value='extrapolate')
            ext_shifted_CCF_data = f_ext(rv_data)
            ext_shifted_CCF_data_list.append(ext_shifted_CCF_data)
            compiled_ccf_list.append(ext_shifted_CCF_data)

            # fits the shifted by ext removed data
            p_shifted_ext = [.6, 0.091 + ext_shift, 3., 1.0]
            pfit_ext, results_ext = mpyfit.fit(least, p_shifted_ext, (rv_data, ext_shifted_CCF_data), parinfo)
            mu_ext = pfit_ext[1]
            mu_ext_list.append(mu_ext)

            if zero_or_median == "zero":
                if shift_by_rv =="prov_rvs":
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [.6, 0.091 - shift_to_zero, 3., 1.0]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else: #shift by mpyfit rvs instead
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [.6, 0.091 - shift_to_zero, 3., 1.0]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [.6, 0.091 - shift_to_median, 3., 1.0]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    #print(m_zero)
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [.6, 0.091 - shift_to_median, 3., 1.0]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        else:  # Do not remove any planet signals *a priori*
            if zero_or_median == "zero":
                if shift_by_rv == "prov_rvs":
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
        final_ccf_list.append(ccf_to_use)

        # normalize the CCFs
        one_fifth = int(0.2*len(ccfBary[0]))
        x_left = ccf_to_use[0:one_fifth]
        x_right = ccf_to_use[len(ccfBary[0])-one_fifth:len(ccfBary[0])]
        x_norm_range = list(x_left) + list(x_right)
        max_norm_range = np.max(x_norm_range)
        min_pt_ccf = np.min(ccf_to_use)
        CCF_normalized = ccf_to_use* (1 / np.mean(x_norm_range)) #-min_pt_ccf)/(max_norm_range-min_pt_ccf) #
        CCF_normalized_list.append(CCF_normalized)

        # clip off 1km/s on each side
        # find indexes of where to cutoff
        index_cutoff = np.where(abs(abs(rv_data)-index_cut_num) < 0.2)
        ccf_norm_np = np.array(list(CCF_normalized_list))
        ccf_norm_transpose_np = ccf_norm_np.transpose()
        # clip edges and take the transpose again
        ccf_norm_cutoff_np = ccf_norm_transpose_np[index_cutoff[0][0]:index_cutoff[0][1], ].transpose()
        
    cff_residual_list= CCF_normalized_list-CCF_normalized_list[484]
    cff_residual_list_cutoff = ccf_norm_cutoff_np-ccf_norm_cutoff_np[484]
    
    # compute medians and stds
    median_rv = np.mean(rvh)
    median_residual = np.median(cff_residual_list, axis=0)
    std_residual = np.std(cff_residual_list, axis=0)
    
    median_cutoff_residual = np.median(cff_residual_list_cutoff, axis=0)
    std_cutoff_residual = np.std(cff_residual_list_cutoff, axis=0)
    
    # Create a dataframe
    d = {'BJD': BJD_list,
         'vrad_star': rvh-injected_planet_rvs,
         'og_ccf_list': og_ccf_list,
         'jup_shifted_CCF_data_list': jup_shifted_CCF_data_list,
         'zero_shifted_CCF_list': shifted_CCF_list,
         'CCF_normalized_list': CCF_normalized_list,
         'cff_residual_list': cff_residual_list.tolist(),
         'ccf_residual_rescaled': ((cff_residual_list-median_residual)/std_residual).tolist(),
         'CCF_normalized_list_cutoff': ccf_norm_cutoff_np.tolist(),
         'CCF_residual_list_cutoff': cff_residual_list_cutoff.tolist(),
         'ccf_residual_rescaled_cutoff': ((cff_residual_list_cutoff-median_cutoff_residual)/std_cutoff_residual).tolist(),
         'mu_og_list': mu_og_list,
         'mu_jup_list': mu_jup_list,
         'mu_zero_list': mu_zero_list,
         'fwhm': fwhm,
         'cont': cont,
         'bis': bis,
         'shift_by_rv': shift_by_rv}
    df = pd.DataFrame(data=d)

# %%
plt.plot(bjd, rvh, ".")
plt.plot(bjd, injected_planet_rvs+0.1, ".")

# %%
df
# Out:
#               BJD  vrad_star  \
# 0    2.457328e+06   0.107084
# 1    2.457333e+06   0.100751
# 2    2.457378e+06   0.106107
# 3    2.457385e+06   0.111252
# 4    2.457270e+06   0.101495
# ..            ...        ...
# 523  2.458304e+06   0.097120
# 524  2.458303e+06   0.096482
# 525  2.458233e+06   0.097091
# 526  2.458221e+06   0.103147
# 527  2.458224e+06   0.103725
#
#                                            og_ccf_list  \
# 0    [1.0015224031138537, 1.000039686979028, 0.9985...
# 1    [1.0014282107359722, 0.9999334168522531, 0.998...
# 2    [1.0013784438238018, 0.9999425387997717, 0.998...
# 3    [1.001415265378614, 0.9999673041866095, 0.9984...
# 4    [1.0014295627421244, 0.999913634649706, 0.9983...
# ..                                                 ...
# 523  [1.0012487020539702, 0.9997446848837195, 0.998...
# 524  [1.0012482254730197, 0.9997770157434326, 0.998...
# 525  [1.0010976504936324, 0.9996672979782181, 0.998...
# 526  [1.001147846587928, 0.9996498402234817, 0.9982...
# 527  [1.0010429346146332, 0.9994998809517465, 0.998...
#
#                              jup_shifted_CCF_data_list  \
# 0    [1.0015351313982053, 1.0000529093059374, 0.998...
# 1    [1.001450786811234, 0.9999571955709488, 0.9984...
# 2    [1.0013935991892697, 0.9999586788957249, 0.998...
# 3    [1.0014276572754934, 0.9999809179282284, 0.998...
# 4    [1.0014288523730248, 0.9999128615631061, 0.998...
# ..                                                 ...
# 523  [1.0012348452447213, 0.9997301125617746, 0.998...
# 3    [1.000966757404017, 0.9994300285057547, 0.9980...
# 4    [1.0009566448684049, 0.9993650941183752, 0.998...
# ..                                                 ...
# 523  [1.0008758878625343, 0.9993332894526227, 0.998...
# 524  [1.0009275185519235, 0.9993646449993394, 0.997...
# 525  [1.0008482740767106, 0.9993621056906032, 0.998...
# 526  [1.000800032953972, 0.9993518816729837, 0.9980...
# 527  [1.0007311986226584, 0.9993034013318067, 0.997...
#
#                               CCF_residual_list_cutoff  \
# 0    [0.0002000888482318608, 0.00021774864498858015...
# 1    [6.675682158552299e-05, 6.318595725418596e-05,...
# 2    [0.0001384152313392839, 0.00015384116277072923...
# 3    [0.0001139053117285016, 0.0001052685353915006,...
# 4    [0.0001037927761162738, 4.0334148011966775e-05...
# ..                                                 ...
# 523  [2.3035770245760645e-05, 8.529482259489463e-06...
# 524  [7.466645963494223e-05, 3.988502897622759e-05,...
# 525  [-4.57801557796067e-06, 3.7345720240056224e-05...
# 526  [-5.2819138316673175e-05, 2.7121702620536148e-...
# 527  [-0.00012165346963022294, -2.135863855645681e-...
#
#                           ccf_residual_rescaled_cutoff  mu_og_list  \
# 0    [2.3655838699246847, 2.633338499835127, 2.3812...    0.103159
# 1    [0.3566229058613112, 0.07734119064495562, 0.57...    0.106709
# 2    [1.436325596678528, 1.576502888470453, 0.02347...    0.100194
# 3    [1.0670259395076345, 0.7732591903862723, 0.790...    0.102667
# 4    [0.9146567765716087, -0.30055831271779415, -0....    0.101586
# ..                                                 ...         ...
# 523  [-0.3021376909634256, -0.8265108648804537, -0....    0.099284
# 524  [0.47580022942590483, -0.3079853771903538, -0....    0.100668
# 525  [-0.7182044019045992, -0.3499778295214787, -0....    0.102943
# 526  [-1.4450705186383415, -0.5190520214086779, 0.0...    0.093607
# 527  [-2.482221817351649, -1.320769586064103, -1.28...    0.094227
#
#      mu_jup_list  mu_zero_list      fwhm      cont       bis shift_by_rv
# 0       0.110301      0.107253  7.034716  7.034716 -0.064548    prov_rvs
# 1       0.119367      0.117700  7.036466  7.036466 -0.061424    prov_rvs
# 2       0.109090      0.108017  7.037521  7.037521 -0.062043    prov_rvs
# 3       0.109998      0.105114  7.039602  7.039602 -0.062065    prov_rvs
# 4       0.101187      0.101764  7.031382  7.031382 -0.063048    prov_rvs
# ..           ...           ...       ...       ...       ...         ...
# 523     0.091574      0.095483  7.038349  7.038349 -0.066841    prov_rvs
# 524     0.094148      0.097691  7.038117  7.038117 -0.066610    prov_rvs
# 525     0.111250      0.113320  7.038524  7.038524 -0.065913    prov_rvs
# 526     0.096480      0.100230  7.037571  7.037571 -0.067115    prov_rvs
# 527     0.096575      0.099710  7.039245  7.039245 -0.065753    prov_rvs
#
# [528 rows x 18 columns]

# %%
for i in df['ccf_residual_rescaled']:
    plt.plot(i)

# %%
min_rv = np.min(rv_list)
max_rv = np.max(rv_list)
cscale_residuals = (np.array(rv_list - min_rv) / (max_rv - min_rv))
print(np.min(cscale_residuals), np.max(cscale_residuals))

col = plt.cm.jet([0.25, 0.75])
n = len(ccfs_of_interest)
colors = plt.cm.bwr(cscale_residuals)

# Create the residual plot by looping through the list of CCFs ordered by date
fig, ax = plt.subplots(1, 1, figsize=(14, 6))
num = 0
for i in np.arange(0, len(ccfs_of_interest)):
    if num_ref_ccf == "median":
        plt.plot(x_axis, ccfs_of_interest[i] - np.median(list(ccfs_of_interest), axis=0), color=colors[num])
    else:
        if i != num_ref_ccf:
            plt.plot(x_axis, ccfs_of_interest[i] - np.array(ccfs_of_interest[num_ref_ccf]), color=colors[num])
    num += 1

plt.title(plot_title)
# make color bar
cmap = mpl.cm.bwr
norm = mpl.colors.Normalize(vmin=(min_rv - np.median(rv_list)), vmax=(max_rv - np.median(rv_list)))
cb = plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), orientation="vertical", pad=-0.0001)
cb.set_label(label='Stellar Activity Signal (m/s)', size=16, rotation=270, labelpad=20)

# %%
from residual_plot import residual_plot

residual_plot(df['vrad_star'], rv_data, df['og_ccf_list'], "median", 'Original')
residual_plot(df['vrad_star'], rv_data, df['jup_shifted_CCF_data_list'], "median", 'Jupiter Removed')
residual_plot(df['vrad_star'], rv_data, df['zero_shifted_CCF_list'], "median", 'Zero Shifted')
# Out:
# 0.0 1.0
# 0.0 1.0
# 0.0 1.0

# %%
time_bjd_isot(df['BJD'][484])
# Out:
# '2018-03-29T23:43:42.004'

# %%
# save df to npz file

outfile = "Injection_HARPS2.3.1_ready_for_TF_records.npz"
np.savez(outfile, 
         BJD =  BJD_list,
         vrad_star =  rvh,
         og_ccf_list = og_ccf_list,
         jup_shifted_CCF_data_list = jup_shifted_CCF_data_list,
         zero_shifted_CCF_list =  shifted_CCF_list,
         CCF_normalized_list = CCF_normalized_list,
         cff_residual_list = cff_residual_list.tolist(),
         ccf_residual_rescaled = ((cff_residual_list-median_residual)/std_residual).tolist(),
         CCF_normalized_list_cutoff = ccf_norm_cutoff_np.tolist(),
         CCF_residual_list_cutoff = cff_residual_list_cutoff.tolist(),
         ccf_residual_rescaled_cutoff = ((cff_residual_list_cutoff-median_cutoff_residual)/std_cutoff_residual).tolist(),
         mu_og_list = mu_og_list,
         mu_jup_list = mu_jup_list,
         mu_zero_list = mu_zero_list,
         fwhm = fwhm,
         cont = cont,
         bis= bis,
         shift_by_rv = shift_by_rv
        )

# %%
npzfile = np.load(outfile) 
npzfile.files

#npzfile['og_ccf_list']
# Out:
# ['BJD',
#  'vrad_star',
#  'og_ccf_list',
#  'jup_shifted_CCF_data_list',
#  'zero_shifted_CCF_list',
#  'CCF_normalized_list',
#  'cff_residual_list',
#  'ccf_residual_rescaled',
#  'CCF_normalized_list_cutoff',
#  'CCF_residual_list_cutoff',
#  'ccf_residual_rescaled_cutoff',
#  'mu_og_list',
#  'mu_jup_list',
#  'mu_zero_list',
#  'fwhm',
#  'cont',
#  'bis',
#  'shift_by_rv']

# %% [markdown]
# # write it all to Tf_records
#
# Params needed:
# 1. bjd
# 2. CCFs
#     * OG CCF
#     * Jup CCF
#     * ext CCF
#     * Median CCF
# 3. Rescaled CCF residuals
# 4. Activity signal
# 5. mu fits
#     * mu_og_fit
#     * mu_jup_fit
#     * mu_zero_fit
# 6. Other
#     * fwhm
#     * contrast
#     * bis
#
# Subsets needed
# 1. Training set (80%) & Cross-validation subsets (%80)
# 2. Validation set (10%)
# 3. Test set (10%)

# %% [markdown]
# ## Shift CCFs to zero (no planet injection) - Oct 2021

# %%
from master_shifting_planet import master_shifting_planet
from mu_plotting import mu_plotting
from residual_plot import residual_plot
#from shifter_fits_maker import shifter_fits_maker
from tf_writer_jul15_21 import tf_writer
from master_shifting import master_shifting

# %%
# Define gaussian function
def gauss(x, p):
    return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

# A simple minimization function:
def least(p, args):
    x, y = args
    return gauss(x, p) - y

parinfo = [{'fixed': False, 'step': 1e-7},
           {'fixed': False, 'step': 1e-5},
           {'fixed': False, 'step': 1e-4},
           {'fixed': False, 'step': 1e-9}]

# %%
# Test initial fitting params
rv_data = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, len(ccfBary[0]))
CCF_data = ccfBary
p_no =[0.6, 0.0, 2.7, 1.0]# [1.0, 0.0, 3, 1.0] #

fig, ax = plt.subplots(2,1, figsize=(10, 8))
#plt.plot(rv_data, gauss(rv_data,p_no_shifted), label='gaussian guess')
ax[0].plot(rv_data, CCF_data[0], label='real data')
ax[0].vlines(x=rv_data[10], ymin=0.4, ymax=1)
ax[0].vlines(x=rv_data[39], ymin=0.4, ymax=1)

pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no, (rv_data, CCF_data[0]), parinfo)
mu_og = pfit_no_shift[1]

#ax[0].plot(rv_data, gauss(rv_data,p_no), label='guess gaussian fit')
ax[0].plot(rv_data, gauss(rv_data,pfit_no_shift), label='gaussian fit')
ax[0].legend()


ax[1].plot(rv_data, CCF_data[0]-gauss(rv_data,pfit_no_shift), label='difference in real data and gauss fit')
ax[1].legend()

# %%
    bjd = bjd
    ccfBary =  ccfBary
    rvh = rvh
    ref_frame_shift="off" #"off" or a specific value in km/s
    removed_planet_rvs= -bsrv #array of rv values for planet signal in km/s
    zero_or_median = "median"
    p_no = [0.6, 0.0, 3, 1.0] #[0.6, 0.0, 2.7, 1.0],
    shift_by_rv = "prov_rvs"
    fwhm = fwhm
    cont = cont 
    bis = bis
    index_cut_num = 18.76
    
    number_of_ccfs = len(ccfBary)

    # HARPS direct data lists
    BJD_list = []
    og_ccf_list = []
    rv_from_HARPS_list = []
    v_rad_raw_list = []

    # mpyfit lists
    mu_og_list = []
    mu_jup_list = []
    mu_planet_list = []
    mu_zero_list = []
    CCF_normalized_list = []

    # CCF lists
    compiled_ccf_list = []
    jup_shifted_CCF_data_list = []
    shifted_CCF_list = []
    final_ccf_list = []

    spline_method = 'quadratic'
    for i in range(0, number_of_ccfs):
        day_of_observation = bjd[i]
        BJD_list.append(day_of_observation)

        # extracts the CCF data and rv from fits
        CCF_data = ccfBary[i]
        og_ccf_list.append(CCF_data)
        rv_from_HARPS = rvh[i]  # - bsrv[i]
        rv_from_HARPS_list.append(rv_from_HARPS)

        # Finds the local minima using a Gaussian fit
        # Define the actual function where     A = p[0], mu = p[1], sigma = p[2], c = p[3]
        def gauss(x, p):
            return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

        # A simple minimization function:
        def least(p, args):
            x, y = args
            return gauss(x, p) - y

        rv_range = np.max(final_df["rvraw"])-np.min(final_df["rvraw"])

        parinfo = [{'fixed': False, 'step': 1e-7},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-9}]

        # no_shift fit
        rv_data = rv_axis = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, len(ccfBary[0]))
        p_no_shifted = p_no
        pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
        mu_og = pfit_no_shift[1]
        mu_og_list.append(mu_og)
        compiled_ccf_list.append(CCF_data)

        # Add in reference frame shift

        if removed_planet_rvs[0] != "NULL":  # Remove known planet signals *a priori*
            jupiter_shift = removed_planet_rvs[i]
            v_rad_raw = rvh[i] + removed_planet_rvs[i]
            v_rad_raw_list.append(v_rad_raw)

            # planet removal shift
            rv_data_jupiter_shift = rv_data + jupiter_shift  # minus sign
            f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind=spline_method, fill_value='extrapolate')
            jupiter_shifted_CCF_data = f_jup(rv_data)
            jup_shifted_CCF_data_list.append(jupiter_shifted_CCF_data)
            compiled_ccf_list.append(jupiter_shifted_CCF_data)

            # fits the shifted by planets removed data
            p_shifted_jup = [1., 0.1 + jupiter_shift, 1., 0.5]
            pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)
            mu_og = pfit_jup[1]
            mu_jup_list.append(mu_og)

            if zero_or_median == "zero":
                if shift_by_rv =="prov_rvs":
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else: #shift by mpyfit rvs instead
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    #print(m_zero)
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        else:  # Do not remove any planet signals *a priori*
            if zero_or_median == "zero":
                if shift_by_rv == "prov_rvs":
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
        final_ccf_list.append(ccf_to_use)

        # normalize the CCFs
        one_fifth = int(0.2*len(ccfBary[0]))
        x_left = ccf_to_use[0:one_fifth]
        x_right = ccf_to_use[len(ccfBary[0])-one_fifth:len(ccfBary[0])]
        x_norm_range = list(x_left) + list(x_right)
        max_norm_range = np.max(x_norm_range)
        min_pt_ccf = np.min(ccf_to_use)
        CCF_normalized = ccf_to_use* (1 / np.mean(x_norm_range)) #-min_pt_ccf)/(max_norm_range-min_pt_ccf) #
        CCF_normalized_list.append(CCF_normalized)

        # clip off 1km/s on each side
        # find indexes of where to cutoff
        index_cutoff = np.where(abs(abs(rv_data)-index_cut_num) < 0.2)
        ccf_norm_np = np.array(list(CCF_normalized_list))
        ccf_norm_transpose_np = ccf_norm_np.transpose()
        # clip edges and take the transpose again
        ccf_norm_cutoff_np = ccf_norm_transpose_np[index_cutoff[0][0]:index_cutoff[0][1], ].transpose()

    # Create a dataframe
    d = {'BJD': BJD_list,
         'vrad_star': rvh,
         'og_ccf_list': og_ccf_list,
         'jup_shifted_CCF_data_list': jup_shifted_CCF_data_list,
         'zero_shifted_CCF_list': shifted_CCF_list,
         'CCF_normalized_list': CCF_normalized_list,
         'CCF_normalized_list_cutoff': ccf_norm_cutoff_np.tolist(),
         'mu_og_list': mu_og_list,
         'mu_jup_list': mu_jup_list,
         'mu_zero_list': mu_zero_list,
         'fwhm': fwhm,
         'cont': cont,
         'bis': bis,
         'shift_by_rv': shift_by_rv}
    df = pd.DataFrame(data=d)

# %%
df
# Out:
#               BJD  vrad_star  \
# 0    2.457328e+06   0.105097
# 1    2.457333e+06   0.103722
# 2    2.457378e+06   0.103140
# 3    2.457385e+06   0.106937
# 4    2.457270e+06   0.101524
# ..            ...        ...
# 523  2.458304e+06   0.098142
# 524  2.458303e+06   0.098529
# 525  2.458233e+06   0.100014
# 526  2.458221e+06   0.098386
# 527  2.458224e+06   0.098967
#
#                                            og_ccf_list  \
# 0    [1.0015097, 1.0000265, 0.9985184, 0.99718356, ...
# 1    [1.0014056, 0.99990964, 0.99838215, 0.99708915...
# 2    [1.0013633, 0.9999264, 0.9984147, 0.99699295, ...
# 3    [1.0014029, 0.9999537, 0.998419, 0.9970925, 0....
# 4    [1.0014303, 0.9999144, 0.9983245, 0.9969947, 0...
# ..                                                 ...
# 523  [1.0012625, 0.99975926, 0.9982174, 0.9968826, ...
# 524  [1.0012594, 0.9997893, 0.9982279, 0.99685496, ...
# 525  [1.0010835, 0.9996523, 0.9981685, 0.9968275, 0...
# 526  [1.0011425, 0.99964464, 0.99819916, 0.99690175...
# 527  [1.0010383, 0.9994956, 0.99807036, 0.9967336, ...
#
#                              jup_shifted_CCF_data_list  \
# 0    [1.0015259286628648, 1.0000433470402865, 0.998...
# 1    [1.0014229303898672, 0.9999278647491336, 0.998...
# 2    [1.0013834762283933, 0.999947897911216, 0.9984...
# 3    [1.0014225286779062, 0.9999752741082402, 0.998...
# 4    [1.0014295113132394, 0.9999135786764424, 0.998...
# ..                                                 ...
# 523  [1.001246875223447, 0.9997427619553527, 0.9982...
# 524  [1.001244717739918, 0.9997731764398882, 0.9982...
# 525  [1.0010926949166126, 0.9996620572024901, 0.998...
# 526  [1.0011566610584148, 0.9996584211308162, 0.998...
# 527  [1.001052259490087, 0.9995084671315091, 0.9980...
#
#                                  zero_shifted_CCF_list  \
# 0    [1.0015208650773408, 1.0000378134047205, 0.998...
# 1    [1.0014202657981697, 0.9999248319830604, 0.998...
# 2    [1.001381777686345, 0.9999460786785426, 0.9984...
# 3    [1.0014150007404885, 0.9999661819646528, 0.998...
# 4    [1.0014305125233784, 0.9999147786730694, 0.998...
# ..                                                 ...
# 523  [1.0012536519708026, 0.9997503954527563, 0.998...
# 524  [1.0012505645881824, 0.9997800472176485, 0.998...
# 525  [1.0010961673379362, 0.9996658989249703, 0.998...
# 526  [1.0011635098803175, 0.9996652039930165, 0.998...
# 527  [1.0010585600734, 0.9995141432881035, 0.998087...
#
#                                    CCF_normalized_list  \
# 0    [1.0025297484719915, 1.0010452028452679, 0.999...
# 1    [1.002392234295504, 1.0008953490272858, 0.9993...
# 2    [1.0024196963186978, 1.000982509228344, 0.9994...
# 3    [1.0024125052557906, 1.0009622433187584, 0.999...
# 4    [1.0024746024751947, 1.0009572883230446, 0.999...
# ..                                                 ...
# 523  [1.0023913946132479, 1.0008864299176186, 0.999...
# 524  [1.00240676671154, 1.000934551249273, 0.999371...
# 525  [1.0022638974951192, 1.000831960743373, 0.9993...
# 526  [1.0023027725761635, 1.0008027617086195, 0.999...
# 527  [1.00228103966247, 1.0007347368556434, 0.99930...
#
#                             CCF_normalized_list_cutoff  mu_og_list  \
# 0    [1.0010452028452679, 0.9995351747057094, 0.998...    0.096017
# 1    [1.0008953490272858, 0.9993654653060918, 0.998...    0.094052
# 2    [1.000982509228344, 0.9994696096747392, 0.9980...    0.091299
# 3    [1.0009622433187584, 0.999425729811548, 0.9980...    0.095336
# 4    [1.0009572883230446, 0.9993656940821727, 0.998...    0.101985
# ..                                                 ...         ...
# 523  [1.0008864299176186, 0.9993431756206085, 0.998...    0.106994
# 524  [1.000934551249273, 0.9993714816488447, 0.9979...    0.107188
# 525  [1.000831960743373, 0.9993461484793756, 0.9980...    0.094637
# 526  [1.0008027617086195, 0.9993544114492513, 0.998...    0.090734
# 527  [1.0007347368556434, 0.9993066781596304, 0.997...    0.091880
#
#      mu_jup_list  mu_zero_list      fwhm      cont       bis shift_by_rv
# 0       0.105137      0.102172  7.034716  7.034716 -0.064548    prov_rvs
# 1       0.103753      0.102163  7.036466  7.036466 -0.061424    prov_rvs
# 2       0.103147      0.102140  7.037521  7.037521 -0.062043    prov_rvs
# 3       0.106960      0.102156  7.039602  7.039602 -0.062065    prov_rvs
# 4       0.101557      0.102165  7.031382  7.031382 -0.063048    prov_rvs
# ..           ...           ...       ...       ...       ...         ...
# 523     0.098267      0.102257  7.038349  7.038349 -0.066841    prov_rvs
# 524     0.098630      0.102233  7.038117  7.038117 -0.066610    prov_rvs
# 525     0.100035      0.102153  7.038524  7.038524 -0.065913    prov_rvs
# 526     0.098345      0.102090  7.037571  7.037571 -0.067115    prov_rvs
# 527     0.098962      0.102127  7.039245  7.039245 -0.065753    prov_rvs
#
# [528 rows x 14 columns]

# %%
#mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)

plt.plot(rv_data, gauss(rv_data, p_no_shifted))
plt.plot(rv_data, ccfBary[0])

# %%
    # old code
    bjd = bjd
    ccfBary =  ccfBary
    rvh = rvh
    ref_frame_shift="off" #"off" or a specific value in km/s
    removed_planet_rvs= -bsrv #array of rv values for planet signal in km/s
    zero_or_median = "median"
    p_no = [0.6, 0.0, 3, 1.0] #[0.6, 0.0, 2.7, 1.0],
    shift_by_rv = "prov_rvs"
    fwhm = fwhm
    cont = cont 
    bis = bis
    index_cut_num = 18.76
    
    number_of_ccfs = len(ccfBary)

    # HARPS direct data lists
    BJD_list = []
    og_ccf_list = []
    rv_from_HARPS_list = []
    v_rad_raw_list = []

    # mpyfit lists
    mu_og_list = []
    mu_jup_list = []
    mu_planet_list = []
    mu_zero_list = []
    CCF_normalized_list = []

    # CCF lists
    compiled_ccf_list = []
    jup_shifted_CCF_data_list = []
    shifted_CCF_list = []
    final_ccf_list = []

    spline_method = 'quadratic'
    for i in range(0, number_of_ccfs):
        day_of_observation = bjd[i]
        BJD_list.append(day_of_observation)

        # extracts the CCF data and rv from fits
        CCF_data = ccfBary[i]
        og_ccf_list.append(CCF_data)
        rv_from_HARPS = rvh[i]  # - bsrv[i]
        rv_from_HARPS_list.append(rv_from_HARPS)

        # Finds the local minima using a Gaussian fit
        # Define the actual function where     A = p[0], mu = p[1], sigma = p[2], c = p[3]
        def gauss(x, p):
            return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

        # A simple minimization function:
        def least(p, args):
            x, y = args
            return gauss(x, p) - y

        rv_range = np.max(final_df["rvraw"])-np.min(final_df["rvraw"])

        parinfo = [{'fixed': False, 'step': 1e-7},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-9}]

        # no_shift fit
        rv_data = rv_axis = np.linspace(-19.58, 19.78, 49)# rv_data = np.linspace(-20, 20, len(ccfBary[0])) #
        p_no_shifted = p_no
        pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
        mu_og = pfit_no_shift[1]
        mu_og_list.append(mu_og)
        compiled_ccf_list.append(CCF_data)

        # Add in reference frame shift

        if removed_planet_rvs[0] != "NULL":  # Remove known planet signals *a priori*
            jupiter_shift = removed_planet_rvs[i]
            v_rad_raw = rvh[i] + removed_planet_rvs[i]
            v_rad_raw_list.append(v_rad_raw)

            # planet removal shift
            rv_data_jupiter_shift = rv_data + jupiter_shift  # minus sign
            f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind=spline_method, fill_value='extrapolate')
            jupiter_shifted_CCF_data = f_jup(rv_data)
            jup_shifted_CCF_data_list.append(jupiter_shifted_CCF_data)
            compiled_ccf_list.append(jupiter_shifted_CCF_data)

            # fits the shifted by planets removed data
            p_shifted_jup = [1., 0.1 + jupiter_shift, 1., 0.5]
            pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)
            mu_og = pfit_jup[1]
            mu_jup_list.append(mu_og)

            if zero_or_median == "zero":
                if shift_by_rv =="prov_rvs":
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else: #shift by mpyfit rvs instead
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        else:  # Do not remove any planet signals *a priori*
            if zero_or_median == "zero":
                if shift_by_rv == "prov_rvs":
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
        final_ccf_list.append(ccf_to_use)

        # normalize the CCFs
        one_fifth = int(0.2*len(ccfBary[0]))
        x_left = ccf_to_use[0:one_fifth]
        x_right = ccf_to_use[len(ccfBary[0])-one_fifth:len(ccfBary[0])]
        x_norm_range = list(x_left) + list(x_right)
        CCF_normalized = ccf_to_use * (1 / np.mean(x_norm_range))
        CCF_normalized_list.append(CCF_normalized)

        # clip off 1km/s on each side
        # find indexes of where to cutoff
        index_cutoff = np.where(abs(abs(rv_data)-index_cut_num) < 0.2)
        ccf_norm_np = np.array(list(CCF_normalized_list))
        ccf_norm_transpose_np = ccf_norm_np.transpose()
        # clip edges and take the transpose again
        ccf_norm_cutoff_np = ccf_norm_transpose_np[index_cutoff[0][0]:index_cutoff[0][1], ].transpose()

    # Create a dataframe
    d = {'BJD': BJD_list,
         'vrad_star': rvh,
         'og_ccf_list': og_ccf_list,
         'jup_shifted_CCF_data_list': jup_shifted_CCF_data_list,
         'zero_shifted_CCF_list': shifted_CCF_list,
         'CCF_normalized_list': CCF_normalized_list,
         'CCF_normalized_list_cutoff': ccf_norm_cutoff_np.tolist(),
         'mu_og_list': mu_og_list,
         'mu_jup_list': mu_jup_list,
         'mu_zero_list': mu_zero_list,
         'fwhm': fwhm,
         'cont': cont,
         'bis': bis,
         'shift_by_rv': shift_by_rv}
    df = pd.DataFrame(data=d)

# %%
plt.plot(df["BJD"], df["mu_zero_list"], ".")

# %%
mu_plotting(df,["mu_og_list","mu_jup_list", "mu_zero_list"],
            ["original", "Jupiter removed","shifted to "+str(zero_or_median)])
mu_plotting(df_master,["mu_zero_list"],
            ["shifted to "+str(zero_or_median)])

# %%
def master_shifting(bjd, ccfBary, rvh,
                    ref_frame_shift,  # "off" or a specific value in km/s
                    removed_planet_rvs,  # array of rv values for planet signal in km/s OR "NULL"
                    zero_or_median,
                    p_no,
                    shift_by_rv,
                    fwhm, cont, bis,
                    index_cut_num):  # "zero" or "median"
    number_of_ccfs = len(ccfBary)

    # HARPS direct data lists
    BJD_list = []
    og_ccf_list = []
    rv_from_HARPS_list = []
    v_rad_raw_list = []

    # mpyfit lists
    mu_og_list = []
    mu_jup_list = []
    mu_planet_list = []
    mu_zero_list = []
    CCF_normalized_list = []

    # CCF lists
    compiled_ccf_list = []
    jup_shifted_CCF_data_list = []
    shifted_CCF_list = []
    final_ccf_list = []

    spline_method = 'quadratic'
    for i in range(0, number_of_ccfs):
        day_of_observation = bjd[i]
        BJD_list.append(day_of_observation)

        # extracts the CCF data and rv from fits
        CCF_data = ccfBary[i]
        og_ccf_list.append(CCF_data)
        rv_from_HARPS = rvh[i]  # - bsrv[i]
        rv_from_HARPS_list.append(rv_from_HARPS)

        # Finds the local minima using a Gaussian fit
        # Define the actual function where     A = p[0], mu = p[1], sigma = p[2], c = p[3]
        def gauss(x, p):
            return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

        # A simple minimization function:
        def least(p, args):
            x, y = args
            return gauss(x, p) - y

        rv_range = np.max(final_df["rvraw"])-np.min(final_df["rvraw"])

        parinfo = [{'fixed': False, 'step': 1e-7},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-5*rv_range},
                   {'fixed': False, 'step': 1e-9}]

        # no_shift fit
        rv_data = rv_axis = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, len(ccfBary[0]))
        p_no_shifted = p_no
        pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
        mu_og = pfit_no_shift[1]
        mu_og_list.append(mu_og)
        compiled_ccf_list.append(CCF_data)

        # Add in reference frame shift

        if removed_planet_rvs[0] != "NULL":  # Remove known planet signals *a priori*
            jupiter_shift = removed_planet_rvs[i]
            v_rad_raw = rvh[i] + removed_planet_rvs[i]
            v_rad_raw_list.append(v_rad_raw)

            # planet removal shift
            rv_data_jupiter_shift = rv_data + jupiter_shift  # minus sign
            f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind=spline_method, fill_value='extrapolate')
            jupiter_shifted_CCF_data = f_jup(rv_data)
            jup_shifted_CCF_data_list.append(jupiter_shifted_CCF_data)
            compiled_ccf_list.append(jupiter_shifted_CCF_data)

            # fits the shifted by planets removed data
            p_shifted_jup = [1., 0.1 + jupiter_shift, 1., 0.5]
            pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)
            mu_og = pfit_jup[1]
            mu_jup_list.append(mu_og)

            if zero_or_median == "zero":
                if shift_by_rv =="prov_rvs":
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else: #shift by mpyfit rvs instead
                    # Shift to zero based on provided RVs
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    #print(m_zero)
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        else:  # Do not remove any planet signals *a priori*
            if zero_or_median == "zero":
                if shift_by_rv == "prov_rvs":
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    # Shift to zero
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]

                    shift_to_zero = -(mu_og)
                    rv_data_shifted = rv_data + shift_to_zero

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_zero, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
            else:  # shifted to median instead
                if shift_by_rv == "prov_rvs":
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - rv_from_HARPS)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
                else:  # shift by mpyfit rvs instead
                    ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
                    shift_to_median = (np.mean(rvh) - mu_og)
                    rv_data_shifted = rv_data + shift_to_median

                    f = interp1d(rv_data_shifted, ccf_to_use, kind='cubic', fill_value='extrapolate')
                    shifted_CCF_data = f(rv_data)
                    shifted_CCF_list.append(shifted_CCF_data)
                    compiled_ccf_list.append(shifted_CCF_data)

                    # fits the shifted data
                    p_shifted = [1., 0.1 - shift_to_median, 1., 0.5]
                    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
                    m_zero = pfit[1]
                    mu_zero_list.append(m_zero)  # -0.1)
        ccf_to_use = compiled_ccf_list[len(compiled_ccf_list) - 1]
        final_ccf_list.append(ccf_to_use)

        # normalize the CCFs
        one_fifth = int(0.2*len(ccfBary[0]))
        x_left = ccf_to_use[0:one_fifth]
        x_right = ccf_to_use[len(ccfBary[0])-one_fifth:len(ccfBary[0])]
        x_norm_range = list(x_left) + list(x_right)
        max_norm_range = np.max(x_norm_range)
        min_pt_ccf = np.min(ccf_to_use)
        CCF_normalized = ccf_to_use* (1 / np.mean(x_norm_range)) #-min_pt_ccf)/(max_norm_range-min_pt_ccf) #
        CCF_normalized_list.append(CCF_normalized)

        # clip off 1km/s on each side
        # find indexes of where to cutoff
        index_cutoff = np.where(abs(abs(rv_data)-index_cut_num) < 0.01)
        ccf_norm_np = np.array(list(CCF_normalized_list))
        ccf_norm_transpose_np = ccf_norm_np.transpose()
        # clip edges and take the transpose again
        ccf_norm_cutoff_np = ccf_norm_transpose_np[index_cutoff[0][0]:index_cutoff[0][1], ].transpose()

    # Create a dataframe
    d = {'BJD': BJD_list,
         'vrad_star': rvh,
         'og_ccf_list': og_ccf_list,
         'jup_shifted_CCF_data_list': jup_shifted_CCF_data_list,
         'zero_shifted_CCF_list': shifted_CCF_list,
         'CCF_normalized_list': CCF_normalized_list,
         'CCF_normalized_list_cutoff': ccf_norm_cutoff_np.tolist(),
         'mu_og_list': mu_og_list,
         'mu_jup_list': mu_jup_list,
         'mu_zero_list': mu_zero_list,
         'fwhm': fwhm,
         'cont': cont,
         'bis': bis,
         'shift_by_rv': shift_by_rv}
    df = pd.DataFrame(data=d)

    return df

# %%
plt.plot(bjd, rvh, '.')

# %%
# No planet injection, just remove Jupiter and shift the rvs to zero 
# This cell is mainly helpful as a diagnostic, but does not write the shifted ccfs to new files

zero_or_median = "median"
shift_by_rv = "prov_rvs" # "mpyfit_rvs"#"prov_rvs" #or "mpyfit_rvs"#
index_cut_num = 19.16666667

df_master = master_shifting(bjd, ccfBary, rvh,
                    ref_frame_shift="off", #"off" or a specific value in km/s
                    removed_planet_rvs= -bsrv, #array of rv values for planet signal in km/s
                    zero_or_median = zero_or_median,
                    p_no = [0.6, 0.0, 3, 1.0], #[0.6, 0.0, 2.7, 1.0],
                    shift_by_rv = shift_by_rv,
                    fwhm = fwhm,
                    cont = cont, 
                    bis = bis,
                    index_cut_num = index_cut_num)#,
#                    ext=list(ext))

mu_plotting(df_master,["mu_og_list","mu_jup_list", "mu_zero_list"],
            ["original", "Jupiter removed","shifted to "+str(zero_or_median)])

wls = np.linspace(-19.58, 19.78, 49) #np.linspace(-20, 20, 49)

residual_plot(df_master["vrad_star"]*1000, wls,df_master["og_ccf_list"], 484, plot_title = "Original CCFs")
#residual_plot(df_master["vrad_star"], df_master["planet_shifted_CCF_data_list"], "median", plot_title = "Injected Planet Shifted CCFs")
residual_plot(df_master["vrad_star"]*1000, wls, df_master["zero_shifted_CCF_list"], 484, plot_title = "Mean Shifted CCFs")
residual_plot(df_master["vrad_star"]*1000, wls, df_master["CCF_normalized_list"], 484, plot_title = "Normalized Mean Shifted CCFs")

# plot results
#residual_plot(df_master["vrad_star"], wls[4:156], df_master["CCF_normalized_list_cutoff"], 544, plot_title = "Normalized Mean Shifted CCFs")


df_master
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/rn/06tzsshx6h542jl02_xd33t80000gn/T/ipykernel_57041/478206753.py in <module>
#      15                     cont = cont,
#      16                     bis = bis,
# ---> 17                     index_cut_num = index_cut_num)#,
#      18 #                    ext=list(ext))
#      19
#
# /var/folders/rn/06tzsshx6h542jl02_xd33t80000gn/T/ipykernel_57041/454299250.py in master_shifting(bjd, ccfBary, rvh, ref_frame_shift, removed_planet_rvs, zero_or_median, p_no, shift_by_rv, fwhm, cont, bis, index_cut_num)
#     237         ccf_norm_transpose_np = ccf_norm_np.transpose()
#     238         # clip edges and take the transpose again
# --> 239         ccf_norm_cutoff_np = ccf_norm_transpose_np[index_cutoff[0][0]:index_cutoff[0][1], ].transpose()
#     240
#     241     # Create a dataframe
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df_master["og_ccf_list"]
# Out:
# 0      [1.0015097, 1.0000265, 0.9985184, 0.99718356, ...
# 1      [1.0014056, 0.99990964, 0.99838215, 0.99708915...
# 2      [1.0013633, 0.9999264, 0.9984147, 0.99699295, ...
# 3      [1.0014029, 0.9999537, 0.998419, 0.9970925, 0....
# 4      [1.0014303, 0.9999144, 0.9983245, 0.9969947, 0...
#                              ...
# 523    [1.0012625, 0.99975926, 0.9982174, 0.9968826, ...
# 524    [1.0012594, 0.9997893, 0.9982279, 0.99685496, ...
# 525    [1.0010835, 0.9996523, 0.9981685, 0.9968275, 0...
# 526    [1.0011425, 0.99964464, 0.99819916, 0.99690175...
# 527    [1.0010383, 0.9994956, 0.99807036, 0.9967336, ...
# Name: og_ccf_list, Length: 528, dtype: object

# %%
#mu_plotting(df_master,["mu_zero_list"],
#            ["shifted to "+str(zero_or_median)])
# 50 cm/s

fig, ax = plt.subplots(2, 1, figsize=(12, 10))

ax[0].plot(df_master['BJD'], df_master["mu_og_list"]*20-np.mean(df_master["mu_og_list"]*20), ".", label="og ccffs")
ax[0].plot(df_master['BJD'], df_master["mu_zero_list"]*1000-np.mean(df_master["mu_zero_list"]*1000), ".", label="shifted to "+str(zero_or_median))
ax[0].plot(BJD_list,DRS_rvh*20-2, ".", label="DRS Raw RVs *20 - offset")
ax[1].plot(bjd, ext*1000, ".")
ax[0].set_ylabel("RV (m/s)")
ax[1].set_ylabel("Extinction (m/s)")

ax[0].legend()

np.max(df_master["mu_og_list"]-np.mean(df_master["mu_og_list"]))*1000
#np.min(df_master["mu_og_list"]-np.mean(df_master["mu_og_list"]))
# Out:
# 14.890615434773965

# %% [markdown]
# ## write to a fits file

# %%
np.shape([l.tolist() for l in df_master["og_ccf_list"]])
# Out:
# (528, 49)

# %%
col2 = fits.Column(name='og_ccf_list', format='528E', dim='(49)',
                       array=np.array([l.tolist() for l in df_master["og_ccf_list"]]))
col2
# Out:
# name = 'og_ccf_list'; format = '528E'; dim = '(49)'

# %%
zero_or_median = "median"
shift_by_rv =  "prov_rvs" #"mpyfit_rvs"#or
clipped = "clipped"

shifter_fits_maker(bjd, ccfBary, rvh,
                        ref_frame_shift="off", #"off" or a specific value in km/s
                        removed_planet_rvs= -bsrv, #array of rv values for planet signal in km/s
                        zero_or_median = zero_or_median,
                        shift_by_rv = shift_by_rv,
                        fwhm = fwhm,
                        cont = cont, 
                        bis = bis,
                        index_cut_num = index_cut_num,
                        path = 'shifted_fits_clean_'+zero_or_median+'_'+shift_by_rv+'_'+clipped+'_Oct27_one_file')
# Out:
# ---------------------------------------------------------------------------
# VerifyError                               Traceback (most recent call last)
# /var/folders/rn/06tzsshx6h542jl02_xd33t80000gn/T/ipykernel_21714/3454317268.py in <module>
#      12                         bis = bis,
#      13                         index_cut_num = index_cut_num,
# ---> 14                         path = 'shifted_fits_clean_'+zero_or_median+'_'+shift_by_rv+'_'+clipped+'_Oct27_one_file')
#
# ~/Documents/GitHub/SOAP_2_smol2/Archive_HARPS_N_NEW DRS/shifter_fits_maker.py in shifter_fits_maker(bjd, ccfBary, rvh, ref_frame_shift, removed_planet_rvs, zero_or_median, shift_by_rv, fwhm, cont, bis, index_cut_num, path)
#      33     # ccf params
#      34     col2 = fits.Column(name='og_ccf_list', format='49E', dim='(528)',
# ---> 35                        array=np.array([l.tolist() for l in df_master["og_ccf_list"]]).reshape((528 ,49)))
#      36     col3 = fits.Column(name='jup_shifted_CCF_data_list' ,format='49E', dim='(528)',
#      37                        array=np.array([l.tolist() for l in df_master["jup_shifted_CCF_data_list"]]).reshape((528 ,49)))
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.7/site-packages/astropy/io/fits/column.py in __init__(self, name, format, unit, null, bscale, bzero, disp, start, dim, array, ascii, coord_type, coord_unit, coord_ref_point, coord_ref_value, coord_inc, time_ref_pos)
#     619                 msg.append(indent(val[1]))
#     620
# --> 621             raise VerifyError('\n'.join(msg))
#     622
#     623         for attr in KEYWORD_ATTRIBUTES:
#
# VerifyError: The following keyword arguments to Column were invalid:
#     The repeat count of the column format 'og_ccf_list' for column '49E' is fewer than the number of elements per the TDIM argument '(528)'.  The invalid TDIMn value will be ignored for the purpose of formatting this column.

# %%
np.array([l.tolist() for l in df_master["og_ccf_list"]]).reshape((528 ,49))
# Out:
# array([[1.00150967, 1.00002646, 0.99851841, ..., 1.0014503 , 1.00178933,
#         1.00203037],
#        [1.0014056 , 0.99990964, 0.99838215, ..., 1.00164509, 1.00206935,
#         1.00231409],
#        [1.00136328, 0.99992639, 0.9984147 , ..., 1.00153542, 1.00192058,
#         1.00214958],
#        ...,
#        [1.00108349, 0.99965233, 0.99816853, ..., 1.00143445, 1.00178301,
#         1.00197899],
#        [1.0011425 , 0.99964464, 0.99819916, ..., 1.0013417 , 1.00174582,
#         1.00193501],
#        [1.00103831, 0.99949563, 0.99807036, ..., 1.00132012, 1.00171173,
#         1.0019238 ]])

# %%
# Check file contents

hdul = fits.open('shifted_fits_clean_'+zero_or_median+'_'+shift_by_rv+'_'+clipped+'_Aug24_one_file/shifted_ccfs_combined.fits', memmap=False)

# extracts activity signal and rv_data
ccf_tests = hdul[1].data['CCF_normalized_list_cutoff']
num = 0

fig, ax = plt.subplots(1, 1, figsize=(14, 6))
for i in np.arange(0,629):
    plt.plot(wls[4:156], ccf_tests[i]-ccf_tests[544])
    num += 1

# %% [markdown]
# ## write to TF records

# %%
# write fits files into TF_Records
# Choose path to pull fits files from: 'input_path'
# Choose path to write TF_Records to: 'path;
# Choose number of fits files: 'numfits'
# Choose random seed for shuffling: 'randseed'

pathname= '/Users/Zoe/Documents/SOAP_2/Archive_HARPS_N/TF_record_Aug_24_21_no_planets_'+clipped+'_'+zero_or_median+'_'+shift_by_rv

tf_writer(input_path = 'shifted_fits_clean_'+zero_or_median+'_'+shift_by_rv+'_'+clipped+'_Aug24_one_file/',
          path=pathname+'/',
          numfits=629, randseed =42)#37)

# %% [markdown]
# ## older code (pre-October 2021)

# %%
#np.average(DRS_new_vrad_list, weights=DRS_weight_new_sig_vrad_list)
#len(mean_ccf)
plt.plot(normalized_ccf)
len(hdul[1].data[68])
# Out:
# 49

# %%
len(np.arange(-20, 20, 0.5))
# Out:
# 80

# %%
index = new_bjd_list.get_loc(bjd, method = "nearest")
print(bjd)
print(df["quality"][index])
# Out:
# 2457376.12272715
# 0.7459557889241406

# %%
print(len(df["quality"]))
len(df["quality"][df["quality"]<0.99])
# Out:
# 98019
# 28923

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2021-07-23T11:21:54' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# VERSION =               120203 / Application parameter value
# DWELL   =               300000 / Application parameter value
# RD_TIME =                    0 / Application parameter value
# RS_TIME =                  383 / Application parameter value
# FRM_TYPE=                    1 / Application parameter value
# NUM_EXPS=                    1 / Application parameter value
# EL_GAIN =                    1 / Application parameter value
# SPEED   =                    1 / Application parameter value
# SER_REG =                    0 / Application parameter value
# CLK_MON1=                    0 / Application parameter value
# CLK_MON2=                    1 / Application parameter value
# TELESCOP= 'TNG     '
# TIMESYS = 'UTC     '           / Explicit time scale specification
# DATE-OBS= '2018-04-16T08:38:51.270' / Date and time of start of obs. in UTC
# PROCESS = 'Single raw read'    / Data processing mode
# FILENAME= 'HARPN.2018-04-16T08-38-51.270.fits' / FITS file generatedName
# TIME    = '08:44:13'           / Time FITS file was written
# EXPSTART= '08:38:51'           / Exposure start time (UT)
# PROGRAM = 'SOLAR   '           / Program generatedName
# OBS-TYPE= 'SCIENCE '           / Observation type
# SITENAME= 'ORM     '           / La Palma
# INSTRUME= 'HARPN   '           / Instrument generatedName
# OBSERVAT= 'TNG     '           / Observatory
# GEOELEV =               2387.2 / no comment
# GEOLAT  = '28 45 14.4 N'       / no comment
# GEOLON  = '17 53 20.6 W'       / no comment
# RA-RAD  =    0.421890804269112 / Right ascension (radians as float)
# DEC-RAD =    0.175645742282368 / Declination (radians as float)
# RA-DEG  =           24.1725625 / Right ascension (degrees as float)
# DEC-DEG =     10.0637597222222 / Declination (degrees as float)
# RA      =     1.61150416666667 / Right Ascension (hours as float)
# DEC     =    0.670917314814815 / Declination (hours as float)
# EL      =    0.427823304552332 / Elevation at the end (radians as float)
# AIRMASS =     2.31109643009331 / Air mass
# AG-FILE = '20180416T083851.fits' / Autoguider file generatedName
# EM-FILE = 'NONE    '           / Exposure meter file generatedName
# EX-FILE = 'NONE    '           / Expose AG file generatedName
# MJD-OBS =        58224.3603125 / Julian Date
# LST     =     21.0855555555556 / Local Sidereal Time
# EQUINOX =                2000. / no comment
# EXPTIME =                 300. / Effective exposure time (in secs)
# PRODCATG= 'ANCILLARY.CCF'
# DATAMD5 = 'b62f998b7304a3d6af331ca053e16599' / MD5 checksum
# PIPEFILE= 'HARPN_CCF_A.fits'   / Filename of data product
# HIERARCH ESO PRO CATG = 'CCF_A   ' / Category of pipeline product frame
# HIERARCH ESO PRO DID = 'PRO-1.16' / Data dictionary for PRO
# HIERARCH ESO PRO TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH = 'UNDEFINED' / Observation technique
# HIERARCH ESO PRO SCIENCE =   F / Scientific product if T
# HIERARCH ESO PRO REC1 ID = 'espdr_sci_red' / Pipeline recipe (unique) identifier
# HIERARCH ESO PRO REC1 DRS ID = 'cpl-7.1.3' / Data Reduction System identifier
# HIERARCH ESO PRO REC1 PIPE ID = 'espdr/2.3.1' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC1 RAW1 NAME = 'HARPN.2018-04-16T08-38-51.270.fits' / File na
# HIERARCH ESO PRO REC1 RAW1 CATG = 'HEADER  ' / Category of raw frame
# HIERARCH ESO PRO REC1 RAW2 NAME = 'HARPN.2018-04-16T08-38-51.270.fits' / File na
# HIERARCH ESO PRO REC1 RAW2 CATG = 'OBJ_FP  ' / Category of raw frame
# HIERARCH ESO PRO DATANCOM =  2 / Number of combined frames
# HIERARCH ESO PRO REC1 CAL1 NAME = 'HARPN_CCD_geom_config.fits' / File name of ca
# HIERARCH ESO PRO REC1 CAL1 CATG = 'CCD_GEOM' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL2 NAME = 'HARPN_HARPNCCD1_master_inst_config.fits' / Fi
# HIERARCH ESO PRO REC1 CAL2 CATG = 'MASTER_INST_CONFIG' / Category of calibration
# HIERARCH ESO PRO REC1 CAL3 NAME = 'HARPN_hot_pixels.fits' / File name of calibra
# HIERARCH ESO PRO REC1 CAL3 CATG = 'HOT_PIXEL_MASK' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL3 DATAMD5 = '22f4bb946f551ee4791f135e1ab33724' / MD5 si
# HIERARCH ESO PRO REC1 CAL4 NAME = 'HARPN_HARPNCCD1_1_bad_pixels.fits' / File nam
# HIERARCH ESO PRO REC1 CAL4 CATG = 'BAD_PIXEL_MASK' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL4 DATAMD5 = '9407b8c064fcada27d0869163e529fa3' / MD5 si
# HIERARCH ESO PRO REC1 CAL5 NAME= 'r.HARPN.2018-04-16T16:45:59.302_ORDER_TABLE_A'
# HIERARCH ESO PRO REC1 CAL5 CATG = 'ORDER_TABLE_A' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL5 DATAMD5 = '6520f81ab8ab752c05bdc28d4755ae00' / MD5 si
# HIERARCH ESO PRO REC1 CAL6 NAME= 'r.HARPN.2018-04-16T16:45:59.302_ORDER_TABLE_B'
# HIERARCH ESO PRO REC1 CAL6 CATG = 'ORDER_TABLE_B' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL6 DATAMD5 = '3cd160cff302c757501dcab9e6f82720' / MD5 si
# HIERARCH ESO PRO REC1 CAL7 NAME= 'r.HARPN.2018-04-16T16:46:59.513_MASTER_ORDER_'
# HIERARCH ESO PRO REC1 CAL7 CATG = 'ORDER_PROFILE_A' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL7 DATAMD5 = 'a11b7df2dc19f6d5670bf8691acf16c7' / MD5 si
# HIERARCH ESO PRO REC1 CAL8 NAME= 'r.HARPN.2018-04-16T16:46:59.513_MASTER_ORDER_'
# HIERARCH ESO PRO REC1 CAL8 CATG = 'ORDER_PROFILE_B' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL8 DATAMD5 = 'd4154a9f06b905a7799bae6c826dc878' / MD5 si
# HIERARCH ESO PRO REC1 CAL9 NAME= 'r.HARPN.2018-04-16T16:46:59.513_MASTER_FSPECT'
# HIERARCH ESO PRO REC1 CAL9 CATG = 'FSPECTRUM_A' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL9 DATAMD5 = 'f6636f69197882a537fe609ce34302e9' / MD5 si
# HIERARCH ESO PRO REC1 CAL10 NAME= 'r.HARPN.2018-04-16T16:46:59.513_MASTER_FSPEC'
# HIERARCH ESO PRO REC1 CAL10 CATG = 'FSPECTRUM_B' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL10 DATAMD5 = '2a3aefd92aff43f0755b352821872a5f' / MD5 s
# HIERARCH ESO PRO REC1 CAL11 NAME= 'r.HARPN.2018-04-16T16:46:59.513_MASTER_BLAZE'
# HIERARCH ESO PRO REC1 CAL11 CATG = 'BLAZE_A ' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL11 DATAMD5 = '2cf309b12ae3a936abbb674cb83a51c2' / MD5 s
# HIERARCH ESO PRO REC1 CAL12 NAME= 'r.HARPN.2018-04-16T16:46:59.513_MASTER_BLAZE'
# HIERARCH ESO PRO REC1 CAL12 CATG = 'BLAZE_B ' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL12 DATAMD5 = '09a63f1666cb28a5fdb199eef957edac' / MD5 s
# HIERARCH ESO PRO REC1 CAL13 NAME= 'r.HARPN.2018-04-16T17:04:11.233_WAVE_MATRIX_'
# HIERARCH ESO PRO REC1 CAL13 CATG = 'WAVE_MATRIX_DRIFT_THAR_FP_A' / Category of c
# HIERARCH ESO PRO REC1 CAL13 DATAMD5 = 'f9a30cee22f1d3955d9762bd11572239' / MD5 s
# HIERARCH ESO PRO REC1 CAL14 NAME= 'r.HARPN.2018-04-16T16:53:02.305_WAVE_MATRIX_'
# HIERARCH ESO PRO REC1 CAL14 CATG = 'WAVE_MATRIX_DRIFT_THAR_THAR_B' / Category of
# HIERARCH ESO PRO REC1 CAL14 DATAMD5 = 'ea6541f2ffe3fe7bff1220d7327d68a5' / MD5 s
# HIERARCH ESO PRO REC1 CAL15 NAME= 'r.HARPN.2018-04-16T17:04:11.233_DLL_MATRIX_D'
# HIERARCH ESO PRO REC1 CAL15 CATG = 'DLL_MATRIX_DRIFT_THAR_FP_A' / Category of ca
# HIERARCH ESO PRO REC1 CAL15 DATAMD5 = '424436fe9d25c2c71e459c002211998c' / MD5 s
# HIERARCH ESO PRO REC1 CAL16 NAME= 'r.HARPN.2018-04-16T16:53:02.305_DLL_MATRIX_D'
# HIERARCH ESO PRO REC1 CAL16 CATG = 'DLL_MATRIX_DRIFT_THAR_THAR_B' / Category of
# HIERARCH ESO PRO REC1 CAL16 DATAMD5 = '0602853fa1cfb9783ea2361b3c06ca67' / MD5 s
# HIERARCH ESO PRO REC1 CAL17 NAME = 'HARPN_REL_EFF_B.fits' / File name of calibra
# HIERARCH ESO PRO REC1 CAL17 CATG = 'REL_EFF_B' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL17 DATAMD5 = '343a32255b063b76d09ab0c8440e7877' / MD5 s
# HIERARCH ESO PRO REC1 CAL18 NAME= 'r.HARPN.2020-03-11T04:10:06.828_ABS_EFF_A.fi'
# HIERARCH ESO PRO REC1 CAL18 CATG = 'ABS_EFF_A' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL18 DATAMD5 = 'e834e6856373ce8e4e8cd6b7ca37f15d' / MD5 s
# HIERARCH ESO PRO REC1 CAL19 NAME= 'r.HARPN.2018-04-16T17:17:17.949_CONTAM_FP_B.'
# HIERARCH ESO PRO REC1 CAL19 CATG = 'CONTAM_FP' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL19 DATAMD5 = '27a9d5800e1d0ab3cc0eb0162cecc458' / MD5 s
# HIERARCH ESO PRO REC1 CAL20 NAME= 'r.HARPN.2018-04-16T17:04:11.233_S2D_BLAZE_TH'
# HIERARCH ESO PRO REC1 CAL20 CATG = 'S2D_BLAZE_THAR_FP_B' / Category of calibrati
# HIERARCH ESO PRO REC1 CAL20 DATAMD5 = '5aee2ea09f7535f05469f4a5fe3a65d7' / MD5 s
# HIERARCH ESO PRO REC1 CAL21 NAME = 'ESPRESSO_EXTINCTION_TABLE.fits' / File name
# HIERARCH ESO PRO REC1 CAL21 CATG = 'EXT_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL22 NAME = 'ESPRESSO_mask_lut.fits' / File name of calib
# HIERARCH ESO PRO REC1 CAL22 CATG = 'MASK_LUT' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL23 NAME = 'HARPN_flux_template.fits' / File name of cal
# HIERARCH ESO PRO REC1 CAL23 CATG = 'FLUX_TEMPLATE' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL24 NAME = 'ESPRESSO_new_G2.fits' / File name of calibra
# HIERARCH ESO PRO REC1 CAL24 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 PARAM1 NAME = 'ovsc_sig_clip_method' / method for sigma cl
# HIERARCH ESO PRO REC1 PARAM1 VALUE = 'mean    ' / Default: 'mean'
# HIERARCH ESO PRO REC1 PARAM2 NAME = 'ovsc_ksigma' / ksigma for sigma clipping in
# HIERARCH ESO PRO REC1 PARAM2 VALUE = '4       ' / Default: 4
# HIERARCH ESO PRO REC1 PARAM3 NAME = 'ovsc_max_iter' / maximal number of iteratio
# HIERARCH ESO PRO REC1 PARAM3 VALUE = '10      ' / Default: 10
# HIERARCH ESO PRO REC1 PARAM4 NAME = 'background_sw' / Background subtraction act
# HIERARCH ESO PRO REC1 PARAM4 VALUE = 'on      ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM5 NAME = 'sci_bkgr_grid_size_x' / Grid size in x used
# HIERARCH ESO PRO REC1 PARAM5 VALUE = '128     ' / Default: 577
# HIERARCH ESO PRO REC1 PARAM6 NAME = 'sci_bkgr_grid_size_y' / Grid size in y used
# HIERARCH ESO PRO REC1 PARAM6 VALUE = '64      ' / Default: 256
# HIERARCH ESO PRO REC1 PARAM7 NAME = 'wave_cal_source' / Wavelength calibration s
# HIERARCH ESO PRO REC1 PARAM7 VALUE = 'THAR    ' / Default: 'THAR'
# HIERARCH ESO PRO REC1 PARAM8 NAME = 'mask_table_id' / Mask table to be used, def
# HIERARCH ESO PRO REC1 PARAM8 VALUE = 'G2      ' / Default: 'XX'
# HIERARCH ESO PRO REC1 PARAM9 NAME = 'rv_center' / Approximate RV. In case of def
# HIERARCH ESO PRO REC1 PARAM9 VALUE = '0.1     ' / Default: -9999
# HIERARCH ESO PRO REC1 PARAM10 NAME = 'rv_range' / Range for the RV table.
# HIERARCH ESO PRO REC1 PARAM10 VALUE = '20      ' / Default: 20
# HIERARCH ESO PRO REC1 PARAM11 NAME = 'rv_step ' / Range's step for the RV table.
# HIERARCH ESO PRO REC1 PARAM11 VALUE = '0.5     ' / Default: 0.5
# HIERARCH ESO PRO REC1 PARAM12 NAME = 'extraction_method' / Method used to extrac
# HIERARCH ESO PRO REC1 PARAM12 VALUE = 'horne   ' / Default: 'horne'
# HIERARCH ESO PRO REC1 PARAM13 NAME = 'ksigma_cosmic' / ksigma for removing cosmi
# HIERARCH ESO PRO REC1 PARAM13 VALUE = '3.5     ' / Default: 3.5
# HIERARCH ESO PRO REC1 PARAM14 NAME = 'bias_res_removal_sw' / Flag indicating to
# HIERARCH ESO PRO REC1 PARAM14 VALUE = 'off     ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM15 NAME = 'flux_correction_type' / Flux correction: N
# HIERARCH ESO PRO REC1 PARAM15 VALUE = 'AUTO    ' / Default: 'AUTO'
# HIERARCH ESO PRO REC1 PARAM16 NAME = 'drift_correction_sw' / Drift correction ac
# HIERARCH ESO PRO REC1 PARAM16 VALUE = 'on      ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM17 NAME = 'drift_method_fp' / Method adopted to compu
# HIERARCH ESO PRO REC1 PARAM17 VALUE = 'flux_global_drift_global_sequential_fit'
# HIERARCH ESO PRO REC1 PARAM18 NAME = 'drift_space' / Space to compute drift (pix
# HIERARCH ESO PRO REC1 PARAM18 VALUE = 'pixel   ' / Default: 'pixel'
# HIERARCH ESO PRO REC1 PARAM19 NAME = 'drift_ksigma' / ksigma for computing drift
# HIERARCH ESO PRO REC1 PARAM19 VALUE = '50      ' / Default: 50
# HIERARCH ESO PRO REC1 PARAM20 NAME = 'sky_sub_method' / Method used to subtract
# HIERARCH ESO PRO REC1 PARAM20 VALUE = 'pixel-by-pixel' / Default: 'pixel-by-pixe
# HIERARCH ESO PRO REC1 PARAM21 NAME = 'sky_sub_sliding_box_size' / Sliding box si
# HIERARCH ESO PRO REC1 PARAM21 VALUE = '50      ' / Default: 50
# HIERARCH ESO PRO REC1 PARAM22 NAME = 'slit_loss' / Slit loss in flux calibration
# HIERARCH ESO PRO REC1 PARAM22 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM23 NAME = 'cosmic_detection_sw' / LA Cosmic detection
# HIERARCH ESO PRO REC1 PARAM23 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM24 NAME = 'lacosmic.post-filter-x' / X Size of the po
# HIERARCH ESO PRO REC1 PARAM24 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM25 NAME = 'lacosmic.post-filter-y' / Y Size of the po
# HIERARCH ESO PRO REC1 PARAM25 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM26 NAME = 'lacosmic.post-filter-mode' / Post filterin
# HIERARCH ESO PRO REC1 PARAM26 VALUE = 'dilation' / Default: 'dilation'
# HIERARCH ESO PRO REC1 PARAM27 NAME = 'lacosmic.sigma_lim' / LA Cosmic Poisson fl
# HIERARCH ESO PRO REC1 PARAM27 VALUE = '4       ' / Default: 4
# HIERARCH ESO PRO REC1 PARAM28 NAME = 'lacosmic.f_lim' / LA Cosmic minimum contra
# HIERARCH ESO PRO REC1 PARAM28 VALUE = '4       ' / Default: 4
# HIERARCH ESO PRO REC1 PARAM29 NAME = 'lacosmic.max_iter' / LA Cosmic max number
# HIERARCH ESO PRO REC1 PARAM29 VALUE = '5       ' / Default: 5
# HIERARCH ESO PRO REC1 PARAM30 NAME = 'extra_products_sw' / Set to TRUE to create
# HIERARCH ESO PRO REC1 PARAM30 VALUE = 'false   ' / Default: false
# HIERARCH COM_TAB_START =     0 / Application parameter value
# HIERARCH TNG AG ACQ BKGD = -99999.9 / no comment
# HIERARCH TNG AG ACQ FLUX = -99999.9 / no comment
# HIERARCH TNG AG ACQ POSX = -99999.9 / no comment
# HIERARCH TNG AG ACQ POSY = -99999.9 / no comment
# HIERARCH TNG AG ACQ FWHMX = -99999.9 / no comment
# HIERARCH TNG AG ACQ FWHMY = -99999.9 / no comment
# HIERARCH TNG AG ACQ POSM2 = -99999.9 / no comment
# HIERARCH TNG OBS NAME = 'OB_SOLAR' / no comment
# HIERARCH TNG OBS ID =        1 / no comment
# HIERARCH TNG OBS TARG NAME = 'Sun     ' / no comment
# HIERARCH TNG OBS PI-COI ID = 1 / no comment
# HIERARCH TNG OBS GRP = 'HARPS   ' / no comment
# HIERARCH TNG OBS PI-COI NAME = 'PHILLIPS' / no comment
# HIERARCH TNG OBS PROG ID = 'SOLAR   ' / no comment
# HIERARCH TNG TEL TARG MAG = -26.74 / no comment
# HIERARCH TNG TEL TARG RADVEL = 0.1 / Hard coded for SUN
# HIERARCH TNG TEL TARG EPOCH = 2000. / no comment
# HIERARCH TNG TEL TARG ALPHA = '01h36m40.1381' / Corrected coordinates from astro
# HIERARCH TNG TEL TARG EQUINOX = 2000 / no comment
# HIERARCH TNG TEL TARG SPTYPE = 'G2      ' / no comment
# HIERARCH TNG TEL TARG DELTA = '10:03:42.0808' / Corrected coordinates from astro
# HIERARCH TNG TEL TARG PMA = 0. / no comment
# HIERARCH TNG TEL TARG PMD = 0. / no comment
# HIERARCH TNG INS OPTI1 POS = 'COMB    ' / no comment
# HIERARCH TNG INS MIRR POS = 'BOTH    ' / no comment
# HIERARCH TNG INS DUST ST =   F / no comment
# HIERARCH TNG INS MODE = 'HARPN   ' / no comment
# HIERARCH TNG INS OPTI2 POS = 'FP      ' / no comment
# HIERARCH TNG DET READ GAIN = 1 / no comment
# HIERARCH TNG DET EXP TYPE = 'NORMAL  ' / no comment
# HIERARCH TNG DET READ SPEED = 1 / no comment
# HIERARCH TNG DET READ MODE = 'High, 500kHz' / no comment
# HIERARCH TNG DET READ REG =  0 / no comment
# HIERARCH TNG DET WIN1 UIT1 = 300. / no comment
# HIERARCH TNG DPR TYPE = 'STAR    ' / no comment
# HIERARCH TNG DPR CATG = 'SCIENCE ' / no comment
# HIERARCH TNG DPR TECH = 'ECHELLE ' / no comment
# HIERARCH TNG TPL NAME = 'HARPN_ech_sol_wavesimult' / no comment
# HIERARCH TNG TPL ID = 'HARPN_ech_sol_wavesimult' / no comment
# HIERARCH TNG TPL NEXP =   1000 / no comment
# HIERARCH TNG TPL EXPNO =     4 / no comment
# HIERARCH TNG VTRK TRK ALFAST = -99999.9 / no comment
# HIERARCH TNG VTRK TRK DELAST = -99999.9 / no comment
# HIERARCH TNG VTRK TRK PRMAR = -99999.9 / no comment
# HIERARCH TNG VTRK TRK PRMDE = -99999.9 / no comment
# HIERARCH TNG VTRK TRK PARALL = -99999.9 / no comment
# HIERARCH TNG VTRK TRK AZENC = -99999.9 / no comment
# HIERARCH TNG VTRK TRK ELENC = -99999.9 / no comment
# HIERARCH TNG VTRK GHO STATUS = 'NONE    ' / no comment
# HIERARCH TNG POL HANPO HANPO = '        ' / HANPO folding label position
# HIERARCH TNG POL HANPO RETARDER = '        ' / HANPO retard label position
# HIERARCH TNG POL HANPO RET2POL = '-99999.9' / HANPO polarization angle
# HIERARCH TNG METEO HUMIDITY = -99999.9 / no comment
# HIERARCH TNG METEO PRESSURE = -99999.9 / no comment
# HIERARCH TNG METEO WINDSPEED = -99999.9 / no comment
# HIERARCH TNG METEO WINDDIR = -99999.9 / no comment
# HIERARCH TNG METEO TEMP10M = -99999.9 / no comment
# HIERARCH TNG M1 CH1TEMP = -99999.9 / M1 channel1 temperature
# HIERARCH TNG INS LCU ADC1 = -99999.9 / ADC1 position
# HIERARCH TNG INS LCU ADC2 = -99999.9 / ADC2 position
# HIERARCH TNG EXP_METER_A UIT = 1. / Time per sample (seconds)
# HIERARCH TNG EXP_METER_A EXP CENTROID = 0.4992 / Fractional exposure centroid in
# HIERARCH TNG EXP_METER_A COUNTS MEAN = 94515.47 / Mean counts per second
# HIERARCH TNG EXP_METER_A EXPECTED MEAN = 150000. / Expected mean counts per sec
# HIERARCH TNG EXP_METER_A EFFICENCY MEAN = 0.63 / Efficency of the measured mean
# HIERARCH TNG EXP_METER_A COUNTS MIN = 14. / Minimum counts per second
# HIERARCH TNG EXP_METER_A COUNTS MAX = 96149. / Maximum counts per second
# HIERARCH TNG EXP_METER_A COUNTS STDDEV = 6058.113 / Standard deviation of the co
# HIERARCH TNG EXP_METER_A COUNTS TOTAL = 28395282. / Total number of counts dur
# HIERARCH TNG EXP_METER_B UIT = 1. / Time per sample
# HIERARCH TNG EXP_METER_B EXP CENTROID = 0.4988 / Fractional exposure centroid in
# HIERARCH TNG EXP_METER_B COUNTS MEAN = 7465.312 / Mean counts per second
# HIERARCH TNG EXP_METER_B COUNTS MIN = 2780. / Minimum counts per second
# HIERARCH TNG EXP_METER_B COUNTS MAX = 7692. / Maximum counts per second
# HIERARCH TNG EXP_METER_B COUNTS STDDEV = 309.157 / Standard deviation of the cou
# HIERARCH TNG EXP_METER_B COUNTS TOTAL = 2233760. / Total number of counts durin
# HIERARCH TNG INS DETHDBODY_T MIN = 19.3880004882812 / MIN Detector-Head body b
# HIERARCH TNG INS DETHDBODY_T MAX = 19.3899993896484 / MAX Detector-Head body b
# HIERARCH TNG INS DETHDBODY_T MEAN = 19.3889007568359 / MEAN Detector-Head body
# HIERARCH TNG INS CCDCONTRL_T MIN = -114.98999786377 / MIN Detector Head Heate
# HIERARCH TNG INS CCDCONTRL_T MAX = -114.98999786377 / MAX Detector Head Heate
# HIERARCH TNG INS CCDCONTRL_T MEAN = -114.98999786377 / MEAN Detector Head Hea
# HIERARCH TNG INS CFCSORPUMP_T MIN = -180. / MIN CFC sorption pump temperature
# HIERARCH TNG INS CFCSORPUMP_T MAX = -180. / MAX CFC sorption pump temperature
# HIERARCH TNG INS SPAREIN1_T MEAN = 17.139799118042 / MEAN None
# HIERARCH TNG INS SPARE3_T MIN = 16.6650009155273 / MIN Temperature of Spare #2
# HIERARCH TNG INS SPARE3_T MAX = 16.6790008544922 / MAX Temperature of Spare #2
# HIERARCH TNG INS SPARE3_T MEAN = 16.6743011474609 / MEAN Temperature of Spare
# HIERARCH TNG INS VVOUTCOL_T MIN = 17.5109996795654 / MIN Temperature of Vacuum
# HIERARCH TNG INS VVOUTCOL_T MAX = 17.5429992675781 / MAX Temperature of Vacuum
# HIERARCH TNG INS VVOUTCOL_T MEAN = 17.5291004180908 / MEAN Temperature of Vacuu
# HIERARCH TNG INS EMPTY8_T MIN = 0. / MIN Empty8
# HIERARCH TNG INS EMPTY8_T MAX = 0. / MAX Empty8
# HIERARCH TNG INS EMPTY8_T MEAN = 0. / MEAN Empty8
# HIERARCH TNG INS COLONTOP_T MIN = 16.9619998931885 / MIN Collimator on the top
# HIERARCH TNG INS COLONTOP_T MAX = 16.9689998626709 / MAX Collimator on the top
# HIERARCH TNG INS COLONTOP_T MEAN = 16.9660987854004 / MEAN Collimator on the to
# HIERARCH TNG INS CUHALOGEN_T MIN = 9.13199996948242 / MIN CU Halogen lamp Temp
# HIERARCH TNG INS CUHALOGEN_T MAX = 9.16199970245361 / MAX CU Halogen lamp Temp
# HIERARCH TNG INS CUHALOGEN_T MEAN = 9.144700050354 / MEAN CU Halogen lamp Te
# HIERARCH TNG INS FEUGUIDEC_T MIN = 10.9420003890991 / MIN Guide Camera Tempera
# HIERARCH TNG INS FEUGUIDEC_T MAX = 10.9449996948242 / MAX Guide Camera Tempera
# HIERARCH TNG INS FEUGUIDEC_T MEAN = 10.9433994293213 / MEAN Guide Camera Tempe
# HIERARCH TNG INS VVOUTS4_T MIN = 17.0359992980957 / MIN Temperature of Vacuum
# HIERARCH TNG INS VVOUTS4_T MAX = 17.05299949646 / MAX Temperature of Vacuum
# HIERARCH TNG INS VVOUTS4_T MEAN = 17.0462989807129 / MEAN Temperature of Vacuu
# HIERARCH TNG INS HEADCONTRL_T MIN = 19.5020008087158 / MIN CCD chip control ref
# HIERARCH TNG INS HEADCONTRL_T MAX = 19.5060005187988 / MAX CCD chip control re
# HIERARCH TNG INS HEADCONTRL_T MEAN = 19.5039005279541 / MEAN CCD chip control
# HIERARCH TNG INS FP_P MIN = 0.000349999987520277 / MIN Fabry-Perot pressure
# HIERARCH TNG INS FP_P MAX = 0.00039999998989515 / MAX Fabry-Perot pressure
# HIERARCH TNG INS FP_P MEAN = 0.000354999996488913 / MEAN Fabry-Perot pressure
# HIERARCH TNG INS OPBTOPDET_T MIN = 17.363000869751 / MIN Optical Bench top-De
# HIERARCH TNG INS OPBTOPDET_T MAX = 17.3649997711182 / MAX Optical Bench top-De
# HIERARCH TNG INS OPBTOPDET_T MEAN = 17.3644008636475 / MEAN Optical Bench top-
# HIERARCH TNG INS VVINLEFT_T MIN = 16.8649997711182 / MIN Vacuum vessel insite
# HIERARCH TNG INS VVINLEFT_T MAX = 16.8689994812012 / MAX Vacuum vessel insite
# HIERARCH TNG INS VVINLEFT_T MEAN = 16.8670997619629 / MEAN Vacuum vessel insit
# HIERARCH TNG INS CUCHASSIS_T MIN = 8.76000022888184 / MIN CAL Unit chassis Tem
# HIERARCH TNG INS CUCHASSIS_T MAX = 8.76599979400635 / MAX CAL Unit chassis Tem
# HIERARCH TNG INS CUCHASSIS_T MEAN = 8.76249980926514 / MEAN CAL Unit chassis Te
# HIERARCH TNG INS OPBBOTR_T MIN = 17.3379993438721 / MIN Optical Bench bottom r
# HIERARCH TNG INS OPBBOTR_T MAX = 17.3400001525879 / MAX Optical Bench bottom r
# HIERARCH TNG INS OPBBOTR_T MEAN = 17.3388996124268 / MEAN Optical Bench bottom
# HIERARCH TNG INS EMPTY4_T MIN = 0. / MIN Empty4
# HIERARCH TNG INS EMPTY4_T MAX = 0. / MAX Empty4
# HIERARCH TNG INS EMPTY4_T MEAN = 0. / MEAN Empty4
# HIERARCH TNG INS SPAREIN3_T MIN = 17.1520004272461 / MIN None
# HIERARCH TNG INS SPAREIN3_T MAX = 17.1550006866455 / MAX None
# HIERARCH TNG INS SPAREIN3_T MEAN = 17.153600692749 / MEAN None
# HIERARCH TNG INS CCRATETOP_T MIN = 13.289999961853 / MIN Control rack tempera
# HIERARCH TNG INS CCRATETOP_T MAX = 13.3940000534058 / MAX Control rack tempera
# HIERARCH TNG INS CCRATETOP_T MEAN = 13.3395004272461 / MEAN Control rack tempe
# HIERARCH TNG INS OPBBOTDET_T MIN = 17.3330001831055 / MIN Optical Bench bot-De
# HIERARCH TNG INS OPBBOTDET_T MAX = 17.3349990844727 / MAX Optical Bench bot-De
# HIERARCH TNG INS OPBBOTDET_T MEAN = 17.3337993621826 / MEAN Optical Bench bot-
# HIERARCH TNG INS FEUCHASSIS_T MIN = 25.7749996185303 / MIN Temperature of FEU
# HIERARCH TNG INS FEUCHASSIS_T MAX = 25.7819995880127 / MAX Temperature of FEU
# HIERARCH TNG INS FEUCHASSIS_T MEAN = 25.778299331665 / MEAN Temperature of FE
# HIERARCH TNG INS 3TSEC_T MIN = 17.443000793457 / MIN 3T secondary temperature
# HIERARCH TNG INS 3TSEC_T MAX = 17.4459991455078 / MAX 3T secondary temperature
# HIERARCH TNG INS 3TSEC_T MEAN = 17.4445991516113 / MEAN 3T secondary temperatu
# HIERARCH TNG INS ECHONTOP_T MIN = 17.0090007781982 / MIN Echelle Grating on to
# HIERARCH TNG INS ECHONTOP_T MAX = 17.0130004882812 / MAX Echelle Grating on top
# HIERARCH TNG INS ECHONTOP_T MEAN = 17.0109996795654 / MEAN Echelle Grating on
# HIERARCH TNG INS SPAREIN2_T MIN = 17.2150001525879 / MIN None
# HIERARCH TNG INS SPAREIN2_T MAX = 17.2180004119873 / MAX None
# HIERARCH TNG INS SPAREIN2_T MEAN = 17.2161998748779 / MEAN None
# HIERARCH TNG INS OPBBOTCOL_T MIN = 17.0100002288818 / MIN Optical Bench bot-Co
# HIERARCH TNG INS OPBBOTCOL_T MAX = 17.0179996490479 / MAX Optical Bench bot-Co
# HIERARCH TNG INS OPBBOTCOL_T MEAN = 17.0142993927002 / MEAN Optical Bench bot-
# HIERARCH TNG INS VVINDET_T MIN = 16.7670001983643 / MIN Vacuum vessel insite i
# HIERARCH TNG INS VVINDET_T MAX = 16.7689990997314 / MAX Vacuum vessel insite i
# HIERARCH TNG INS VVINDET_T MEAN = 16.7677001953125 / MEAN Vacuum vessel insite
# HIERARCH TNG INS AIRTHRUGIBFAN4_T MIN = 16.9559993743896 / MIN Temperature of
# HIERARCH TNG INS AIRTHRUGIBFAN4_T MAX = 16.9720001220703 / MAX Temperature of
# HIERARCH TNG INS AIRTHRUGIBFAN4_T MEAN = 16.9636993408203 / MEAN Temperature o
# HIERARCH TNG INS FEUGUIDEF2_T MIN = 10.9040002822876 / MIN Guide filter 2 Temp
# HIERARCH TNG INS FEUGUIDEF2_T MAX = 10.9069995880127 / MAX Guide filter 2 Temp
# HIERARCH TNG INS FEUGUIDEF2_T MEAN = 10.9055004119873 / MEAN Guide filter 2 Te
# HIERARCH TNG INS EMPTY2_T MIN = 0. / MIN Empty2
# HIERARCH TNG INS EMPTY2_T MAX = 0. / MAX Empty2
# HIERARCH TNG INS EMPTY2_T MEAN = 0. / MEAN Empty2
# HIERARCH TNG INS ISCRAMOUTVV_T MIN = 16.8400001525879 / MIN Temperature of Ima
# HIERARCH TNG INS ISCRAMOUTVV_T MAX = 16.8659992218018 / MAX Temperature of Ima
# HIERARCH TNG INS ISCRAMOUTVV_T MEAN = 16.850700378418 / MEAN Temperature of Im
# HIERARCH TNG INS CUCALSEL1_T MIN = 8.73900032043457 / MIN CU CAL selector 1 Te
# HIERARCH TNG INS CUCALSEL1_T MAX = 8.74199962615967 / MAX CU CAL selector 1 Te
# HIERARCH TNG INS CUCALSEL1_T MEAN = 8.74030017852783 / MEAN CU CAL selector 1
# HIERARCH TNG INS VVINRIGHT_T MIN = 16.6720008850098 / MIN Vacuum vessel insite
# HIERARCH TNG INS VVINRIGHT_T MAX = 16.6800003051758 / MAX Vacuum vessel insite
# HIERARCH TNG INS VVINRIGHT_T MEAN = 16.6760997772217 / MEAN Vacuum vessel insi
# HIERARCH TNG INS OPBTOPCOL_T MIN = 16.9710006713867 / MIN Optical Bench top-Col
# HIERARCH TNG INS OPBTOPCOL_T MAX = 16.9759998321533 / MAX Optical Bench top-Col
# HIERARCH TNG INS OPBTOPCOL_T MEAN = 16.9731006622314 / MEAN Optical Bench top-
# HIERARCH TNG INS ISINVV_T MIN = 16.8050003051758 / MIN Image Scrambler inside V
# HIERARCH TNG INS ISINVV_T MAX = 16.8110008239746 / MAX Image Scrambler inside V
# HIERARCH TNG INS ISINVV_T MEAN = 16.808500289917 / MEAN Image Scrambler insid
# HIERARCH TNG INS VVINTOP_T MIN = 16.8360004425049 / MIN Vacuum vessel insite t
# HIERARCH TNG INS VVINTOP_T MAX = 16.8419990539551 / MAX Vacuum vessel insite t
# HIERARCH TNG INS VVINTOP_T MEAN = 16.8390998840332 / MEAN Vacuum vessel insite
# HIERARCH TNG INS FOOTSEC_T MIN = 16.9640007019043 / MIN Vacuum Vessel foot sec
# HIERARCH TNG INS FOOTSEC_T MAX = 16.9659996032715 / MAX Vacuum Vessel foot sec
# HIERARCH TNG INS FOOTSEC_T MEAN = 16.9650001525879 / MEAN Vacuum Vessel foot s
# HIERARCH TNG INS OPBTOPL_T MIN = 17.2070007324219 / MIN Optical Bench top left
# HIERARCH TNG INS OPBTOPL_T MAX = 17.2140007019043 / MAX Optical Bench top left
# HIERARCH TNG INS OPBTOPL_T MEAN = 17.2099990844727 / MEAN Optical Bench top le
# HIERARCH TNG INS 3TCONTRL_T MIN = 17.5030002593994 / MIN 3T control reference
# HIERARCH TNG INS 3TCONTRL_T MAX = 17.5060005187988 / MAX 3T control reference
# HIERARCH TNG INS 3TCONTRL_T MEAN = 17.5044002532959 / MEAN 3T control referenc
# HIERARCH TNG INS FEUADC2_T MIN = 9.70699977874756 / MIN ADC2 Temperature
# HIERARCH TNG INS FEUADC2_T MAX = 9.71500015258789 / MAX ADC2 Temperature
# HIERARCH TNG INS FEUADC2_T MEAN = 9.71179962158203 / MEAN ADC2 Temperature
# HIERARCH TNG INS DETECTOR_P MIN = 0. / MIN Detector Dewar pre
# HIERARCH TNG INS DETECTOR_P MAX = 0. / MAX Detector Dewar pre
# HIERARCH TNG INS DETECTOR_P MEAN = 0. / MEAN Detector Dewar p
# HIERARCH TNG INS CFCCPLATE_T MIN = -161. / MIN CFC cold plate temperature
# HIERARCH TNG INS CFCCPLATE_T MAX = -159. / MAX CFC cold plate temperature
# HIERARCH TNG INS CFCCPLATE_T MEAN = -159.899993896484 / MEAN CFC cold plate te
# HIERARCH TNG INS CCRATEBOT_T MIN = 10.2430000305176 / MIN Control rack tempera
# HIERARCH TNG INS CCRATEBOT_T MAX = 10.3079996109009 / MAX Control rack tempera
# HIERARCH TNG INS CCRATEBOT_T MEAN = 10.2656002044678 / MEAN Control rack tempe
# HIERARCH TNG INS AIRIN3T_T MIN = 16.8479995727539 / MIN Air in 3T Temperature
# HIERARCH TNG INS AIRIN3T_T MAX = 16.8689994812012 / MAX Air in 3T Temperature
# HIERARCH TNG INS AIRIN3T_T MEAN = 16.8595008850098 / MEAN Air in 3T Temperatur
# HIERARCH TNG INS PRIMLINE_P MIN = 26. / MIN Primary pump line pre
# HIERARCH TNG INS PRIMLINE_P MAX = 26. / MAX Primary pump line pre
# HIERARCH TNG INS PRIMLINE_P MEAN = 26. / MEAN Primary pump line p
# HIERARCH TNG INS VVINBOT_T MIN = 16.8920001983643 / MIN Vacuum vessel insite b
# HIERARCH TNG INS VVINBOT_T MAX = 16.8969993591309 / MAX Vacuum vessel insite b
# HIERARCH TNG INS VVINBOT_T MEAN = 16.8944988250732 / MEAN Vacuum vessel insite
# HIERARCH TNG INS EMPTY3_T MIN = 0. / MIN Empty3
# HIERARCH TNG INS EMPTY3_T MAX = 0. / MAX Empty3
# HIERARCH TNG INS EMPTY3_T MEAN = 0. / MEAN Empty3
# HIERARCH TNG INS EMPTY5_T MIN = 0. / MIN Empty5
# HIERARCH TNG INS EMPTY5_T MAX = 0. / MAX Empty5
# HIERARCH TNG INS EMPTY5_T MEAN = 0. / MEAN Empty5
# HIERARCH TNG INS SPAREIN4_T MIN = 17.1889991760254 / MIN None
# HIERARCH TNG INS SPAREIN4_T MAX = 17.1919994354248 / MAX None
# HIERARCH TNG INS SPAREIN4_T MEAN = 17.1902008056641 / MEAN None
# HIERARCH TNG INS FPSEC_T MIN = 21.6529998779297 / MIN Fabry Perot temperature
# HIERARCH TNG INS FPSEC_T MAX = 21.6550006866455 / MAX Fabry Perot temperature
# HIERARCH TNG INS FPSEC_T MEAN = 21.6541996002197 / MEAN Fabry Perot temperatur
# HIERARCH TNG INS VLINE_P MIN = 9.99999974737875E-05 / MIN Pumping line pressure
# HIERARCH TNG INS VLINE_P MAX = 9.99999974737875E-05 / MAX Pumping line pressure
# HIERARCH TNG INS VLINE_P MEAN = 9.99999974737875E-05 / MEAN Pumping line pressur
# HIERARCH TNG INS CUCALSEL2_T MIN = 9.04300022125244 / MIN CU CAL selector 2 Te
# HIERARCH TNG INS CUCALSEL2_T MAX = 9.07400035858154 / MAX CU CAL selector 2 Te
# HIERARCH TNG INS CUCALSEL2_T MEAN = 9.05780029296875 / MEAN CU CAL selector 2
# HIERARCH TNG INS GRISMONEDGE_T MIN = 17.1469993591309 / MIN The Grism on the ed
# HIERARCH TNG INS GRISMONEDGE_T MAX = 17.1539993286133 / MAX The Grism on the e
# HIERARCH TNG INS GRISMONEDGE_T MEAN = 17.1511001586914 / MEAN The Grism on the
# HIERARCH TNG INS DETHDRING_T MIN = 19.5400009155273 / MIN Detector-Head holdin
# HIERARCH TNG INS DETHDRING_T MAX = 19.5429992675781 / MAX Detector-Head holdin
# HIERARCH TNG INS DETHDRING_T MEAN = 19.5410003662109 / MEAN Detector-Head hold
# HIERARCH TNG INS SECLINE_P MIN = 0.000180000002728775 / MIN Secondary pump line
# HIERARCH TNG INS SECLINE_P MAX = 0.000180000002728775 / MAX Secondary pump line
# HIERARCH TNG INS SECLINE_P MEAN = 0.000180000002728775 / MEAN Secondary pump li
# HIERARCH TNG INS AIRIN2T_T MIN = 14.5129995346069 / MIN Air in 2T Temperature
# HIERARCH TNG INS AIRIN2T_T MAX = 14.5240001678467 / MAX Air in 2T Temperature
# HIERARCH TNG INS AIRIN2T_T MEAN = 14.5201997756958 / MEAN Air in 2T Temperatur
# HIERARCH TNG INS VVINCOL_T MIN = 16.8810005187988 / MIN Vacuum vessel insite i
# HIERARCH TNG INS VVINCOL_T MAX = 16.9130001068115 / MAX Vacuum vessel insite i
# HIERARCH TNG INS VVINCOL_T MEAN = 16.8980007171631 / MEAN Vacuum vessel insite
# HIERARCH TNG INS FXHOLD_T MIN = 17.1459999084473 / MIN Fiber exit on square fi
# HIERARCH TNG INS FXHOLD_T MAX = 17.1569995880127 / MAX Fiber exit on square fi
# HIERARCH TNG INS FXHOLD_T MEAN = 17.1523990631104 / MEAN Fiber exit on square
# HIERARCH TNG INS CFCEXHAUST_T MIN = 9. / MIN CFC exhaust gas temperature
# HIERARCH TNG INS CFCEXHAUST_T MAX = 11. / MAX CFC exhaust gas temperature
# HIERARCH TNG INS CFCEXHAUST_T MEAN = 9.80000019073486 / MEAN CFC exhaust gas te
# HIERARCH TNG INS FEUADC1_T MIN = 11.1579999923706 / MIN ADC1 Temperature
# HIERARCH TNG INS FEUADC1_T MAX = 11.1590003967285 / MAX ADC1 Temperature
# HIERARCH TNG INS FEUADC1_T MEAN = 11.1586999893188 / MEAN ADC1 Temperature
# HIERARCH TNG INS OPBTOPR_T MIN = 17.2910003662109 / MIN Optical Bench top righ
# HIERARCH TNG INS OPBTOPR_T MAX = 17.2940006256104 / MAX Optical Bench top righ
# HIERARCH TNG INS OPBTOPR_T MEAN = 17.2927989959717 / MEAN Optical Bench top rig
# HIERARCH TNG INS FEUGUIDEF1_T MIN = 10.9910001754761 / MIN Guide filter 1 Temp
# HIERARCH TNG INS FEUGUIDEF1_T MAX = 10.9949998855591 / MAX Guide filter 1 Temp
# HIERARCH TNG INS FEUGUIDEF1_T MEAN = 10.9927997589111 / MEAN Guide filter 1 Te
# HIERARCH TNG INS OPBBOTL_T MIN = 17.2950000762939 / MIN Optical Bench bottom l
# HIERARCH TNG INS OPBBOTL_T MAX = 17.2970008850098 / MAX Optical Bench bottom l
# HIERARCH TNG INS OPBBOTL_T MEAN = 17.2964000701904 / MEAN Optical Bench bottom
# HIERARCH TNG INS CFCINVV_T MIN = 17.1630001068115 / MIN CFC Inside Vacuum Vess
# HIERARCH TNG INS CFCINVV_T MAX = 17.1650009155273 / MAX CFC Inside Vacuum Vess
# HIERARCH TNG INS CFCINVV_T MEAN = 17.1639003753662 / MEAN CFC Inside Vacuum Ve
# HIERARCH TNG INS INCABSPECTR_T MIN = 21.1879997253418 / MIN Temperature of Vac
# HIERARCH TNG INS INCABSPECTR_T MAX = 21.32200050354 / MAX Temperature of Vac
# HIERARCH TNG INS INCABSPECTR_T MEAN = 21.2721996307373 / MEAN Temperature of V
# HIERARCH TNG INS CFCOUTVV_T MIN = 14.2080001831055 / MIN Temperature of Cryost
# HIERARCH TNG INS CFCOUTVV_T MAX = 14.2309999465942 / MAX Temperature of Cryost
# HIERARCH TNG INS CFCOUTVV_T MEAN = 14.2208003997803 / MEAN Temperature of Cryo
# HIERARCH TNG INS EMPTY6_T MIN = 0. / MIN Empty6
# HIERARCH TNG INS EMPTY6_T MAX = 0. / MAX Empty6
# HIERARCH TNG INS EMPTY6_T MEAN = 0. / MEAN Empty6
# HIERARCH TNG INS PUMP_T MIN = -245.149993896484 / MIN Pumpt or Spare
# HIERARCH TNG INS PUMP_T MAX = -245.149993896484 / MAX Pumpt or Spare
# HIERARCH TNG INS PUMP_T MEAN = -245.149993896484 / MEAN Pumpt or Spare
# HIERARCH TNG INS DCRATETOP_T MIN = 0. / MIN Detector rack temper
# HIERARCH TNG INS DCRATETOP_T MAX = 0. / MAX Detector rack temper
# HIERARCH TNG INS DCRATETOP_T MEAN = 0. / MEAN Detector rack tempe
# HIERARCH TNG INS FPCONTRL_T MIN = 22.0049991607666 / MIN Fabry Perot control tem
# HIERARCH TNG INS FPCONTRL_T MAX = 22.0060005187988 / MAX Fabry Perot control t
# HIERARCH TNG INS FPCONTRL_T MEAN = 22.0051002502441 / MEAN Fabry Perot control
# HIERARCH TNG INS VESSEL_P MIN = 0.000199999994947575 / MIN Vacuum Vessel pressu
# HIERARCH TNG INS VESSEL_P MAX = 0.000199999994947575 / MAX Vacuum Vessel pressu
# HIERARCH TNG INS VESSEL_P MEAN = 0.000199999994947575 / MEAN Vacuum Vessel pres
# HIERARCH PIPELINE MASK TIMESTAMP = '2020-06-23T22:43:06' / Header Mask generatio
# HIERARCH TNG RV STEP =    0.82 / Coordinate increment per pixel
# HIERARCH TNG RV START = -19.58 / Coordinate at reference pixel
# HIERARCH TNG QC EXT0 ROX0 ROY0 BIAS RON = 3.77386734522353 / RON[ADU] for ext 0,
# HIERARCH TNG QC EXT0 ROX1 ROY0 BIAS RON = 3.5759283728064 / RON[ADU] for ext 0,
# HIERARCH TNG QC EXT0 ROX0 ROY0 MAX FLUX = 20903. / Max flux [ADU], raw image
# HIERARCH TNG QC EXT0 ROX1 ROY0 MAX FLUX = 23264. / Max flux [ADU], raw image
# HIERARCH TNG QC SATURATION CHECK = 1 / Saturation [ADU] QC
# HIERARCH TNG QC ORDER1 COSMIC NB = 36 / Cosmics number in the order
# HIERARCH TNG QC ORDER2 COSMIC NB = 694 / Cosmics number in the order
# HIERARCH TNG QC ORDER3 COSMIC NB = 242 / Cosmics number in the order
# HIERARCH TNG QC ORDER4 COSMIC NB = 30 / Cosmics number in the order
# HIERARCH TNG QC ORDER5 COSMIC NB = 3 / Cosmics number in the order
# HIERARCH TNG QC ORDER6 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER7 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER8 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER9 COSMIC NB = 4 / Cosmics number in the order
# HIERARCH TNG QC ORDER10 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER11 COSMIC NB = 6 / Cosmics number in the order
# HIERARCH TNG QC ORDER12 COSMIC NB = 6 / Cosmics number in the order
# HIERARCH TNG QC ORDER13 COSMIC NB = 7 / Cosmics number in the order
# HIERARCH TNG QC ORDER14 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER15 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER16 COSMIC NB = 3 / Cosmics number in the order
# HIERARCH TNG QC ORDER17 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER18 COSMIC NB = 3 / Cosmics number in the order
# HIERARCH TNG QC ORDER19 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER20 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER21 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER22 COSMIC NB = 4 / Cosmics number in the order
# HIERARCH TNG QC ORDER23 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER24 COSMIC NB = 3 / Cosmics number in the order
# HIERARCH TNG QC ORDER25 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER26 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER27 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER28 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER29 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER30 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER31 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER32 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER33 COSMIC NB = 3 / Cosmics number in the order
# HIERARCH TNG QC ORDER34 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER35 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER36 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER37 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER38 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER39 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER40 COSMIC NB = 4 / Cosmics number in the order
# HIERARCH TNG QC ORDER41 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER42 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER43 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER44 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER45 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER46 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER47 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER48 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER49 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER50 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER51 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER52 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER53 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER54 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER55 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER56 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER57 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER58 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER59 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER60 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER61 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER62 COSMIC NB = 1 / Cosmics number in the order
# HIERARCH TNG QC ORDER63 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER64 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER65 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER66 COSMIC NB = 2 / Cosmics number in the order
# HIERARCH TNG QC ORDER67 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER68 COSMIC NB = 0 / Cosmics number in the order
# HIERARCH TNG QC ORDER69 COSMIC NB = 624 / Cosmics number in the order
# HIERARCH TNG QC ORDER1 COSMIC NB2 = 0 / Number of cosmics found in each order (2
# HIERARCH TNG QC ORDER2 COSMIC NB2 = 0 / Number of cosmics found in each order (2
# HIERARCH TNG QC ORDER3 COSMIC NB2 = 0 / Number of cosmics found in each order (2
# HIERARCH TNG QC ORDER4 COSMIC NB2 = 0 / Number of cosmics found in each order (2
# HIERARCH TNG QC ORDER5 COSMIC NB2 = 0 / Number of cosmics found in each order (2
# ...
# HIERARCH TNG QC ORDER55 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER56 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER57 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER58 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER59 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER60 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER61 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER62 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER63 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER64 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER65 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER66 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER67 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER68 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER69 COSMIC NB2 = 0 / Number of cosmics found in each order (
# HIERARCH TNG QC ORDER1 SNR = 65.0962460736599 / SNR in the order
# HIERARCH TNG QC ORDER2 SNR = 63.5230206459385 / SNR in the order
# HIERARCH TNG QC ORDER3 SNR = 71.3577883945455 / SNR in the order
# HIERARCH TNG QC ORDER4 SNR = 65.8549555306361 / SNR in the order
# HIERARCH TNG QC ORDER5 SNR = 103.933295459208 / SNR in the order
# HIERARCH TNG QC ORDER6 SNR = 109.186163057886 / SNR in the order
# HIERARCH TNG QC ORDER7 SNR = 115.074826709732 / SNR in the order
# HIERARCH TNG QC ORDER8 SNR = 115.483856756857 / SNR in the order
# HIERARCH TNG QC ORDER9 SNR = 127.594842506863 / SNR in the order
# HIERARCH TNG QC ORDER10 SNR = 126.290990443019 / SNR in the order
# HIERARCH TNG QC ORDER11 SNR = 146.873884789526 / SNR in the order
# HIERARCH TNG QC ORDER12 SNR = 143.591932165691 / SNR in the order
# HIERARCH TNG QC ORDER13 SNR = 159.024015663061 / SNR in the order
# HIERARCH TNG QC ORDER14 SNR = 140.624477360506 / SNR in the order
# HIERARCH TNG QC ORDER15 SNR = 161.709632427525 / SNR in the order
# HIERARCH TNG QC ORDER16 SNR = 120.16853141009 / SNR in the order
# HIERARCH TNG QC ORDER17 SNR = 133.983741859194 / SNR in the order
# HIERARCH TNG QC ORDER18 SNR = 175.473385254916 / SNR in the order
# HIERARCH TNG QC ORDER19 SNR = 183.015239926668 / SNR in the order
# HIERARCH TNG QC ORDER20 SNR = 188.789560912097 / SNR in the order
# HIERARCH TNG QC ORDER21 SNR = 207.2070369121 / SNR in the order
# HIERARCH TNG QC ORDER22 SNR = 224.728915720313 / SNR in the order
# HIERARCH TNG QC ORDER23 SNR = 224.269620349313 / SNR in the order
# HIERARCH TNG QC ORDER24 SNR = 227.841918046497 / SNR in the order
# HIERARCH TNG QC ORDER25 SNR = 231.65574478916 / SNR in the order
# HIERARCH TNG QC ORDER26 SNR = 246.266973844291 / SNR in the order
# HIERARCH TNG QC ORDER27 SNR = 250.505171001873 / SNR in the order
# HIERARCH TNG QC ORDER28 SNR = 243.592184919818 / SNR in the order
# HIERARCH TNG QC ORDER29 SNR = 262.205604342595 / SNR in the order
# HIERARCH TNG QC ORDER30 SNR = 268.627908805182 / SNR in the order
# HIERARCH TNG QC ORDER31 SNR = 276.197229896827 / SNR in the order
# HIERARCH TNG QC ORDER32 SNR = 250.955948275854 / SNR in the order
# HIERARCH TNG QC ORDER33 SNR = 288.347711343172 / SNR in the order
# HIERARCH TNG QC ORDER34 SNR = 272.86697000781 / SNR in the order
# HIERARCH TNG QC ORDER35 SNR = 297.901774431105 / SNR in the order
# HIERARCH TNG QC ORDER36 SNR = 276.545639782065 / SNR in the order
# HIERARCH TNG QC ORDER37 SNR = 300.306039911327 / SNR in the order
# HIERARCH TNG QC ORDER38 SNR = 280.479001303765 / SNR in the order
# HIERARCH TNG QC ORDER39 SNR = 289.036025514244 / SNR in the order
# HIERARCH TNG QC ORDER40 SNR = 275.431090405805 / SNR in the order
# HIERARCH TNG QC ORDER41 SNR = 313.102063494799 / SNR in the order
# HIERARCH TNG QC ORDER42 SNR = 301.058974404076 / SNR in the order
# HIERARCH TNG QC ORDER43 SNR = 330.059021774897 / SNR in the order
# HIERARCH TNG QC ORDER44 SNR = 325.900503440721 / SNR in the order
# HIERARCH TNG QC ORDER45 SNR = 323.024980550217 / SNR in the order
# HIERARCH TNG QC ORDER46 SNR = 320.240554252797 / SNR in the order
# HIERARCH TNG QC ORDER47 SNR = 327.76938811423 / SNR in the order
# HIERARCH TNG QC ORDER48 SNR = 329.795526790358 / SNR in the order
# HIERARCH TNG QC ORDER49 SNR = 339.342204328676 / SNR in the order
# HIERARCH TNG QC ORDER50 SNR = 336.852965345081 / SNR in the order
# HIERARCH TNG QC ORDER51 SNR = 338.015075014334 / SNR in the order
# HIERARCH TNG QC ORDER52 SNR = 338.895039258638 / SNR in the order
# HIERARCH TNG QC ORDER53 SNR = 345.741889670088 / SNR in the order
# HIERARCH TNG QC ORDER54 SNR = 337.129116168592 / SNR in the order
# HIERARCH TNG QC ORDER55 SNR = 336.082722478952 / SNR in the order
# HIERARCH TNG QC ORDER56 SNR = 335.064695703277 / SNR in the order
# HIERARCH TNG QC ORDER57 SNR = 341.643935584958 / SNR in the order
# HIERARCH TNG QC ORDER58 SNR = 346.869669708227 / SNR in the order
# HIERARCH TNG QC ORDER59 SNR = 345.862867437923 / SNR in the order
# HIERARCH TNG QC ORDER60 SNR = 342.025045807218 / SNR in the order
# HIERARCH TNG QC ORDER61 SNR = 346.033174037605 / SNR in the order
# HIERARCH TNG QC ORDER62 SNR = 350.245890628388 / SNR in the order
# HIERARCH TNG QC ORDER63 SNR = 340.959428723307 / SNR in the order
# HIERARCH TNG QC ORDER64 SNR = 351.32212343168 / SNR in the order
# HIERARCH TNG QC ORDER65 SNR = 349.079298142806 / SNR in the order
# HIERARCH TNG QC ORDER66 SNR = 344.228354779522 / SNR in the order
# HIERARCH TNG QC ORDER67 SNR = 344.679780777683 / SNR in the order
# HIERARCH TNG QC ORDER68 SNR = 342.394773438015 / SNR in the order
# HIERARCH TNG QC ORDER69 SNR = 252.53243005207 / SNR in the order
# HIERARCH TNG QC BERV = -0.116133888416562 / Barycentric correction [km/s]
# HIERARCH TNG QC BJD = 2458224.85707656 / Barycentric Julian date (TDB) [JD]
# HIERARCH TNG QC BERVMAX = 31.9999999532768 / Barycentric max [km/s]
# HIERARCH TNG QC THAR LAMP OFFSET AR = 2.14086580110828 / TH lamp offset AR [m/s]
# HIERARCH TNG QC THAR LAMP OFFSET AR1 = 2.99657625482002 / TH lamp offset AR1 [m/
# HIERARCH TNG QC THAR LAMP OFFSET AR2 = 1.91588925198572 / TH lamp offset AR2 [m/
# HIERARCH TNG QC EXT0 BKGR MEAN = 26.071519199804 / Bkgr mean [e-] in the extensi
# HIERARCH TNG QC EXT0 BKGR MIN = 1.51576239441905 / Bkgr min [e-] in the extensio
# HIERARCH TNG QC EXT0 BKGR MAX = 52.7802293162893 / Bkgr max [e-] in the extensio
# HIERARCH TNG QC DRIFT DET0 FIRST_ORDER = 1 / first order nb on detector 0
# HIERARCH TNG QC DRIFT DET0 LAST_ORDER = 69 / last order nb on detector 0
# HIERARCH TNG QC DRIFT DET0 FLUX_RATIO = 1.00237881523668 / flux ratio for detect
# HIERARCH TNG QC DRIFT DET0 FLUX_RATIO_ERR = 3.25553410256172E-05 / flux ratio er
# HIERARCH TNG QC DRIFT DET0 MEAN = 0.000552249490393283 / mean drift [pxl] for de
# HIERARCH TNG QC DRIFT DET0 MEAN_ERR = 6.68665647122304E-05 / mean drift err [pxl
# HIERARCH TNG QC DRIFT DET0 SLOPE_X = 0. / drift slope along the orders for det 0
# HIERARCH TNG QC DRIFT DET0 SLOPE_X_ERR = 0. / drift slope err for det 0
# HIERARCH TNG QC DRIFT DET0 SLOPE_O = 0. / drift slope across the orders for det
# HIERARCH TNG QC DRIFT DET0 SLOPE_O_ERR = 0. / drift slope err for det 0
# HIERARCH TNG QC DRIFT DET0 CHISQ = 3.6886847675876 / drift fit CHI2 for det 0
# HIERARCH TNG QC DRIFT DET0 REJECTED = 448 / nb of rejected pixels for det 0
# HIERARCH TNG QC SCIRED DRIFT CHI2 CHECK = 1 / SCIRED drift CHI2 QC
# HIERARCH TNG QC SCIRED DRIFT FLUX_RATIO CHECK = 1 / SCIRED drift flux ratio QC
# HIERARCH TNG QC SCIRED DRIFT MEAN CHECK = 1 / SCIRED drift mean QC
# HIERARCH TNG QC SCIRED DRIFT MEAN_ERR CHECK = 1 / SCIRED drift mean error QC
# HIERARCH TNG QC SCIRED DRIFT CHECK = 1 / SCIRED drift QC
# HIERARCH TNG QC ORDER1 FLUX CORR = 0.706350409064962 / Flux corr for the order
# HIERARCH TNG QC ORDER2 FLUX CORR = 0.734471007706589 / Flux corr for the order
# HIERARCH TNG QC ORDER3 FLUX CORR = 0.760088047596783 / Flux corr for the order
# HIERARCH TNG QC ORDER4 FLUX CORR = 0.783327753693817 / Flux corr for the order
# HIERARCH TNG QC ORDER5 FLUX CORR = 0.804317813473872 / Flux corr for the order
# HIERARCH TNG QC ORDER6 FLUX CORR = 0.823187125990085 / Flux corr for the order
# HIERARCH TNG QC ORDER7 FLUX CORR = 0.840065299555871 / Flux corr for the order
# HIERARCH TNG QC ORDER8 FLUX CORR = 0.855082409604453 / Flux corr for the order
# HIERARCH TNG QC ORDER9 FLUX CORR = 0.868368732808584 / Flux corr for the order
# HIERARCH TNG QC ORDER10 FLUX CORR = 0.880054421031359 / Flux corr for the order
# HIERARCH TNG QC ORDER11 FLUX CORR = 0.890269226870116 / Flux corr for the order
# HIERARCH TNG QC ORDER12 FLUX CORR = 0.899142127901554 / Flux corr for the order
# HIERARCH TNG QC ORDER13 FLUX CORR = 0.906800931830167 / Flux corr for the order
# HIERARCH TNG QC ORDER14 FLUX CORR = 0.913371946360439 / Flux corr for the order
# HIERARCH TNG QC ORDER15 FLUX CORR = 0.918979559809468 / Flux corr for the order
# HIERARCH TNG QC ORDER16 FLUX CORR = 0.923745809392489 / Flux corr for the order
# HIERARCH TNG QC ORDER17 FLUX CORR = 0.927789951011954 / Flux corr for the order
# HIERARCH TNG QC ORDER18 FLUX CORR = 0.931228014253984 / Flux corr for the order
# HIERARCH TNG QC ORDER19 FLUX CORR = 0.934172331949682 / Flux corr for the order
# HIERARCH TNG QC ORDER20 FLUX CORR = 0.936731062688832 / Flux corr for the order
# HIERARCH TNG QC ORDER21 FLUX CORR = 0.939007718074588 / Flux corr for the order
# HIERARCH TNG QC ORDER22 FLUX CORR = 0.941100650933755 / Flux corr for the order
# HIERARCH TNG QC ORDER23 FLUX CORR = 0.943102559877023 / Flux corr for the order
# HIERARCH TNG QC ORDER24 FLUX CORR = 0.945099997735188 / Flux corr for the order
# HIERARCH TNG QC ORDER25 FLUX CORR = 0.947172870592301 / Flux corr for the order
# HIERARCH TNG QC ORDER26 FLUX CORR = 0.949393956006645 / Flux corr for the order
# HIERARCH TNG QC ORDER27 FLUX CORR = 0.95182842578004 / Flux corr for the order
# HIERARCH TNG QC ORDER28 FLUX CORR = 0.954533398547305 / Flux corr for the order
# HIERARCH TNG QC ORDER29 FLUX CORR = 0.957557518915348 / Flux corr for the order
# HIERARCH TNG QC ORDER30 FLUX CORR = 0.960940575890543 / Flux corr for the order
# HIERARCH TNG QC ORDER31 FLUX CORR = 0.964713160422171 / Flux corr for the order
# HIERARCH TNG QC ORDER32 FLUX CORR = 0.968896385857345 / Flux corr for the order
# HIERARCH TNG QC ORDER33 FLUX CORR = 0.97350167112991 / Flux corr for the order
# HIERARCH TNG QC ORDER34 FLUX CORR = 0.978530607377245 / Flux corr for the order
# HIERARCH TNG QC ORDER35 FLUX CORR = 0.983974915337456 / Flux corr for the order
# HIERARCH TNG QC ORDER36 FLUX CORR = 0.98981653479332 / Flux corr for the order
# HIERARCH TNG QC ORDER37 FLUX CORR = 0.996027832349 / Flux corr for the order
# HIERARCH TNG QC ORDER38 FLUX CORR = 1.00257194579211 / Flux corr for the order
# HIERARCH TNG QC ORDER39 FLUX CORR = 1.00940328391476 / Flux corr for the order
# HIERARCH TNG QC ORDER40 FLUX CORR = 1.01646822133328 / Flux corr for the order
# HIERARCH TNG QC ORDER41 FLUX CORR = 1.02370600442485 / Flux corr for the order
# HIERARCH TNG QC ORDER42 FLUX CORR = 1.03104989935522 / Flux corr for the order
# HIERARCH TNG QC ORDER43 FLUX CORR = 1.03842857944095 / Flux corr for the order
# HIERARCH TNG QC ORDER44 FLUX CORR = 1.04576774416518 / Flux corr for the order
# HIERARCH TNG QC ORDER45 FLUX CORR = 1.05299208396241 / Flux corr for the order
# HIERARCH TNG QC ORDER46 FLUX CORR = 1.06002756969336 / Flux corr for the order
# HIERARCH TNG QC ORDER47 FLUX CORR = 1.06680401212174 / Flux corr for the order
# HIERARCH TNG QC ORDER48 FLUX CORR = 1.07325797185079 / Flux corr for the order
# HIERARCH TNG QC ORDER49 FLUX CORR = 1.07933607009193 / Flux corr for the order
# HIERARCH TNG QC ORDER50 FLUX CORR = 1.08499855571603 / Flux corr for the order
# HIERARCH TNG QC ORDER51 FLUX CORR = 1.09022320896902 / Flux corr for the order
# HIERARCH TNG QC ORDER52 FLUX CORR = 1.09500958882539 / Flux corr for the order
# HIERARCH TNG QC ORDER53 FLUX CORR = 1.0993834893321 / Flux corr for the order
# HIERARCH TNG QC ORDER54 FLUX CORR = 1.10340144996336 / Flux corr for the order
# HIERARCH TNG QC ORDER55 FLUX CORR = 1.10715537085737 / Flux corr for the order
# HIERARCH TNG QC ORDER56 FLUX CORR = 1.11077701955568 / Flux corr for the order
# HIERARCH TNG QC ORDER57 FLUX CORR = 1.11444208542935 / Flux corr for the order
# HIERARCH TNG QC ORDER58 FLUX CORR = 1.11837359600679 / Flux corr for the order
# HIERARCH TNG QC ORDER59 FLUX CORR = 1.12284429701373 / Flux corr for the order
# HIERARCH TNG QC ORDER60 FLUX CORR = 1.12817745972501 / Flux corr for the order
# HIERARCH TNG QC ORDER61 FLUX CORR = 1.13474552298692 / Flux corr for the order
# HIERARCH TNG QC ORDER62 FLUX CORR = 1.14296566580506 / Flux corr for the order
# HIERARCH TNG QC ORDER63 FLUX CORR = 1.15329133115443 / Flux corr for the order
# HIERARCH TNG QC ORDER64 FLUX CORR = 1.16619825140202 / Flux corr for the order
# HIERARCH TNG QC ORDER65 FLUX CORR = 1.18216377092568 / Flux corr for the order
# HIERARCH TNG QC ORDER66 FLUX CORR = 1.20163651980022 / Flux corr for the order
# HIERARCH TNG QC ORDER67 FLUX CORR = 1.22499502600988 / Flux corr for the order
# HIERARCH TNG QC ORDER68 FLUX CORR = 1.2524903590604 / Flux corr for the order
# HIERARCH TNG QC ORDER69 FLUX CORR = 1.28417128309366 / Flux corr for the order
# HIERARCH TNG QC FLUX CORR MIN = 0.706350409064962 / Min of flux correction
# HIERARCH TNG QC FLUX CORR MAX = 1.28417128309366 / Max of flux correction
# HIERARCH TNG QC SCIRED FLUX CORR CHECK = 1 / Flux correction QC
# HIERARCH TNG QC CCF RV = 0.093380554958549 / Radial velocity [km/s]
# HIERARCH TNG QC CCF RV ERROR = 0.000273535800989133 / Uncertainty on radial velo
# HIERARCH TNG QC CCF FWHM = 7.03480002987557 / CCF FWHM [km/s]
# HIERARCH TNG QC CCF FWHM ERROR = 0.000547071601978265 / Uncertainty on CCF FWHM
# HIERARCH TNG QC CCF CONTRAST = 56.9217522572806 / CCF contrast %
# HIERARCH TNG QC CCF CONTRAST ERROR = 0.00442660403459276 / CCF contrast error %
# HIERARCH TNG QC CCF CONTINUUM = 142989857.765784 / CCF continuum level [e-]
# HIERARCH TNG QC CCF MASK = 'G2      ' / CCF mask used
# HIERARCH TNG QC CCF FLUX ASYMMETRY = 0.0230823633333285 / CCF asymmetry (km/s)
# HIERARCH TNG QC CCF FLUX ASYMMETRY ERROR = 0.000418179324935964 / CCF asymmetry
# HIERARCH TNG QC CCF BIS SPAN = -0.066624290471054 / CCF bisector span (km/s)
# HIERARCH TNG QC CCF BIS SPAN ERROR = 0.000547071601978265 / CCF bisector span er
# HIERARCH TNG QC SCIRED CHECK = 1 / SCIRED global QC
# CHECKSUM= 'GC7AJ952GA59G959'   / HDU checksum updated 2021-07-23T11:21:57
# DATASUM = '         0'         / data unit checksum updated 2021-07-23T11:21:57

# %%
plt.plot(df["bjd"], df["rvraw"], ".")
plt.plot(bjd_list, DRS_new_vrad_list, ".")
plt.plot(df["bjd"], df["rvheli"]*0.01+0.1, ".")

# %%
len(DRS_new_vrad_list)

#Save loaded data as NPZ files

outfile = 'HARPS2_3_1.npz'#TemporaryFile()#"test_savez_file"

np.savez(outfile, bjd_list=bjd_list, DRS_new_vrad_list=DRS_new_vrad_list, DRS_new_berv_list=DRS_new_berv_list)

# %%
npzfile = np.load(outfile)
npzfile.files
# Out:
# ['bjd_list', 'DRS_new_vrad_list', 'DRS_new_berv_list']

# %%
fig, ax = plt.subplots(3,1, figsize=(10, 10))
ax[0].plot(bjd_list,DRS_new_vrad_list-np.mean(DRS_new_vrad_list), ".", label="vrad_raw")
ax[1].plot(bjd_list,DRS_new_berv_list-np.mean(DRS_new_berv_list), ".", label="berv")
ax[2].plot(bjd_list,np.array(DRS_new_berv_list)-DRS_new_vrad_list, ".", label="berv - vrad_raw")



for i in [0,1,2]:
    ax[i].legend(loc="upper right")
    ax[i].set_ylim(-1, 1)

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
plt.plot(np.array(bjd_list)-24000,DRS_new_berv_list-np.mean(DRS_new_berv_list), ".", label="berv")
ax.legend()

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))
plt.plot(bjd_list,DRS_new_vrad_list-np.mean(DRS_new_vrad_list), ".", label="vrad")
ax.legend()

# %%
np.max(bjd_list)-np.min(bjd_list)
# Out:
# 780.6867202799767

# %%
missing_dates = []
full_bjd_list = []
qflag_bjd_list_diff = []
removed_counter = 0
qflag_removed_counter = 0
ccf_counter = 0
gen_counter = 0
#fig, ax = plt.subplots(figsize=(10, 7))
#fig3, ax3 = plt.subplots(figsize=(10, 7))

for directory in directories:
    #print(directory)
    if directory == '.DS_Store':
        continue
    files = os.listdir(str('hpcstorage'+str(year)+'/buchschn/HARPN/reduced/'+directory))
    
    #fig, ax = plt.subplots(figsize=(10, 7))
    bjd_list =[]
    ccf_list = []
    DRS_qflag_list = []
    DRS_new_fwhm_list = []
    DRS_new_contrast_list = []
    DRS_new_vrad_list = []
    DRS_new_berv_list = []
    DRS_vrad_raw_list = []
    DRS_new_bis_span_list = []
    
    DRS_new_sig_vrad_list = []
    DRS_new_sig_fwhm_list = []
    DRS_new_sig_contrast_list = []
    DRS_new_sig_bis_span_list = []
    
    DRS_weight_new_sig_vrad_list = []
    DRS_weight_new_sig_fwhm_list = []
    DRS_weight_new_sig_contrast_list = []
    DRS_weight_new_sig_bis_span_list = []
    
    rv_axis = np.linspace(-20,20, 161)
    for file in files:
        #print(file)
        ccf_counter += 1
        hdul = fits.open(str('hpcstorage'+str(year)+'/buchschn/HARPN/reduced/'+directory+"/"+file), memmap=False)
        ccf = hdul[1].data[69]
        bjd = hdul[0].header["HIERARCH TNG QC BJD"]
        
        new_bjd_list = pd.Index(df['bjd'])
        i = new_bjd_list.get_loc(bjd, method = "nearest")
        #print(np.abs(df['new_bjd'][i]))
        
        # Check that the BJD is within 10 seconds (0.000115741 days)
        if (np.abs(df['bjd'][i]-bjd)) > 0.000115741:
            #print("the difference in BJD is more than 10 seconds for BJD: "+str(bjd))
            removed_counter +=1
            continue
        
        DRS_new_vrad= hdul[0].header['HIERARCH TNG QC CCF RV'] #df['new_vrad'][i]
        DRS_new_berv= hdul[0].header['HIERARCH TNG QC BERV'] #df['new_berv'][i]
        #DRS_vrad_raw= df['new_vrad_raw'][i]
        DRS_new_sig_vrad = df["HIERARCH TNG QC CCF RV ERROR"][i]
        DRS_weight_new_sig_vrad = 1/(DRS_new_sig_vrad)**2
        DRS_new_fwhm = df["new_fwhm"][i]
        DRS_new_sig_fwhm = df["new_sig_fwhm"][i]
        DRS_weight_new_sig_fwhm = 1/ (DRS_new_sig_fwhm)**2
        DRS_new_contrast = df["new_contrast"][i]
        DRS_new_sig_contrast = df["new_sig_contrast"][i]
        DRS_weight_new_sig_contrast = 1/(DRS_new_sig_contrast)**2
        DRS_new_bis_span = df["new_bis_span"][i]
        DRS_new_sig_bis_span = df["new_sig_bis_span"][i]
        DRS_weight_new_sig_bis_span = 1/(DRS_new_sig_bis_span)**2
        #ax.plot(rv_axis,ccf, color= 'b')
        
        qflag_bjd = bjd- 2400000
        qflag_list = pd.Index(df['BJD'])
        q_index = qflag_list.get_loc(qflag_bjd, method = "nearest")
        qflag_bjd_diff = np.abs(df['BJD'][q_index]-qflag_bjd)
        
        # extract values from DRS and weights
        DRS_qflag = df["quality"][q_index]
        if qflag_bjd_diff > 0.00081 or DRS_qflag <0.99:
            #print("the difference in BJD is more than 10 seconds for BJD: "+str(bjd))
            qflag_removed_counter += 1
            continue
        qflag_bjd_list_diff.append(qflag_bjd_diff)
        ccf_list.append(ccf)
        bjd_list.append(bjd)
        full_bjd_list.append(bjd)
        
        # append values from DRS
        DRS_qflag_list.append(DRS_qflag)
        DRS_new_fwhm_list.append(DRS_new_fwhm)
        DRS_new_contrast_list.append(DRS_new_contrast)
        DRS_new_vrad_list.append(DRS_new_vrad)
        DRS_new_berv_list.append(DRS_new_berv)
        DRS_vrad_raw_list.append(DRS_vrad_raw)
        DRS_new_bis_span_list.append(DRS_new_bis_span)
        
        # append sig from DRS
        DRS_new_sig_vrad_list.append(DRS_new_sig_vrad)
        DRS_new_sig_fwhm_list.append(DRS_new_sig_fwhm)
        DRS_new_sig_contrast_list.append(DRS_new_sig_contrast)
        DRS_new_sig_bis_span_list.append(DRS_new_sig_bis_span)
        
        # append weights from DRS
        DRS_weight_new_sig_vrad_list.append(DRS_weight_new_sig_vrad)
        DRS_weight_new_sig_fwhm_list.append(DRS_weight_new_sig_fwhm)
        DRS_weight_new_sig_contrast_list.append(DRS_weight_new_sig_contrast)
        DRS_weight_new_sig_bis_span_list.append(DRS_weight_new_sig_bis_span)
        
        #print("  - - - ")
    if not ccf_list:
        #print("There are no DRS RVs on "+str(directory))
        print(str(directory))
        missing_dates.append(directory)
        continue
    # take the (weighted) averages for that day of observations
    mean_ccf = np.mean(ccf_list, axis=0)
    median_DRS_qflag = np.mean(DRS_qflag_list)
    median_DRS_new_fwhm = np.average(DRS_new_fwhm_list, weights = DRS_weight_new_sig_fwhm_list)
    median_DRS_new_contrast = np.average(DRS_new_contrast_list, weights = DRS_weight_new_sig_contrast_list)
    median_DRS_new_vrad = np.average(DRS_new_vrad_list, weights=DRS_weight_new_sig_vrad_list)
    median_DRS_new_berv = np.mean(DRS_new_berv_list) #no weights exist
    median_DRS_vrad_raw = np.mean(DRS_vrad_raw_list) #no weights exist
    median_DRS_new_bis_span = np.average(DRS_new_bis_span_list, weights= DRS_weight_new_sig_bis_span_list)
    median_bjd = np.mean(bjd_list)
    #ax.plot(rv_axis,ccf, label = "all ccf's", color= 'b')
    #ax.plot(rv_axis,mean_ccf, label = "mean ccf, "+str(median_bjd), color= 'r')
    #ax.set_xlabel("RV (m/s)", size =15)
    #ax.set_ylabel("CCF", size =15)
    #ax.legend()

    #print(median_bjd)
    #print(median_DRS_new_vrad)
    
    #fig2, ax2 = plt.subplots(figsize=(10, 7))
    x_mean = [median_DRS_new_vrad]*len(DRS_new_vrad_list)
    #ax2.scatter(bjd_list,DRS_new_vrad_list, label = "all rv's", color='b')
    #ax2.plot(bjd_list,x_mean, label = "mean rv", color = 'r')
    #ax2.set_xlabel("BJD", size =15)
    #ax2.set_ylabel("DRS RV", size =15)
    #ax2.legend()
    
    # Normalize the CCF
    rv_data = np.linspace(-20, 20, 161)
    x = np.where(abs(rv_data) > 10)
    non_peak = mean_ccf[x]
    p3guess = np.median(non_peak)
    #p_guess = [-np.min(mean_ccf)+p3guess, 0., 3, p3guess]
    #pfit, results = mpyfit.fit(least, p_guess, (rv_axis, mean_ccf), parinfo)
    #A = pfit[0]
    #C = pfit[3]
    #print(pfit)
    #print(C)
    normalized_ccf =(mean_ccf/p3guess)
    #gauss_guess = -p_guess[0] * np.exp(-(rv_axis - p_guess[1]) ** 2 / (2. * p_guess[2] ** 2)) + p_guess[3]
    #gauss_fit = -pfit[0] * np.exp(-(rv_axis - pfit[1]) ** 2 / (2. * pfit[2] ** 2)) + pfit[3]
    #ax.plot(rv_axis,gauss_fit,label = "gauss fit")
    #ax.plot(rv_axis,gauss_guess,label = "gauss guess")
    #ax.legend()
    #ax3.plot(rv_axis,normalized_ccf)
    
    
    # Write CCF, BJD, and RV to a fits file
    hdu_new = fits.ImageHDU()
    hdr = fits.Header()
    primary_hdu = fits.PrimaryHDU(header=hdr)
    hdul = fits.HDUList([primary_hdu, hdu_new])
    
    #creates columns in CCF.fits files
    #col1 = fits.Column(name='CCF data', format='E', array=normalized_ccf)
    
    hdu = fits.PrimaryHDU(normalized_ccf)
    hdulist = fits.HDUList([hdu])
    
    # Set header
    hdulist[0].header.set("qflag", median_DRS_qflag,'RV [km/s]')
    hdulist[0].header.set("fwhm", median_DRS_new_fwhm,'FWHM [km/s]')
    hdulist[0].header.set("contrast", median_DRS_new_contrast,'contrast')
    hdulist[0].header.set("bis_span", median_DRS_new_bis_span,'bis span [km/s]')
    hdulist[0].header.set('rvh', median_DRS_new_vrad, 'RV [km/s]')
    hdulist[0].header.set('berv', median_DRS_new_berv, 'RV [km/s]')
    hdulist[0].header.set("vradraw", median_DRS_vrad_raw,'RV [km/s]')
    hdulist[0].header.set("BJD", median_bjd, 'Barycentric JD (from DRS)')
                          
    # check whether folder exists. If not, make it
    CCF_folder_outputs = 'fits/fits_'+str(year)
    if not os.path.exists(CCF_folder_outputs):
        os.mkdir(CCF_folder_outputs)
    
    # write and close hdul
    #hdulist.writeto('fits/fits_'+str(year)+'/ccf' +directory+'.fits')
    hdulist.close()
    gen_counter +=1
    if gen_counter%50==0:
        print(gen_counter)
    #print("_______")
    #if directory == "2020-02-06":
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-d615b8aec0dc> in <module>
#      13     if directory == '.DS_Store':
#      14         continue
# ---> 15     files = os.listdir(str('hpcstorage'+str(year)+'/buchschn/HARPN/reduced/'+directory))
#      16
#      17     #fig, ax = plt.subplots(figsize=(10, 7))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hpcstorage2015/buchschn/HARPN/reduced/2015-12-19'

# %%
#2015: 4376 - 91 = 4,285
#2016: 13458 -110 = 13,348
# 2017: 10635 - 2,346 = 8,289
# 2018: 12469 - 2,836 = 9,633


#2015: 91/4376 = 0.02
#2016: 110/13458 = 0.0008
#2017: 2,346/10,635 = 0.220
#2018: 2,836/12469 =0.227
ccf_counter
# Out:
# 12469

# %%
qflag_removed_counter
# Out:
# 2836

# %%
rv_data = np.linspace(-20, 20, 161)
x = np.where(abs(rv_data) > 10)

# %%
plt.plot(mean_ccf[x])

# %%
2457328.0335699-2400000

# %%
np.mean(qflag_bjd_list_diff)

# %%
np.min(full_bjd_list)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.scatter(np.array(full_bjd_list)-2400000, qflag_bjd_list_diff)
ax.set_ylabel("Offset between BJD (Days)", size = 12)
ax.set_xlabel("BJD from TNG Header", size = 12)
ax.set_ylim(0.00076, 0.00082)

# %%
qflag_removed_counter

# %%
ccf_counter

# %%
hdul[0].header["HIERARCH TNG QC CCF RV"]

# %%
hdul[0].header["HIERARCH TNG QC BERV"]

# %%
sorted(missing_dates)
for i in sorted(missing_dates):
    print(i)

# %%
removed_counter

# %%
import julian
import datetime

# %%
files = os.listdir("fits_"+str(year)+"/")

# %%
mu_fits = []
bjd_list = []
berv_list = []
rv_list = []
vradraw_list = []
CCF_data_list = []
files_list = []

# %%
# Check contents to see whether Jupiter is removed or not??
year = "2015"

files = os.listdir("fits/fits_"+str(year)+"/")
for file in sorted(files):
    if file == ".DS_Store":
        continue
    print(file)
    files_list.append(file)
    hdul2 = fits.open(str("fits/fits_"+str(year)+"/"+file), memmap=False)
    bjd_test = hdul2[0].header["BJD"]
    bjd_list.append(bjd_test-2400000)
    rv = hdul2[0].header["rvh"]
    rv_list.append(rv)
    berv = hdul2[0].header["berv"]
    berv_list.append(berv)
    vradraw = hdul2[0].header["vradraw"]
    vradraw_list.append(vradraw)
    CCF_data = hdul2[0].data
    CCF_data_list.append(CCF_data)
    
    # Plot ccf_data
    plt.plot(CCF_data)
    
    #fit ccf_data
    rv_axis = np.linspace(-20, 20, 161)
    p_guess = [1, 0.1, 1., 0.5]
    pfit, results = mpyfit.fit(least, p_guess, (rv_axis, CCF_data), parinfo)
    mu = pfit[1]
    mu_fits.append(mu)
    
    print(bjd_test)
    date= julian.from_jd(bjd_test-2400000, fmt='mjd')
    print(date)
    print("_______")

# %%
hdul2[0].header

# %%
(np.max(berv_list)-np.min(berv_list))/(np.max(mu_fits)-np.min(mu_fits))

# %%
# plot mu fits over time to figure out whether jupiter was removed from CCFs

fig, ax = plt.subplots(figsize=(10, 7))
ax.scatter(bjd_list, mu_fits)
#ax.set_xlim(2457391.0619573, 2457716.93670025)
ax.set_xlabel("BJD", size= 16)
ax.set_ylabel("mu fit to ccfs", size= 16)

# %%
# plot mu fits over time to figure out whether jupiter was removed from CCFs

fig, ax = plt.subplots(figsize=(10, 7))
ax.scatter(bjd_list, berv_list, label="berv from DRS")
#ax.scatter(bjd_list, mu_fits, label = "mu fits")
#ax.set_xlim(2457391.0619573, 2457716.93670025)
ax.set_xlabel("BJD", size= 16)
ax.set_ylabel("berv_list to ccfs", size= 16)
ax.legend()

# %%
# plot v_rad_raw fits over time to figure out whether jupiter was removed from CCFs

fig, ax = plt.subplots(figsize=(10, 7))
ax.scatter(bjd_list, vradraw_list, label="vradraw from DRS")
ax.scatter(bjd_list, mu_fits, label="mu fits")
#ax.scatter(bjd_list, mu_fits, label = "mu fits")
#ax.set_xlim(2457391.0619573, 2457716.93670025)
ax.set_xlabel("BJD", size= 16)
ax.set_ylabel("berv_list to ccfs", size= 16)
ax.legend()

# %% [markdown]
# ## Removing jupiter and shifting to zero

# %%
coeff_list= []
number_of_iterations_list = []
mu_og_list = []
mu_jup_list = []
mu_zero_list = []
BJD_list = []
shifted_CCF_list = []

mu_fits = []
berv_list = []
rv_list = []
vradraw_list = []
CCF_data_list = []
files_list = []

# %%
def gauss(x, p):
    return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[
#        -9.13297446, -9.13298112, -9.13298163, -9.13298589, -9.13298942,
#        -9.13299288, -9.1330006 , -9.13300405, -9.13300779, -9.1330119 ,
#        -9.1330152 , -9.13301856, -9.13302304, -9.13302633, -9.13303316,
#        -9.13303383, -9.13305175, -9.13305239, -9.13305983, -9.13306345,
#        -9.13306759, -9.13307118, -9.13307413, -9.13308559, -9.13309265,
#        -9.1330927 , -9.13310142, -9.13310455, -9.13310817, -9.13311169,
#        -9.13311588, -9.13311916, -9.13312302, -9.13312708, -9.1331304 ,
#        -9.13313391, -9.13314093, -9.13314148, -9.13314524, -9.13316035,
#        -9.13316748, -9.13317505, -9.13317855, -9.13319709, -9.13321602,
#        -9.13321954, -9.13322702, -9.13323066, -9.13325679])

# %%
# Shift all files to zero and remove jupiter
year = "2015"

#fig, ax = plt.subplots(figsize=(10, 7))

files = os.listdir("fits/fits_"+str(year)+"/")
for file in sorted(files):
    if file == ".DS_Store":
        continue
    #print(file)
    files_list.append(file)
    hdul2 = fits.open(str("fits/fits_"+str(year)+"/"+file), memmap=False)
    headr = getheader(str("fits/fits_"+str(year)+"/"+file), memmap=False)
    # Extract properties from the header
    median_bjd = hdul2[0].header["BJD"]
    BJD_list.append(median_bjd-2400000)
    
    # Extract properties from observation
    median_DRS_qflag = hdul2[0].header["qflag"]
    median_DRS_new_fwhm = hdul2[0].header["fwhm"]
    median_DRS_new_contrast = hdul2[0].header["contrast"]
    median_DRS_new_bis_span = hdul2[0].header["bis_span"]
    median_DRS_new_berv = hdul2[0].header["berv"]
    
    # extracts the CCF data and rv from fits
    CCF_data = hdul2[0].data
    CCF_data_list.append(CCF_data)
    berv = hdul2[0].header["berv"]
    berv_list.append(berv)
    vradraw = hdul2[0].header["vradraw"]
    vradraw_list.append(vradraw)
    rv = hdul2[0].header["rvh"] -(m_slope*(median_bjd)+b_offset)
    rv_list.append(rv)
    jupiter_shift = vradraw-rv
    #ax.plot(rv_data, CCF_data, label = "original")
    
    # no_shift fit
    rv_data = np.linspace(-20, 20, 161)
    x = np.where(abs(rv_data) > 10)
    non_peak = CCF_data[x]
    median_non_peak= np.median(non_peak)
    
    parinfo = [{'fixed': False, 'step': 1e-3*median_non_peak},
               {'fixed': False, 'step': 1*median_non_peak},
               {'fixed': False, 'step': 1e-3},
               {'fixed': False, 'step': 1e-3*median_non_peak},
               {'fixed': False, 'step': 1e-3*median_non_peak},
               {'fixed': False, 'step': 1e-3*median_non_peak}]
    
    p_no_shifted = [-0.5*median_non_peak, -0.5, 3.5, 1*median_non_peak, 1e-3*median_non_peak, 1e-3*median_non_peak]
    pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_data, CCF_data), parinfo)
    mu_og = pfit_no_shift[1]
    mu_og_list.append(mu_og)
    
    # Jupiter shift
    rv_data = np.linspace(-20, 20, 161)
    rv_data_jupiter_shift = rv_data - jupiter_shift # minus sign
    f_jup = interp1d(rv_data_jupiter_shift, CCF_data, kind='cubic', fill_value='extrapolate')
    jupiter_shifted_CCF_data = f_jup(rv_data)
    #ax.plot(rv_data, jupiter_shifted_CCF_data, label = "jupiter shifted")
    
    # fits the shifted by jupiter data
    p_shifted_jup = [-0.5*median_non_peak, -0.5, 3.5 +jupiter_shift, 1*median_non_peak, 1e-3*median_non_peak, 1e-3*median_non_peak]
    pfit_jup, results_jup = mpyfit.fit(least, p_shifted_jup, (rv_data, jupiter_shifted_CCF_data), parinfo)

    num_iters = results_jup["niter"]
    number_of_iterations_list.append(num_iters)
    coeff_list.append(pfit_jup)
    m = pfit_jup[1]
    mu_jup_list.append(m)
    
    # Shift to zero, after jupiter shift
    shift_to_zero = -rv
    rv_data_shifted = rv_data + shift_to_zero + 0.10001953299548397 - 0.014550377629497218

    f = interp1d(rv_data_shifted, jupiter_shifted_CCF_data, kind='cubic', fill_value='extrapolate')
    shifted_CCF_data = f(rv_data)
    shifted_CCF_list.append(shifted_CCF_data)
    #ax.plot(rv_data, shifted_CCF_data, label = "shifted to zero")
    #ax.set_xlim(-3,3)
    #ax.set_ylim(0.35,0.65)
    #ax.legend()
    
    # fits the shifted data
    p_shifted = [-0.5*median_non_peak, -0.5, 3.5 + shift_to_zero, 1*median_non_peak, 1e-3*median_non_peak, 1e-3*median_non_peak]
    pfit, results = mpyfit.fit(least, p_shifted, (rv_data, shifted_CCF_data), parinfo)
    m_zero = pfit[1]
    mu_zero_list.append(m_zero)#-0.1)

    # finds center of mass
    center_of_mass = np.sum((1-CCF_data)*rv_data)/(np.sum(1-CCF_data))

    #creates columns in CCF.fits files
    col1 = fits.Column(name='RV data', format='E', array=rv_data)
    col2 = fits.Column(name='Shifted CCF data', format='E', array=shifted_CCF_data)
    cols = fits.ColDefs([col1, col2])

    # Combines fits files
    tbhdu = fits.BinTableHDU.from_columns(cols)
    hdu_new = fits.ImageHDU(header=headr)
    hdr = fits.Header()
    primary_hdu = fits.PrimaryHDU(header=hdr)
    hdul = fits.HDUList([primary_hdu, hdu_new])
    hdul.append(tbhdu)
    
    # add new parameters
    hdul[0].header.set('label', rv, 'RV [km/s]')
    #hdul[0].header.set('CENTMASS', center_of_mass, 'center of mass [km/s]')      
    hdul[0].header.set('INSTRMNT', rv, 'HARPS-N')
    hdul[0].header.set("BJD", median_bjd, 'Barycentric JD (from DRS)')
    hdul[0].header.set('MU_og', mu_og, 'km/s')
    hdul[0].header.set('MU_jup', m, 'km/s')
    hdul[0].header.set('MU_zero', m_zero, 'km/s')
    hdul[0].header.set('N_iters', num_iters, 'iterations for fit')
    hdul[0].header.set('Amp', pfit[0], 'coefficient for fit')
    hdul[0].header.set('sigma', pfit[2], 'coefficient for fit')
    hdul[0].header.set('offset', pfit[3], 'coefficient for fit')
                
    #Add old header
    # Set header
    hdul[0].header.set("qflag", median_DRS_qflag,'RV [km/s]')
    hdul[0].header.set("fwhm", median_DRS_new_fwhm,'FWHM [km/s]')
    hdul[0].header.set("contrast", median_DRS_new_contrast,'contrast')
    hdul[0].header.set("bis_span", median_DRS_new_bis_span,'bis span [km/s]')
    hdul[0].header.set('rvh', rv, 'RV [km/s]')
    hdul[0].header.set('berv', median_DRS_new_berv, 'RV [km/s]')
    hdul[0].header.set("vradraw", vradraw,'RV [km/s]')
    hdul[0].header.set("BJD", median_bjd, 'Barycentric JD (from DRS)')
                
    # check whether folder exists. If not, make it
    CCF_folder_outputs = 'shifted_fits_slope/shifted_fits_'+str(year)
    if not os.path.exists(CCF_folder_outputs):
        os.mkdir(CCF_folder_outputs)

    hdul.append(tbhdu)
    print(CCF_folder_outputs +'/'+file+'.fits')

    hdul.writeto(CCF_folder_outputs +'/'+file)
    hdul.close()
# Out:
# shifted_fits_slope/shifted_fits_2015/ccf2015-07-20.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-07-29.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-07-30.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-07-31.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-01.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-02.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-03.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-04.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-05.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-07.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-10.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-16.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-17.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-18.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-19.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-20.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-21.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-22.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-24.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-25.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-26.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-27.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-28.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-29.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-30.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-08-31.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-01.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-02.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-03.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-04.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-05.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-06.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-07.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-08.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-09.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-10.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-11.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-12.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-13.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-14.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-15.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-16.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-17.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-19.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-20.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-26.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-27.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-28.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-09-29.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-05.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-06.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-07.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-08.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-10.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-11.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-12.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-26.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-28.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-29.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-10-30.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-01.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-02.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-03.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-04.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-05.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-06.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-07.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-08.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-14.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-18.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-20.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-21.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-23.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-24.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-26.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-11-28.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-04.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-11.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-12.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-15.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-21.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-22.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-23.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-24.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-25.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-28.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-29.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-30.fits.fits
# shifted_fits_slope/shifted_fits_2015/ccf2015-12-31.fits.fits

# %%
plt.plot(BJD_list,rv_list) #1*m*bjd +b

# %%
files = os.listdir("shifted_fits/shifted_fits_2015_16_17_18_half/")
index = np.arange(0, 647, 1)

for i in index:
    print(files[i])
# Out:
# ccf2017-10-31.fits
# ccf2016-07-26.fits
# ccf2017-06-18.fits
# ccf2017-08-06.fits
# ccf2016-02-09.fits
# ccf2017-08-10.fits
# ccf2016-11-19.fits
# ccf2016-03-24.fits
# ccf2016-01-19.fits
# ccf2017-07-23.fits
# ccf2016-04-20.fits
# ccf2018-06-24.fits
# ccf2016-07-30.fits
# ccf2015-08-20.fits
# ccf2017-06-22.fits
# ccf2016-02-25.fits
# ccf2018-03-31.fits
# ccf2017-09-11.fits
# ccf2016-03-08.fits
# ccf2018-06-08.fits
# ccf2017-01-26.fits
# ccf2018-05-18.fits
# ccf2016-05-21.fits
# ccf2016-09-02.fits
# ccf2015-07-29.fits
# ccf2017-02-20.fits
# ccf2016-06-27.fits
# ccf2016-09-14.fits
# ccf2017-04-09.fits
# ccf2017-09-07.fits
# ccf2017-07-19.fits
# ccf2017-05-24.fits
# ccf2016-05-17.fits
# ccf2017-11-10.fits
# ccf2018-07-13.fits
# ccf2016-08-19.fits
# ccf2016-06-07.fits
# ccf2018-04-03.fits
# ccf2015-09-17.fits
# ccf2016-01-03.fits
# ccf2017-09-27.fits
# ccf2015-12-30.fits
# ccf2017-05-04.fits
# ccf2017-04-29.fits
# ccf2017-06-14.fits
# ccf2015-11-20.fits
# ccf2016-03-28.fits
# ccf2017-05-12.fits
# ccf2018-03-11.fits
# ccf2016-06-12.fits
# ccf2016-03-07.fits
# ccf2018-02-13.fits
# ccf2016-07-13.fits
# ccf2015-08-03.fits
# ccf2018-05-17.fits
# ccf2016-04-03.fits
# ccf2016-08-20.fits
# ccf2018-06-07.fits
# ccf2015-07-30.fits
# ccf2017-10-04.fits
# ccf2017-03-02.fits
# ccf2016-06-28.fits
# ccf2018-06-11.fits
# ccf2016-03-11.fits
# ccf2017-09-08.fits
# ccf2016-10-01.fits
# ccf2017-08-25.fits
# ccf2017-04-06.fits
# ccf2016-08-16.fits
# ccf2016-06-08.fits
# ccf2018-05-21.fits
# ccf2017-03-22.fits
# ccf2016-05-18.fits
# ccf2017-08-05.fits
# ccf2018-03-08.fits
# ccf2017-04-30.fits
# ccf2017-08-13.fits
# ccf2015-12-29.fits
# ccf2017-07-20.fits
# ccf2016-03-27.fits
# ccf2018-06-27.fits
# ccf2016-04-23.fits
# ccf2017-01-09.fits
# ccf2016-02-26.fits
# ccf2017-06-21.fits
# ccf2017-05-31.fits
# ccf2017-10-08.fits
# ccf2016-09-01.fits
# ccf2016-05-22.fits
# ccf2017-01-25.fits
# ccf2016-04-19.fits
# ccf2017-02-23.fits
# ccf2016-09-17.fits
# ccf2015-08-19.fits
# ccf2015-11-03.fits
# ccf2017-08-29.fits
# ccf2016-01-20.fits
# ccf2017-05-27.fits
# ccf2017-09-04.fits
# ccf2018-03-24.fits

# %%
# Plot rv's of all all kinds
fig, ax = plt.subplots(figsize=(10, 7))

#ax.scatter(BJD_list, rv_list, label = "new_vrad", s=5)
#ax.scatter(BJD_list, vradraw_list, label = "vradraw_list", s=5)
ax.scatter(BJD_list, mu_og_list, label = "mpyfit un_shifted ccfs", s=5)
ax.scatter(BJD_list, mu_jup_list, label = "mpyfit jupiter_shifted ccfs", s=5)
ax.scatter(BJD_list, mu_zero_list, label = "mpyfit to zero_shifted ccfs", s=5)
#ax.scatter(BJD_list, vradraw_list-np.array(rv_list), label = "vradraw_list - rv_list", s=5)
ax.set_ylabel('RV in km/s', size=20)
ax.set_xlabel('BJD', size=20)
ax.legend()

# %%
np.mean(mu_zero_list)
# Out:
# -0.0003362898953797339

# %%
fig, ax = plt.subplots(figsize=(10, 7))


ax.scatter(BJD_list, mu_og_list, label = "original", s=5)
ax.scatter(BJD_list, mu_jup_list, label = "shifted by jupiter (DRS)", s=5)
ax.scatter(BJD_list, mu_zero_list, label = "\"shifted to zero\" by adding rvh", s=5)
ax.set_ylabel('rv in km/s', size=20)
ax.set_xlabel('BJD', size=20)
ax.legend()

# %%
CCF_data1_list = []
rv_signal_list = []
bjd_test_list = []
mu_zero_list_after = []

# %%
# Open shifted file to check contents
year = "2015_16_17_18"
files = os.listdir("shifted_fits/shifted_fits_"+str(year)+"/")
for file in sorted(files):
    hdul2 = fits.open(str("shifted_fits/shifted_fits_"+str(year)+"/"+file), memmap=False)
    bjd_test = hdul2[0].header["BJD"]
    #print(bjd_test)
    bjd_test_list.append(bjd_test)
    rv_signal = hdul2[0].header["rvh"]
    rv_signal_list.append(rv_signal)
    shifted_CCF_data = hdul2[2].data["Shifted CCF data"]
    CCF_data1_list.append(shifted_CCF_data)
    
    # no_shift fit
    rv_data = np.linspace(-20, 20, 161)
    x = np.where(abs(rv_data) > 10)
    non_peak = shifted_CCF_data[x]
    median_non_peak= np.median(non_peak)
    
    parinfo = [{'fixed': False, 'step': 1e-3*median_non_peak},
               {'fixed': False, 'step': 1*median_non_peak},
               {'fixed': False, 'step': 1e-3},
               {'fixed': False, 'step': 1e-3*median_non_peak},
               {'fixed': False, 'step': 1e-5*median_non_peak},
               {'fixed': False, 'step': 1e-5*median_non_peak}]
    
    # fits the shifted data
    rv_data_shifted = np.linspace(-20, 20, 161)
    #p_shifted = [-0.5*median_non_peak, -0.5, 3.5 + shift_to_zero, 1*median_non_peak, 1e-3*median_non_peak, 1e-3*median_non_peak]
    #pfit, results = mpyfit.fit(least, p_shifted, (rv_data_shifted, shifted_CCF_data), parinfo)
    #m_zero = pfit[1]
    #mu_zero_list_after.append(m_zero)#-0.1)
    
    #hdul1 = fits.open(str("fits/fits_"+str(year)+"/"+file), memmap=False)
    #CCF_data1 = hdul1[0].data
    #CCF_data1_list.append(CCF_data1)

# %%
np.max(bjd_test_list)
# Out:
# 2458484.046883868

# %%
fig, ax = plt.subplots(figsize=(10, 7))

ax.scatter(np.array(BJD_list), mu_zero_list, label = "mpyfit before writing to file", s=5)
ax.scatter(np.array(bjd_test_list)-2400000, mu_zero_list_after, label = "mpyfit after opening shifted fits file", s=5)
ax.set_ylabel('rv in km/s', size=20)
ax.set_xlabel('BJD', size=20)
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aeb543e979dd> in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 7))
#       2
# ----> 3 ax.scatter(np.array(BJD_list), mu_zero_list, label = "mpyfit before writing to file", s=5)
#       4 ax.scatter(np.array(bjd_test_list)-2400000, mu_zero_list_after, label = "mpyfit after opening shifted fits file", s=5)
#       5 ax.set_ylabel('rv in km/s', size=20)
#
# NameError: name 'BJD_list' is not defined

# %%
#plt.plot(np.array(bjd_test_list)-2400000, rv_signal_list)
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(np.array(bjd_test_list)-2400000, rv_signal_list, label = "New DRS slope corr")
#ax.plot(bjd_test_list, m*(np.array(bjd_test_list)) + b)
#ax.plot(bjd_test_list[0:540], m_half*(np.array(bjd_test_list[0:540])) + b_half)
ax.set_xlabel("BJD", size = 20)
ax.set_ylabel("RV (km/s)", size = 20)
ax.legend()

print("slope: "+str(m*1000)+ " km/s")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-00017173e074> in <module>
#       9 ax.legend()
#      10
# ---> 11 print("slope: "+str(m*1000)+ " km/s")
#
# TypeError: unsupported operand type(s) for *: 'module' and 'int'

# %%
print(rv_signal_list)
# Out:
# [0.005025528907819565, 0.005375766223380985, 0.006387548542578211, 0.006671668468640418, 0.006865386379104219, 0.007994358603170416, 0.006846942085494957, 0.005343229531182608, 0.005990162731040403, 0.00553331382426789, 0.002734499764787659, 0.004078345308894864, 0.003631054875354992, 0.003501994358723631, 0.003660581983920363, 0.001795549631786095, 0.003170395108751025, 0.006030003752944206, 0.005899435534949315, 0.006181715291
# %%
m, b = np. polyfit(bjd_test_list, rv_signal_list, 1) # m = slope, b = intercept.
m_half, b_half = np. polyfit(bjd_test_list[0:540], rv_signal_list[0:540], 1) # m = slope, b = intercept.

slope_sub = m*(np.array(bjd_test_list))+ b

#plt.plot(np.array(bjd_test_list)-2400000, rv_signal_list)
#plt.plot(np.array(bjd_test_list), rv_signal_list)
#plt.plot(bjd_test_list, m*(np.array(bjd_test_list)) + b)
#plt.plot(np.array(bjd_test_list), rv_signal_list, color="g", label="original")
plt.plot(np.array(bjd_test_list), rv_signal_list -1*slope_sub, label="remove slope")
plt.plot(bjd_test_list, m*(np.array(bjd_test_list)) + b, label="slope")
plt.xlabel("BJD", size =15)
plt.xlabel("RV (km/s)", size =15)
print(m*1000)
plt.legend()
# Out:
# -0.0037156240651736463

# %%
print(rv_signal_list[0:10])
print(bjd_test_list[0:10])
print(slope_sub[0:10])
# Out:
# [0.005025528907819565, 0.005375766223380985, 0.006387548542578211, 0.006671668468640418, 0.006865386379104219, 0.007994358603170416, 0.006846942085494957, 0.005343229531182608, 0.005990162731040403, 0.00553331382426789]
# [2457223.914824152, 2457233.004082826, 2457234.126658932, 2457235.108307244, 2457236.069661575, 2457237.106435021, 2457238.003753148, 2457239.216463533, 2457239.945210034, 2457242.019233522]
# [-8.97760158 -8.97763478 -8.97763889 -8.97764247 -8.97764598 -8.97764977
#  -8.97765305 -8.97765748 -8.97766014 -8.97766772]

# %%
np.std(rv_signal_list -slope_sub)

# %%
scaled_signals = []
for i in rv_signal_list:
    scaled_signals.append(i*1000)

fig, ax = plt.subplots(figsize=(10, 7))
ax.hist(scaled_signals, color= "c")
ax.set_xlabel("rvh (m/s)", size = 15)
ax.set_ylabel("Frequency", size = 15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig, ax = plt.subplots(figsize=(10, 7))
for i in CCF_data1_list:
    ax.plot(np.linspace(-20, 20, 161),i)
    ax.set_xlabel("RV (m/s)", size =18)
    ax.set_ylabel("CCF", size=18)

# %%
hdul3 = fits.open("shifted_fits_slope/shifted_fits_2019/ccf2019-12-08.fits", memmap=False)
bjd_test = hdul3[0].header["BJD"]
rv_signal = hdul3[0].header["rvh"]
CCF_data_zero = hdul3[2].data["Shifted CCF data"]
mu_zero = hdul3[0].header["MU_zero"]

hdul_quiet = fits.open("shifted_fits_slope/shifted_fits_2017/ccf2017-03-13.fits", memmap=False)
CCF_quiet = hdul_quiet[2].data["Shifted CCF data"]
print(mu_zero)
print(bjd_test)
print(rv_signal)
# Out:
# -0.00017713946699567
# 2458826.036000756
# -0.00023950112048327

# %%
len(CCF_data1_list)
# Out:
# 89

# %% [markdown]
# ## Residual plots

# %%
median_ccf = np.mean(CCF_data1_list, axis=0)
plt.plot(median_ccf)

# %%
# remove extreme outliers

for i in range(0, len(rv_signal_list)):
    if rv_signal_list[i]==0.006865386379104219:
        print(i)

# Make a list of the rv's withot this anomoly
rv_list_no_outliers = []
ccf_list_no_outliers = []
for i in range(0, len(rv_signal_list)):
    if i==5 or i ==45 or i ==85:#or i == 739 or i ==756 or i ==85:
        #print(ccf_num_list[i])
        continue
    rv_list_no_outliers.append(rv_signal_list[i])
    ccf_list_no_outliers.append(CCF_data1_list[i])
# Out:
# 4

# %%
print(bjd_test_list[5])
print(bjd_test_list[45])
print(bjd_test_list[85])
# Out:
# 2457237.106435021
# 2457292.86711829
# 2457385.070376353

# %%
#print(np.min(rv_list_no_outliers), np.max(rv_list_no_outliers))


print(np.min(rv_signal_list), np.max(rv_signal_list))
min_rv = np.min(np.array(rv_signal_list)+0.015)
max_rv = np.max(np.array(rv_signal_list)+0.015)
print(min_rv, max_rv)
# Out:
# -0.00675672505154642 0.007994358603170416
# 0.00824327494845358 0.022994358603170416

# %%
cscale_residuals = ((np.array(rv_signal_list)+0.015 -min_rv)/ (max_rv-min_rv))
#cscale_residuals = (np.array(np.abs(rv_signal_list))/ (-4*(max_rv+min_rv)))#-min_rv))#-0.5)/0.6
print(np.min(cscale_residuals), np.max(cscale_residuals))
# Out:
# 0.048863001994289466 0.7907538720359989

# %%
plt.hist(cscale_residuals)
print(len(rv_signal_list))
print(len(cscale_residuals))
# Out:
# 768
# 768

# %%
# color code by date instead of rv
min_rv = np.min(bjd_test_list)
max_rv = np.max(bjd_test_list)
cscale_residuals = (np.array(np.abs(bjd_test_list)) -min_rv)/ (max_rv-min_rv)
print(np.min(cscale_residuals), np.max(cscale_residuals))
# Out:
# 0.0 1.0

# %%
# Print without outliers
fig, ax = plt.subplots(figsize=(12, 7))

rv_data = np.linspace(-20, 20, 161)
#print(ccf_list[5])
#rv_list[5] is centered at 0.0

col = plt.cm.jet([0.25,0.75])
n = len(CCF_data1_list)
colors = plt.cm.bwr(cscale_residuals)


for i in range(0,len(ccf_list_no_outliers)):
    ax.plot(rv_data,ccf_list_no_outliers[i]-CCF_data_zero,  color = colors[i])

ax.set_xlabel('RV in km/s', size=20)
ax.set_ylabel('Residuals ($\Delta$CCF)', size=20)
ax.set_title("CCF Residuals from HARPS-N", size =20)
#fig.colorbar(rv_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-440-30ef43aa6d2f> in <module>
#      11
#      12
# ---> 13 for i in range(0,len(ccf_list_no_outliers)):
#      14     ax.plot(rv_data,ccf_list_no_outliers[i]-CCF_data_zero,  color = colors[i])
#      15
#
# NameError: name 'ccf_list_no_outliers' is not defined

# %%
import matplotlib as mpl
fig, ax = plt.subplots(figsize=(12, 7))

rv_data = np.linspace(-20, 20, 161)
#print(ccf_list[5])
#rv_list[5] is centered at 0.0

col = plt.cm.jet([0.25,0.75])
n = len(CCF_data1_list)
colors = plt.cm.bwr(cscale_residuals)


#for i in range(0,len(ccf_list)):

for i in range(0,len(CCF_data1_list)):
    mean_residual_error = np.mean(CCF_data1_list[i]-CCF_data_zero)
    #if np.abs(mean_residual_error) <5e-4:
    #    continue
    # Plot the ccf- mean_ccf
    #ax.plot(rv_data,CCF_data1_list[i]-median_ccf,  color = colors[i])
    
    # plot the ccf - quiet_ccf
    # CCF_quiet
    #ax.plot(rv_data,CCF_data1_list[i]-CCF_data_zero,  color = colors[i])
    ax.plot(rv_data,CCF_data1_list[i]-CCF_quiet,  color = colors[i])

cb1.set_label('Some Units')
ax.set_xlabel('RV in km/s', size=20)
ax.set_ylabel('Residuals ($\Delta$CCF)', size=20)
ax.set_title("CCF Residuals from HARPS-N", size =20)
#fig.colorbar(rv_list)
# Out:
# Text(0.5, 1.0, 'CCF Residuals from HARPS-N')

# %%
colors = plt.cm.bwr(cscale_residuals)

cmap = plt.cm.bwr
norm =mpl.colors.Normalize(vmin=-6.76, vmax=7.99) # min = -0.0067567, max = 0.007994

cb1 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                orientation='horizontal')
cb1.set_label('Some Units')
fig.show()
# Out:
# /Users/Zoe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
mean_residual_error = np.mean(CCF_data1_list[i]-CCF_data_zero)

# %%
mean_residual_error
# Out:
# -1.742751e-05

# %%
a = [rv_data]
one_array.append((CCF_data1_list[i]-CCF_data_zero))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-305-b30e2d299f15> in <module>
#       1 a = [rv_data]
# ----> 2 one_array.append((CCF_data1_list[i]-CCF_data_zero))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
b = [CCF_data1_list[i]-CCF_data_zero]
c = np.concatenate((a, b))

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import imageio

col = plt.cm.jet([0.25,0.75])
n = len(CCF_data1_list)
colors = plt.cm.bwr(cscale_residuals)

fig, ax = plt.subplots(figsize=(12,7))
ax.set_xlabel('RV in km/s', size=20)
ax.set_ylabel('Residuals ($\Delta$CCF)', size=20)
ax.set_title("New CCF Residuals from HARPS-N", size =20)

def plot_residuals(number):
    # Data for plotting
    rv_data = np.linspace(-20, 20, 161)

    #ax.plot(rv_data,CCF_data1_list[number]-CCF_data_zero,  color = colors[number])
    ax.plot(rv_data,CCF_data1_list[number]-CCF_quiet,  color = colors[number])
    #ax.set_xlabel('RV in km/s', size=20)
    #ax.set_ylabel('Residuals ($\Delta$CCF)', size=20)
    #ax.set_title("New CCF Residuals from HARPS-N", size =20)

    # IMPORTANT ANIMATION CODE HERE
    # Used to keep the limits constant
    ax.set_ylim(-0.001, 0.002)

    # Used to return the plot as an image rray
    fig.canvas.draw()       # draw the canvas, cache the renderer
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
    image  = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    return image


kwargs_write = {'fps':1.0, 'quantizer':'nq'}
imageio.mimsave('./new_DRS_2015_2018.gif', [plot_residuals(i) for i in range(0,len(CCF_data1_list))], fps=60)

# %%
len(CCF_data1_list)
# Out:
# 1079

# %%
b
# Out:
# array([ 8.20159912e-05,  4.97102737e-05,  5.47170639e-05,  9.01222229e-05,
#         6.15119934e-05,  4.72068787e-05,  1.13725662e-04,  9.76324081e-05,
#         6.34193420e-05,  1.20162964e-04,  1.31607056e-04,  1.03950500e-04,
#         1.01685524e-04,  1.51336193e-04,  2.09212303e-04,  1.52349472e-04,
#         1.51038170e-04,  1.66237354e-04,  1.39415264e-04,  9.00626183e-05,
#         5.68628311e-05,  5.03063202e-05,  5.53131104e-05,  3.35574150e-05,
#        -4.07695770e-05,  3.68356705e-05,  4.19616699e-05,  4.79221344e-05,
#         9.23871994e-05,  1.05142593e-04,  7.37905502e-05,  5.73396683e-05,
#        -2.07424164e-05, -8.72612000e-05, -6.07967377e-05, -4.62532043e-05,
#         2.86102295e-06,  5.38825989e-05,  7.74860382e-06, -4.17232513e-06,
#        -2.86102295e-06,  2.31266022e-05,  1.28984451e-04,  1.73211098e-04,
#         2.08973885e-04,  3.22341919e-04,  3.30924988e-04,  2.75850296e-04,
#         2.43544579e-04,  2.01106071e-04])

# %%
one_array
# Out:
# array([-20.  , -19.75, -19.5 , -19.25, -19.  , -18.75, -18.5 , -18.25,
#        -18.  , -17.75, -17.5 , -17.25, -17.  , -16.75, -16.5 , -16.25,
#        -16.  , -15.75, -15.5 , -15.25, -15.  , -14.75, -14.5 , -14.25,
#        -14.  , -13.75, -13.5 , -13.25, -13.  , -12.75, -12.5 , -12.25,
#        -12.  , -11.75, -11.5 , -11.25, -11.  , -10.75, -10.5 , -10.25,
#        -10.  ,  -9.75,  -9.5 ,  -9.25,  -9.  ,  -8.75,  -8.5 ,  -8.25,
#         -8.  ,  -7.75,  -7.5 ,  -7.25,  -7.  ,  -6.75,  -6.5 ,  -6.25,
#         -6.  ,  -5.75,  -5.5 ,  -5.25,  -5.  ,  -4.75,  -4.5 ,  -4.25,
#         -4.  ,  -3.75,  -3.5 ,  -3.25,  -3.  ,  -2.75,  -2.5 ,  -2.25,
#         -2.  ,  -1.75,  -1.5 ,  -1.25,  -1.  ,  -0.75,  -0.5 ,  -0.25,
#          0.  ,   0.25,   0.5 ,   0.75,   1.  ,   1.25,   1.5 ,   1.75,
#          2.  ,   2.25,   2.5 ,   2.75,   3.  ,   3.25,   3.5 ,   3.75,
#          4.  ,   4.25,   4.5 ,   4.75,   5.  ,   5.25,   5.5 ,   5.75,
#          6.  ,   6.25,   6.5 ,   6.75,   7.  ,   7.25,   7.5 ,   7.75,
#          8.  ,   8.25,   8.5 ,   8.75,   9.  ,   9.25,   9.5 ,   9.75,
#         10.  ,  10.25,  10.5 ,  10.75,  11.  ,  11.25,  11.5 ,  11.75,
#         12.  ,  12.25,  12.5 ,  12.75,  13.  ,  13.25,  13.5 ,  13.75,
#         14.  ,  14.25,  14.5 ,  14.75,  15.  ,  15.25,  15.5 ,  15.75,
#         16.  ,  16.25,  16.5 ,  16.75,  17.  ,  17.25,  17.5 ,  17.75,
#         18.  ,  18.25,  18.5 ,  18.75,  19.  ,  19.25,  19.5 ,  19.75,
#         20.  ])

# %% [markdown]
# import sys
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.animation import FuncAnimation
#
# fig, ax = plt.subplots()
# fig.set_tight_layout(True)
#
# # Query the figure's on-screen size and DPI. Note that when saving the figure to
# # a file, we need to provide a DPI for that separately.
# print('fig size: {0} DPI, size in inches {1}'.format(
#     fig.get_dpi(), fig.get_size_inches()))
#
# print(fig.get_dpi())
#
# # Plot a scatter that persists (isn't redrawn) and the initial line.
# x = np.arange(0, 20, 0.1)
# ax.scatter(x, x + np.random.normal(0, 3.0, len(x)))
# line, = ax.plot(x, x - 5, 'r-', linewidth=2)
#
# def update(i):
#     label = 'timestep {0}'.format(i)
#     print(label)
#     # Update the line and the axes (with a new xlabel). Return a tuple of
#     # "artists" that have to be redrawn for this frame.
#     line.set_ydata(x - 5 + i)
#     ax.set_xlabel(label)
#     return line, ax
#
# if __name__ == '__main__':
#     # FuncAnimation will call the 'update' function for each frame; here
#     # animating over 10 frames, with an interval of 200ms between frames.
#     anim = FuncAnimation(fig, update, frames=np.arange(0, 10), interval=200)
#     #if len(sys.argv) > 1 and sys.argv[1] == 'save':
#     anim.save('line.gif', dpi=80, writer='imagemagick')
#     #else:
#     #    # plt.show() will just loop the animation forever.
#     #    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)
# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame

ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = plt.imshow(f(x, y), animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=False,
                                repeat_delay=1000)

print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

#To save the animation, use e.g.
#ani.save("movie.mp4")

# or
#
#from matplotlib.animation import FFMpegWriter
#writer = FFMpegWriter(fps=15, metadata=dict(artist='Me'), bitrate=1800)
#ani.save("movie.mp4", writer=writer)

#ani = FuncAnimation(fig, update, frames=np.linspace(0, 3, 128),
#                    init_func=init, blit=True)

ani.save('test.gif', dpi=72, writer='imagemagick')

plt.show()
# Out:
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# fig size: 72.0 DPI, size in inches [6. 4.]

# %%
type(f(x, y))
# Out:
# numpy.ndarray

# %%
    files = os.listdir("shifted_fits/shifted_fits_"+str(year)+"/")
    file = files[0]
    hdul2 = fits.open(str("shifted_fits/shifted_fits_"+str(year)+"/"+file), memmap=False)
    bjd_test = hdul2[0].header["BJD"]
    #bjd_list.append(bjd_test-2400000)
    rv = hdul2[0].header["rvh"]
    #rv_list.append(rv)
    berv = hdul2[0].header["berv"]
    #berv_list.append(berv)
    vradraw = hdul2[0].header["vradraw"]
    #vradraw_list.append(vradraw)
    CCF_data = hdul2[2].data["CCF data"]
    plt.plot(CCF_data)

# %%
CCF_data = hdul2[2].data["CCF_data"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/column.py in _get_index(names, key)
#    2008         try:
# -> 2009             indx = names.index(key.rstrip())
#    2010         except ValueError:
#
# ValueError: 'CCF_data' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-32d70c296162> in <module>
# ----> 1 CCF_data = hdul2[2].data["CCF_data"]
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/fitsrec.py in __getitem__(self, key)
#     485
#     486         if isinstance(key, str):
# --> 487             return self.field(key)
#     488
#     489         # Have to view as a recarray then back as a FITS_rec, otherwise the
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/fitsrec.py in field(self, key)
#     675         # NOTE: The *column* index may not be the same as the field index in
#     676         # the recarray, if the column is a phantom column
# --> 677         column = self.columns[key]
#     678         name = column.name
#     679         format = column.format
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/column.py in __getitem__(self, key)
#    1614     def __getitem__(self, key):
#    1615         if isinstance(key, str):
# -> 1616             key = _get_index(self.names, key)
#    1617
#    1618         x = self.columns[key]
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/column.py in _get_index(names, key)
#    2016                 indx = names.index(_key)
#    2017             elif count == 0:
# -> 2018                 raise KeyError("Key '{}' does not exist.".format(key))
#    2019             else:              # multiple match
#    2020                 raise KeyError("Ambiguous key name '{}'.".format(key))
#
# KeyError: "Key 'CCF_data' does not exist."

# %%
np.min(full_bjd_list) #2458851.91606227 = July 29, 2015
# 2019 data: January 2, 2019

# %%
np.max(full_bjd_list) #2458915.96040548 = March 7, 2020
# 2019 data: December 31, 2019

# %%
    # Normalize the CCF
    # no_shift fit
    p_no_shifted = [-1618490., 0.1, 1., 16730977]
    pfit_no_shift, results_no_shift = mpyfit.fit(least, p_no_shifted, (rv_axis, mean_ccf), parinfo)
    A = pfit_no_shift[0]
    C = pfit_no_shift[3]
    print(C)
    fig3, ax3 = plt.subplots(figsize=(10, 7))
    normalized_ccfa =(mean_ccf/C)
    ax3.plot(rv_axis,normalized_ccfa)

# %%
# !ls 'hpcstorage/buchschn/HARPN/reduced/2020-03-07'

# %%
hdul = fits.open('hpcstorage/buchschn/HARPN/reduced/2020-03-07/r.HARPN.2020-03-07T09:07:49.640_CCF_A.fits', memmap=False)

# %%
hdul[0].header

# %%
a = hdul[1].data

# %%
plt.plot(a[0])

# %%
rv_data = np.linspace(-20, 20, 161)
for i in a[0:70]:
    plt.plot(rv_data,i)

# %%
len(rv_data)

# %%
plt.plot(hdul[1].data[69])

# %%
len(a[69])

# %% [markdown]
# ## Only first three years using old DRS rv's

# %%
year = "2015"

# list the directories that have HARPS-N files in them
directories = os.listdir('hpcstorage'+str(year)+'/buchschn/HARPN/reduced')

# Open csv file with DRS RVs
df_old = pd.read_excel('../Archive_HARPS_N/Sun_harpsn_qualflag copy.xlsx')

# %%
df_old['BJD']

# %%
bjd

# %%
directories

# %%
# Finds the local minima using a Gaussian fit
# Define the actual function where     A = p[0], mu = p[1], sigma = p[2], c = p[3]
def gauss(x, p):
    return -p[0] * np.exp(-(x - p[1]) ** 2 / (2. * p[2] ** 2)) + p[3]

# A simple minimization function:
def least(p, args):
    x, y = args
    return gauss(x, p) - y

parinfo = [{'fixed': False, 'step': 1e-6},
           {'fixed': False, 'step': 1e-4},
           {'fixed': False, 'step': 1e-14},
           {'fixed': False, 'step': 1e-9}]

# %%
full_bjd_list = []
removed_counter = 0
gen_counter = 0
for directory in directories:
    #print(directory)
    if directory == '.DS_Store':
        continue
    files = os.listdir(str('hpcstorage'+str(year)+'/buchschn/HARPN/reduced/'+directory))
    
    #fig, ax = plt.subplots(figsize=(10, 7))
    bjd_list =[]
    ccf_list = []
    DRS_new_vrad_list= []
    DRS_new_berv_list=[]
    rv_axis = np.linspace(-20,20, 161)
    for file in files:
        #print(file)
        hdul = fits.open(str('hpcstorage'+str(year)+'/buchschn/HARPN/reduced/'+directory+"/"+file), memmap=False)
        #print(hdul[0].header["HIERARCH TNG QC BJD"])
        ccf = hdul[1].data[69]
        bjd = hdul[0].header["HIERARCH TNG QC BJD"]-2400000
        print(bjd)
        #DRS_new_vrad = df.loc[df['new_bjd'] == bjd, 'new_vrad'].item()
        new_bjd_list = pd.Index(df_old['BJD'])
        i = new_bjd_list.get_loc(bjd, method = "nearest")
        #print(np.abs(df['new_bjd'][i]))
        
        # Check that the BJD is within 10 seconds (0.000115741 days)
        if (np.abs(df['new_bjd'][i]-bjd)) > 0.000115741:
            #print("the difference in BJD is more than 10 seconds for BJD: "+str(bjd))
            removed_counter +=1
            continue
        DRS_new_vrad= df['new_vrad'][i]
        DRS_new_berv= df['new_berv'][i]
        #ax.plot(rv_axis,ccf, color= 'b')
        
        ccf_list.append(ccf)
        bjd_list.append(bjd)
        full_bjd_list.append(bjd)
        DRS_new_vrad_list.append(DRS_new_vrad)
        DRS_new_berv_list.append(DRS_new_berv)
        #print("  - - - ")
    if not ccf_list:
        print("There are no DRS RVs on "+str(directory))
        #print(str(directory))
        continue
    mean_ccf = np.mean(ccf_list, axis=0)
    median_DRS_new_vrad = np.mean(DRS_new_vrad_list)
    median_DRS_new_berv = np.mean(DRS_new_berv_list)
    median_bjd = np.mean(bjd_list)
    #ax.plot(rv_axis,ccf, label = "all ccf's", color= 'b')
    #ax.plot(rv_axis,mean_ccf, label = "mean ccf, "+str(median_bjd), color= 'r')
    #ax.set_xlabel("RV (m/s)", size =15)
    #ax.set_ylabel("CCF", size =15)
    #ax.legend()

    #print(median_bjd)
    #print(median_DRS_new_vrad)
    
    #fig2, ax2 = plt.subplots(figsize=(10, 7))
    x_mean = [median_DRS_new_vrad]*len(DRS_new_vrad_list)
    #ax2.scatter(bjd_list,DRS_new_vrad_list, label = "all rv's", color='b')
    #ax2.plot(bjd_list,x_mean, label = "mean rv", color = 'r')
    #ax2.set_xlabel("BJD", size =15)
    #ax2.set_ylabel("DRS RV", size =15)
    #ax2.legend()
    
    # Normalize the CCF
    p_guess = [-1618490., 0.1, 1., 16730977]
    pfit, results = mpyfit.fit(least, p_guess, (rv_axis, mean_ccf), parinfo)
    A = pfit[0]
    C = pfit[3]
    #print(C)
    #fig3, ax3 = plt.subplots(figsize=(10, 7))
    normalized_ccf =(mean_ccf/C)
    #ax3.plot(rv_axis,normalized_ccf)
    
    # Write CCF, BJD, and RV to a fits file
    hdu_new = fits.ImageHDU()
    hdr = fits.Header()
    primary_hdu = fits.PrimaryHDU(header=hdr)
    hdul = fits.HDUList([primary_hdu, hdu_new])
    
    #creates columns in CCF.fits files
    #col1 = fits.Column(name='CCF data', format='E', array=normalized_ccf)
    
    hdu = fits.PrimaryHDU(normalized_ccf)
    hdulist = fits.HDUList([hdu])
    
    # Set header
    hdulist[0].header.set("BJD", median_bjd, 'Barycentric JD (from DRS)')
    hdulist[0].header.set('rvh', median_DRS_new_vrad, 'RV [km/s]')
    hdulist[0].header.set('berv', median_DRS_new_berv, 'RV [km/s]')
    
    # check whether folder exists. If not, make it
    CCF_folder_outputs = '3year_fits_'+str(year)
    if not os.path.exists(CCF_folder_outputs):
        os.mkdir(CCF_folder_outputs)
    
    # write and close hdul
    hdulist.writeto('fits_'+str(year)+'/ccf' +directory+'.fits')
    hdulist.close()
    gen_counter +=1
    if gen_counter%50==0:
        print(gen_counter)
    #print("_______")
    #if directory == "2020-02-06":
    #    break

# %%
new_bjd_list = pd.Index(df_old['BJD'])

# %%
i = new_bjd_list.get_loc(bjd, method = "nearest")

# %%
dupes = df_old["BJD"].duplicated()

# %%
count = 0
for i in dupes:
    if i != False:
        print(i)
        print(df_old["BJD"][count])
    count +=1
