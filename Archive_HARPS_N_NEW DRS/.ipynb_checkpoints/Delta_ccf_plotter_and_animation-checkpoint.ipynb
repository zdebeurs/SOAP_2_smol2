# %%
import numpy as np
#import tensorflow as tf
import matplotlib.pyplot as plt
import csv
import pickle
import math as m
import os
import pandas as pd
from tqdm import tqdm


#globally change font size for plots
plt.rcParams['font.size'] =17
plt.rcParams['mathtext.fontset'] = 'stix'
#plt.rcParams['font.family'] = 'STIXGeneral'


from residual_plot import residual_plot

# %%
outfile = 'HARPS2.3.1_ready_for_TF_records.npz'#'
npzfile = np.load(outfile) 
npzfile.files
# Out:
# ['BJD',
#  'vrad_star',
#  'og_ccf_list',
#  'jup_shifted_CCF_data_list',
#  'zero_shifted_CCF_list',
#  'CCF_normalized_list',
#  'cff_residual_list',
#  'ccf_residual_rescaled',
#  'CCF_normalized_list_cutoff',
#  'CCF_residual_list_cutoff',
#  'ccf_residual_rescaled_cutoff',
#  'mu_og_list',
#  'mu_jup_list',
#  'mu_zero_list',
#  'fwhm',
#  'cont',
#  'bis',
#  'shift_by_rv']

# %%
rv_data = np.linspace(-19.58, 19.78, 49)

#residual_plot(npzfile['vrad_star'], rv_data, npzfile['zero_shifted_CCF_list'], 484, 'Original') #

residual_plot(npzfile['vrad_star'], rv_data[1:47], npzfile['CCF_normalized_list_cutoff'], 484, 'CCF Residuals from HARPS-N')
# Out:
# 0.0 1.0
