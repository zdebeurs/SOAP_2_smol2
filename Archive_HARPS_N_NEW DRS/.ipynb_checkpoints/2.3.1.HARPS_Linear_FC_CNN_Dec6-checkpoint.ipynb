# %%
import os.path
import numpy as np

#Ensures we use Tensorflow 1.x
#%tensorflow_version 1.x
import tensorflow as tf
#tf.enable_eager_execution()
import tensorflow_addons as tfa
print(tf.__version__)

import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 15

import pandas as pd
from sklearn.linear_model import LinearRegression
from astropy.stats import median_absolute_deviation
import numpy as np
from tqdm.notebook import tqdm
from sklearn.linear_model import Ridge
# Out:
# 2.0.0

# %%
print(tf.__version__)
import tensorflow_addons as tfa
# Out:
# 2.0.0

# %%
# rv_net imports.
import sys
sys.path.append("rv_net/")
from ops import training
from tf_util import config_util
from tf_util import configdict
from tf_util import estimator_runner
from rv_net import data_HARPS_N
from rv_net import  data, rv_model, estimator_util, load_dataset_ridge, ridge_regress_harps

# %%
# @title Residual plotting code
import matplotlib.pylab as mpl
def residual_plot(rv_list, x_axis, ccfs_of_interest, num_ref_ccf, plot_title):
    # create color scheme
    min_rv = np.min(rv_list)
    max_rv = np.max(rv_list)
    cscale_residuals = (np.array(rv_list - min_rv) / (max_rv - min_rv))
    print(np.min(cscale_residuals), np.max(cscale_residuals))

    col = plt.cm.jet([0.25, 0.75])
    n = len(ccfs_of_interest)
    colors = plt.cm.bwr(cscale_residuals)

    # Create the residual plot by looping through the list of CCFs ordered by date
    fig, ax = plt.subplots(1, 1, figsize=(14, 6))
    num = 0
    for i in np.arange(0, len(ccfs_of_interest)):
        if num_ref_ccf == "median":
            plt.plot(x_axis, ccfs_of_interest[i] - np.median(list(ccfs_of_interest), axis=0), color=colors[num])
        else:
            if i != num_ref_ccf:
                plt.plot(x_axis, ccfs_of_interest[i] - ccfs_of_interest[num_ref_ccf], color=colors[num])
        num += 1

    plt.title(plot_title)
    # make color bar
    cmap = mpl.cm.bwr
    norm = mpl.colors.Normalize(vmin=(min_rv - np.median(rv_list)), vmax=(max_rv - np.median(rv_list)))
    cb = plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), orientation="vertical", pad=-0.0001)
    cb.set_label(label='Stellar Activity Signal (m/s)', size=16, rotation=270, labelpad=20)

# %% [markdown]
# ## Reading in the data

# %%
eval_method ='cross_val' #"val"#'cross_val' #"val"# "val"#"cross_val" # "val" # "test"

ccf_len = 46

# %%
# Change this path to point towards the location of the files in your drive

# !ls 'TF_records_Nov2021'
# Out:
# TF_ccf_cross_val0 TF_ccf_cross_val4 TF_ccf_cross_val8 TF_ccf_val
# TF_ccf_cross_val1 TF_ccf_cross_val5 TF_ccf_cross_val9
# TF_ccf_cross_val2 TF_ccf_cross_val6 TF_ccf_full_train
# TF_ccf_cross_val3 TF_ccf_cross_val7 TF_ccf_test

# %%
# Read in files for cross-validation
DATA_DIR = 'TF_records_Nov2021/' #TF_record_July_10_21_no_planets_median_prov_rvs/' #HARPS-N Solar Telescope Data (using old DRS)/' #TF_record_July_10_21_no_planets_same_test_set' #TF_record_July_10_21_no_planets_v2'

if eval_method =="cross_val":
  data_files = tf.data.Dataset.list_files(DATA_DIR+'*cross_val*',shuffle=False)
  data_files = [t.numpy() for t in data_files]
  TRAIN_FILE_NAME_LIST = []
  VAL_FILE_NAME_LIST = []

  N = len(data_files)
  for i in range(N):
    val_files = [data_files[i]]
    #print(val_files)
    VAL_FILE_NAME_LIST.append(val_files)
    train_files = data_files[0:i] + data_files[i+1:]
    TRAIN_FILE_NAME_LIST.append(train_files)
    # add all the training files

  NUM_TRAINING_EXAMPLES = 503
  NUM_VALIDATION_EXAMPLES = 51

elif eval_method =="val":
  TRAIN_FILE_NAME_LIST = [[os.path.join(DATA_DIR, "TF_ccf_full_train")]]
  VAL_FILE_NAME_LIST = [[os.path.join(DATA_DIR, "TF_ccf_val")]]#test")]]

  NUM_TRAINING_EXAMPLES = 503
  NUM_VALIDATION_EXAMPLES = 61
elif eval_method =="test":
  TRAIN_FILE_NAME_LIST = [[os.path.join(DATA_DIR, "TF_ccf_full_train")]]
  VAL_FILE_NAME_LIST = [[os.path.join(DATA_DIR, "TF_ccf_test")]]#test")]]

  NUM_TRAINING_EXAMPLES = 503
  NUM_VALIDATION_EXAMPLES = 61
else:
  print("Please select a valid evaluation method: 'cross_val' or 'val' or 'test'")
# Out:
# 2021-12-07 07:36:13.879379: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-07 07:36:13.880468: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
print(TRAIN_FILE_NAME_LIST)
VAL_FILE_NAME_LIST
# Out:
# [[b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val8', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val9'], [b'TF_records_Nov2021/TF_ccf_cross_val0', b'TF_records_Nov2021/TF_ccf_cross_val1', b'TF_records_Nov2021/TF_ccf_cross_val2', b'TF_records_Nov2021/TF_ccf_cross_val3', b'TF_records_Nov2021/TF_ccf_cross_val4', b'TF_records_Nov2021/TF_ccf_cross_val5', b'TF_records_Nov2021/TF_ccf_cross_val6', b'TF_records_Nov2021/TF_ccf_cross_val7', b'TF_records_Nov2021/TF_ccf_cross_val8']]
# [[b'TF_records_Nov2021/TF_ccf_cross_val0'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val1'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val2'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val3'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val4'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val5'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val6'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val7'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val8'],
#  [b'TF_records_Nov2021/TF_ccf_cross_val9']]

# %%
def _example_parser(serialized_example):
    """Parses a single tf.Example into feature and label tensors."""
    feature_name = "Rescaled CCF_residuals_cutoff"#"Rescaled CCF_residuals" #CCF_residuals
    label_name = "activity signal"#"RV",
    label2_name = "BJD"
    data_fields = {
        feature_name: tf.io.FixedLenFeature([ccf_len], tf.float32), #[161], tf.float32),
        label_name: tf.io.FixedLenFeature([], tf.float32),
        label2_name: tf.io.FixedLenFeature([], tf.float32),
    }
    parsed_fields = tf.io.parse_single_example(serialized_example, features=data_fields)
    return parsed_fields[feature_name], parsed_fields[label_name]*1000, parsed_fields[label2_name]

#def load_dataset(file_pattern, batch_size, mode=tf.estimator.ModeKeys.EVAL):
#  filename_dataset = tf.data.Dataset.list_files(file_pattern)
#  dataset = filename_dataset.flat_map(tf.data.TFRecordDataset)
#  if mode == tf.estimator.ModeKeys.TRAIN:
#    dataset = dataset.shuffle(buffer_size=NUM_TRAINING_EXAMPLES)
#  dataset = dataset.map(_example_parser, num_parallel_calls=4)
#  dataset = dataset.batch(batch_size)
#  return dataset

def load_dataset(filenames, batch_size, mode=tf.estimator.ModeKeys.EVAL):
    filename_dataset = tf.data.Dataset.from_tensor_slices(filenames)
    dataset = filename_dataset.flat_map(tf.data.TFRecordDataset)
    if mode == tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.shuffle(buffer_size=NUM_TRAINING_EXAMPLES)
    dataset = dataset.map(_example_parser, num_parallel_calls=4)
    dataset = dataset.batch(batch_size)
    return dataset

# %%
# @title Define LinearModel, FCModel, CNNModel
class LinearModel(tf.keras.Model):
    """A TensorFlow linear regression model."""

    def __init__(self, hparams):
        """Basic setup.

        Args:
          hparams: A ConfigDict of hyperparameters for building the model.

        Raises:
          ValueError: If mode is invalid.
        """
        super(LinearModel, self).__init__()
        self.hparams = hparams
        #self.weights = tf.Variable(tf.zeros(self.hparams.num_features))
        self.dense_layer = tf.keras.layers.Dense(
            1, kernel_initializer=tf.zeros_initializer, use_bias=False)
        
    def call(self, features, training=False):
      # return tf.tensordot(features, self.weights, axes=1)
      return tf.squeeze(self.dense_layer(features))

class FCModel(tf.keras.Model):
    """A TensorFlow linear regression model."""

    def __init__(self, hparams):
        """Basic setup.

        Args:
          hparams: A ConfigDict of hyperparameters for building the model.

        Raises:
          ValueError: If mode is invalid.
        """
        super(FCModel, self).__init__()
        self.hparams = hparams
        #self.hidden_layer1 = tf.keras.layers.Dense(
        #    self.hparams.num_dense_units, activation=tf.keras.activations.relu)
        self.dense_layers = [
          tf.keras.layers.Dense(
              hparams.num_dense_units,
              activation=tf.keras.activations.relu)
          for i in range(hparams.num_dense_layers)
        ]
        self.output_layer = tf.keras.layers.Dense(1)
        
    def call(self, features, training=False):
      net = tf.expand_dims(features, -1)
      batch_size, length, depth = net.shape
      net = tf.reshape(net, [batch_size, length*depth])
      for dense in self.dense_layers:
        net = dense(net)
      net = self.output_layer(net)
      return tf.squeeze(net)

# @title Define RVLinearModel
class CNNModel(tf.keras.Model):
    """A TensorFlow linear regression model."""

    def __init__(self, hparams):
        """Basic setup.

        Args:
          hparams: A ConfigDict of hyperparameters for building the model.

        Raises:
          ValueError: If mode is invalid.
        """
        super(CNNModel, self).__init__()
        self.hparams = hparams
        self.conv_layers = [
          tf.keras.layers.Conv1D(
              filters=hparams.num_conv_filters, 
              kernel_size=hparams.conv_kernel_size,
              activation=tf.keras.activations.relu,
              padding="same")
          for i in range(hparams.num_conv_layers)
        ]
        self.dense_layers = [
          tf.keras.layers.Dense(
              hparams.num_dense_units,
              activation=tf.keras.activations.relu)
          for i in range(hparams.num_dense_layers)
        ]
        self.output_layer = tf.keras.layers.Dense(1)
        
    def call(self, features, training=False):
      net = tf.expand_dims(features, -1)
      for conv in self.conv_layers:
        net = conv(net)
      batch_size, length, depth = net.shape
      net = tf.reshape(net, [batch_size, length*depth])
      for dense in self.dense_layers:
        net = dense(net)
      net = self.output_layer(net)
      return tf.squeeze(net)

# %%
def make_predictions(model, dataset):
  all_preds = []
  all_labels = []
  all_bjds = []
  for features, labels, bjds in dataset:
    preds = model(features, training=False)
    all_preds.append(preds.numpy())
    all_labels.append(labels.numpy())
    all_bjds.append(bjds.numpy())
  return np.concatenate(all_labels), np.concatenate(all_preds), np.concatenate(all_bjds)

def train(model, hparams, plots, model_name, num_epochs):#=100):
  train_dataset = load_dataset([TRAIN_FILE_NAME], batch_size=hparams.batch_size, mode=tf.estimator.ModeKeys.TRAIN)
  val_dataset = load_dataset([VAL_FILE_NAME], batch_size=min(1024, NUM_VALIDATION_EXAMPLES), mode=tf.estimator.ModeKeys.EVAL)
  loss_fn = tf.keras.losses.MeanSquaredError(reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE)
  Opt = tfa.optimizers.extend_with_decoupled_weight_decay(tf.optimizers.SGD)
  optimizer = Opt(weight_decay=hparams.weight_decay, learning_rate=hparams.learning_rate, momentum=hparams.momentum)
  metrics = [
             tf.keras.metrics.MeanSquaredError("train_loss"),
             tf.keras.metrics.RootMeanSquaredError("train_rmse")
  ]
  weight_decay_list_t.append(hparams.weight_decay)
  gaussian_noise_list_t.append(hparams.gaussian_noise_scale)

  metric_values = []
  for epoch in range(1, num_epochs+1):
    # Reset metric values for each new epoch.
    for m in metrics:
      m.reset_states()

    # Train over all batches in the training set.
    for features, labels, bjds in train_dataset:
      if hparams.gaussian_noise_scale:
        features += tf.random.normal(features.shape, stddev=hparams.gaussian_noise_scale)
        #print(hparams.gaussian_noise_scale)
      # One training step.
      with tf.GradientTape() as t:
        preds = model(features, training=True)
        loss = loss_fn(labels, preds)
      grads = t.gradient(loss, model.trainable_variables)
      optimizer.apply_gradients(zip(grads, model.trainable_variables))
      # Update the metrics.
      for m in metrics:
        m(labels, preds)
    
    # End of an epoch.
    epoch_metrics = {"epoch": epoch}
    # First, log the training metrics.
    for m in metrics:
      epoch_metrics[m.name] = m.result().numpy()
    # Next, evaluate over the validation set.
    labels_val, preds_val, bjd_val = make_predictions(model, val_dataset)
    epoch_metrics["val_rmse"] = np.sqrt(np.mean(np.square(preds_val - labels_val)))
    # Add a metric for the raw scatter started with
    epoch_metrics["original_rmse"] = np.std(labels_val)
    # Add a metric for raw scatter - corrected scatter
    epoch_metrics["difference_rmse"] = np.std(labels_val) - np.sqrt(np.mean(np.square(preds_val - labels_val)))
    # Log metrics to tensorboard.
    for metric, value in epoch_metrics.items():
      tf.summary.scalar(metric, value, step=epoch)
    epoch_metrics["epoch"] = epoch
    # Print metric values at selected epochs.
    if epoch == 1 or epoch % 10 == 0 or epoch == num_epochs:
      print("{epoch}: Train loss: {train_loss:.4}, Train RMSE: {train_rmse:.4}, Val RMSE: {val_rmse:.4}".format(**epoch_metrics))
    metric_values.append(epoch_metrics)

  # Gather predictions
  labels, preds, bjd = make_predictions(model, train_dataset)
  labels_val, preds_val, bjd_val = make_predictions(model, val_dataset)
  all_bjds_val.append(bjd_val)
  bjd_run_val.append(bjd_val)
  all_pred_val.append(preds_val)
  pred_run_val.append(preds_val)
  all_labels_val.append(labels_val)
  labels_run_val.append(labels_val)

  # Scatter reduction plot
  sd_x = np.std(labels_val, ddof=1)
  rms_x = np.sqrt(np.mean(np.square(labels_val - preds_val)))
  rms_x_list.append(rms_x)
  rms_avg_list.append(rms_x)
  stel_removed = np.sqrt(np.abs(sd_x**2-rms_x**2))
  x_range = np.linspace(-4,5.5, 17)
  upper_bound = x_range+rms_x
  lower_bound = x_range-rms_x

  if plots=="ON":
    fig, axes = plt.subplots(1, 2, figsize=(24, 6))
    ax = axes[0]
    ax.plot([m["train_rmse"] for m in metric_values], label="Train RMSE")
    ax.plot([m["val_rmse"] for m in metric_values], label="Validation RMSE")
    ax.set_xlabel("Epoch")
    ax.legend(loc="upper right")

    # Gather predictions to plot against labels.
    ax = axes[1]
    ax.plot(preds, labels, ".", label="Training")
    ax.plot(preds_val, labels_val, ".", label="Validation")
    ax.set_xlabel("Actual Y")
    ax.set_ylabel("Predicted Y")
    ax.legend(loc="lower right")

    # plot the scatter reduction plot
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax1.plot(labels_val, preds_val, ".")
    ax1.plot(x_range,x_range, color="blue", label="1:1 ratio")
    #ax.plot(x_range,z[0]*x_range+z[1], color="blue")
    rms_fill=rms_x#0.15
    ax1.fill_between(x_range, x_range+rms_fill, x_range-rms_fill, facecolor='lightblue',
                    alpha=0.5, label="1 standard deviation")
    ax1.set_xlim(-4, 4);
    ax1.set_ylim(-4, 4);
    ax1.set_xlabel("HARPS-N Stellar Activity Signal (m/s)", size =16)
    ax1.set_ylabel("Model Predicted Stellar Activity Signal (m/s)", size =16)
    ax1.set_title(model_name+" Model Predictions of Stellar Activity signal(m/s)") #, %d epochs, weight decay: %.2e, gauss noise: %.2e " %(num_epochs, 
    #hparams.weight_decay, hparams.gaussian_noise_scale, size=16)
    textstr = '\n'.join((
        r'Raw scatter=%.3f m/s' % (sd_x, ),
        r'Corrected scatter=%.3f m/s' % (rms_x, ),
        r'Stellar Error Removed=%.3f m/s' % (stel_removed, )))
    ax1.text(-3.8, 3.5, textstr, size=15,
            ha="left", va="top",
            bbox=dict(boxstyle="square",
                      ec=(1., 0.5, 0.5),
                      fc=(1., 0.8, 0.8),
                      ))
    ax1.legend(loc="lower right")
  else:
    textstr = '\n'.join((
        r'Raw scatter=%.3f m/s' % (sd_x, ),
        r'Corrected scatter=%.3f m/s' % (rms_x, ),
        r'Stellar Error Removed=%.3f m/s' % (stel_removed, )))
    print(textstr)
    
  return metric_values

# %% [markdown]
# # Ridge Regression

# %%
class DatasetBuilder(object):
    """Dataset builder class."""

    def __init__(self, file_pattern, hparams, mode, ccf_len, repeat=1):
        """Initializes the dataset builder.
        Args:
          file_pattern: File pattern matching input file shards, e.g.
            "/tmp/train-?????-of-00100".
          hparams: A ConfigDict.
          mode: A tf.estimator.ModeKeys.
          repeat: The number of times to repeat the dataset. If None, the dataset
            will repeat indefinitely.
        """
        valid_modes = [
            tf.estimator.ModeKeys.TRAIN, tf.estimator.ModeKeys.EVAL,
            tf.estimator.ModeKeys.PREDICT
        ]
        if mode not in valid_modes:
            raise ValueError("Expected mode in {}. Got: {}".format(valid_modes, mode))

        self.file_pattern = file_pattern
        self.hparams = hparams
        self.mode = mode
        self.repeat = repeat
        self.ccf_len = ccf_len

    def __call__(self):
        is_training = self.mode == tf.estimator.ModeKeys.TRAIN

        # Dataset of file names.
        filename_dataset = tf.data.Dataset.list_files(self.file_pattern,
                                                      shuffle=is_training)

        # Dataset of serialized tf.Examples.
        dataset = filename_dataset.flat_map(tf.data.TFRecordDataset)

        # Shuffle in training mode.
        if is_training:
            dataset = dataset.shuffle(self.hparams.shuffle_values_buffer)

        # Possibly repeat.
        if self.repeat != 1:
            dataset = dataset.repeat(self.repeat)

        def _example_parser(serialized_example):
            """Parses a single tf.Example into feature and label tensors."""
            data_fields = {
                self.hparams.ccf_feature_name: tf.io.FixedLenFeature([self.ccf_len], tf.float32),
                self.hparams.label_feature_name: tf.io.FixedLenFeature([], tf.float32),
                self.hparams.label_feature_name2: tf.io.FixedLenFeature([], tf.float32),
            }
            parsed_fields = tf.io.parse_single_example(serialized_example, features=data_fields)
            ccf_data = parsed_fields[self.hparams.ccf_feature_name]
            label = parsed_fields[self.hparams.label_feature_name]
            label *= self.hparams.label_rescale_factor  # Rescale the label.
            label2 = parsed_fields[self.hparams.label_feature_name2]
            return {
                "ccf_data": ccf_data,
                "label": label,
                "bjd": label2,
            }

        # Map the parser over the dataset.
        dataset = dataset.map(_example_parser, num_parallel_calls=4)

        # Batch results by up to batch_size.
        dataset = dataset.batch(self.hparams.batch_size)

        # Prefetch a few batches.
        dataset = dataset.prefetch(10)

        return dataset

# %%
def load_dataset_ridge(filename, ccf_len):
  dataset_hparams = configdict.ConfigDict(dict(
    ccf_feature_name='Rescaled CCF_residuals_cutoff',#"Rescaled CCF_residuals", #CCF_residuals
    label_feature_name= "activity signal",#"RV",
    label_feature_name2= "BJD",
    batch_size=300,
    label_rescale_factor=1000,
  ))
  dataset = DatasetBuilder(filename, dataset_hparams, tf.estimator.ModeKeys.EVAL, ccf_len)()
  batches = list(dataset)
  ccf_data, labels, bjds = zip(*[(batch["ccf_data"], batch["label"], batch["bjd"]) for batch in batches])
  ccf_data = np.concatenate(ccf_data)
  labels = np.concatenate(labels)
  bjds = np.concatenate(bjds)
  assert len(ccf_data.shape) == 2
  assert len(labels.shape) == 1
  assert len(bjds.shape) == 1
  assert ccf_data.shape[0] == labels.shape[0]
  #print("Read dataset with {} examples".format(labels.shape[0]))
  return ccf_data, labels, bjds

# %%
def ridge_regress_harps(TRAIN_FILE_NAME_LIST, VAL_FILE_NAME_LIST, alpha, verbose, ccf_len):
  rms_avg_list = []
  weight_decay_list_t = []
  gaussian_noise_list_t = []
  rms_x_list = []

  all_bjds_val = []
  all_pred_val = []
  all_labels_val = []
  all_mean_val_preds = []
  all_mean_val_bjds = []
  all_mean_val_labels = []
  all_mean_val_bjds = []
  avg_list = []

  for index in range(0, len(VAL_FILE_NAME_LIST)):
    TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
    VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]
    train_X, train_Y, train_bjd  = load_dataset_ridge(TRAIN_FILE_NAME, ccf_len)
    val_X, val_Y, val_bjd = load_dataset_ridge(VAL_FILE_NAME, ccf_len)

    pred_run_val = []
    labels_run_val = []
    bjd_run_val = []
    for k in range(0,10):
      model = Ridge(alpha=alpha).fit(train_X, train_Y)
      val_pred_Y = model.predict(val_X)
      pred_run_val.append(val_pred_Y)
      labels_run_val.append(val_Y)
      bjd_run_val.append(val_bjd)
      rms_avg = np.sqrt(np.mean(np.square(val_Y -val_pred_Y)))
      rms_avg_list.append(rms_avg)
      if verbose == True:
        print(model)
        print("________________________")
        print("Cross-val number: "+str(index+1)+", Run number: "+str(k+1))
        print("rms: "+str(rms_avg))
      else:
        continue
    mean_val_preds = np.mean(pred_run_val, axis=0)
    mean_val_labels = np.mean(labels_run_val, axis=0)
    mean_val_bjds = np.mean(bjd_run_val, axis=0)
    all_mean_val_preds.append(mean_val_preds.tolist())
    all_mean_val_labels.append(mean_val_labels.tolist())
    all_mean_val_bjds.append(mean_val_bjds.tolist())
  avg = np.mean(rms_avg_list)
  avg_list.append(avg)
  print("________________________")
  print("average rms = "+str(avg)+" m/s")

  #flatten the lists
  all_mean_val_preds = [item for sublist in all_mean_val_preds for item in sublist]
  all_mean_val_labels = [item for sublist in all_mean_val_labels for item in sublist]
  all_mean_val_bjds = [item for sublist in all_mean_val_bjds for item in sublist]
  
  return all_mean_val_preds, all_mean_val_labels, all_mean_val_bjds, avg_list, alpha

# %%
# Cross validation Ridge Regression Model Run (10 times)

all_mean_val_preds, all_mean_val_labels, all_mean_val_bjds, avg_rms_list, alpha = ridge_regress_harps(TRAIN_FILE_NAME_LIST, 
                                                                                 VAL_FILE_NAME_LIST, 
                                                                                 alpha=3.6094,#340.010636,#9.469, #340.010636,	#335.734079,#9.469, 
                                                                                 verbose=False,
                                                                                 ccf_len = 46)
# Out:
# ________________________
# average rms = 1.0802236 m/s

# %%
df = pd.DataFrame(list(zip(all_mean_val_labels,all_mean_val_preds, all_mean_val_bjds)), 
               columns =['labels', 'preds', 'BJD']) 
df_sorted = df.sort_values(by=['BJD'])
#df_sorted.to_excel('gdrive/Shared drives/Exoplanet_RV/cross_val_preds/val_preds_ridge_06_30_2021.xlsx', index = False)

# calculation of scatter removed
from astropy.stats import median_absolute_deviation

#df_sorted = df_from_excel
labels_68_percent_by_2 = (np.percentile(df_sorted["labels"], 84)-np.percentile(df_sorted["labels"], 16))/2
labels_median_absolute_deviation_norm = median_absolute_deviation(df_sorted["labels"])*1.4826
preds_68_percent_by_2 = (np.percentile(df_sorted["preds"], 84)-np.percentile(df_sorted["preds"], 16))/2

corrected_rvs = df_sorted["labels"]-df_sorted["preds"]
corrected_rvs_68_percent_by_2 = (np.percentile(corrected_rvs, 84)-np.percentile(corrected_rvs, 16))/2
corrected_rvs_median_absolute_deviation_norm = median_absolute_deviation(corrected_rvs)*1.4826

sd_labels = np.std(df_sorted["labels"], ddof=1)
sd_corrected_rv = np.std(corrected_rvs, ddof=1)
rms_x = np.sqrt(np.mean(np.square(df_sorted["labels"] - df_sorted["preds"])))


print("labels: sd: "+str(sd_labels))
print("corrected rv: sd: "+str(sd_corrected_rv))
print("____________________________________________")
print("labels: MAD*1.4826: "+str(labels_median_absolute_deviation_norm))
print("corrected rv: MAD*1.4826: "+str(corrected_rvs_median_absolute_deviation_norm))
print("____________________________________________")
print("labels: 68 percent/2: "+str(labels_68_percent_by_2))
print("corrected rv: 68 percent/2: "+str(corrected_rvs_68_percent_by_2))


# plot the average results
# Scatter reduction plot
rms_avg_list = []
sd_x = np.std(all_mean_val_labels, ddof=1)
rms_x = np.sqrt(np.mean(np.square(all_mean_val_labels - np.array(all_mean_val_preds))))
#rms_x_list.append(rms_x)
rms_avg_list.append(rms_x)
stel_removed = np.sqrt(np.abs(sd_x**2-rms_x**2))
x_range = np.linspace(-4,5.5, 17)
upper_bound = x_range+rms_x
lower_bound = x_range-rms_x

# plot the scatter reduction plot
fig, ax = plt.subplots(1, 2, figsize=(21, 6))
ax1 = ax[0]
ax1.plot(df_sorted["labels"], df_sorted["preds"], ".")
ax1.plot(x_range,x_range, color="blue", label="1:1 ratio")
#ax.plot(x_range,z[0]*x_range+z[1], color="blue")
rms_fill=rms_x#0.15
ax1.fill_between(x_range, x_range+rms_fill, x_range-rms_fill, facecolor='lightblue',
                alpha=0.5, label="1 standard deviation")
ax1.set_xlim(-4, 5);
ax1.set_ylim(-4, 5);
ax1.set_xlabel("HARPS-N Stellar Activity Signal (m/s)", size =16)
ax1.set_ylabel("Model Predicted Stellar Activity Signal (m/s)", size =16)
ax1.set_title("Ridge Regression Predictions of Stellar Activity signal(m/s)") #, %d epochs, weight decay: %.2e, gauss noise: %.2e " %(num_epochs, 
#hparams.weight_decay, hparams.gaussian_noise_scale, size=16)
textstr = '\n'.join((
    r'Raw scatter=%.3f m/s' % (sd_labels, ),
    r'Corrected scatter=%.3f m/s' % (sd_corrected_rv, ),
    r'Stellar Error Removed=%.3f m/s' % (stel_removed, )))
ax1.text(-3.8, 4.5, textstr, size=15,
        ha="left", va="top",
        bbox=dict(facecolor='#fdcf44',edgecolor='k',
                  boxstyle="square",
                  #ec=(1., 0.5, 0.5),
                  #fc=(1., 0.8, 0.8),
                  ))
ax1.legend(loc="lower right")

# plot predictions over time
ax2 = ax[1]
ax2.plot(df_sorted["BJD"], df_sorted["labels"], ".",color='k',
         markersize=10,label="labels")
ax2.plot(df_sorted["BJD"], df_sorted["preds"], ".", markersize=10,
         label="preds")
ax2.set_xlabel("Time (BJD)")
ax2.set_ylabel("RV (m/s)")
ax2.legend(loc="lower right")
# Out:
# labels: sd: 1.8284893224673766
# corrected rv: sd: 1.0849636105498959
# ____________________________________________
# labels: MAD*1.4826: 1.7439013288736342
# corrected rv: MAD*1.4826: 1.0854544334962963
# ____________________________________________
# labels: 68 percent/2: 1.7452755212783813
# corrected rv: 68 percent/2: 1.0970001339912414

# %%
index=0
TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]
train_X, train_Y, train_bjd  = load_dataset_ridge(TRAIN_FILE_NAME, 46)
val_X, val_Y, val_bjd = load_dataset_ridge(VAL_FILE_NAME, 46)
model = Ridge(alpha=alpha).fit(train_X, train_Y)
x_axis = np.linspace(-19.58, 19.78, 49)[2:48]
plt.plot(x_axis, model.coef_, ".")
plt.ylabel("Weight")
plt.xlabel("RV (km/s)")
plt.xlim(-20, 20)
# Out:
# (-20.0, 20.0)

# %%
# Alpha cross-val runs

# Cross validation Ridge Regression Model Run (10 times)
alpha_range = np.random.uniform(2, 5.5, 100)
#alpha_range = np.append(alpha_range, 9.469)

alpha_list = []
rms_crossval_list = []
for alpha in tqdm(alpha_range):
  all_mean_val_preds, all_mean_val_labels, all_mean_val_bjds, avg_rms_list, alpha = ridge_regress_harps(TRAIN_FILE_NAME_LIST, 
                                                                                  VAL_FILE_NAME_LIST, 
                                                                                  alpha=alpha, 
                                                                                  verbose=False,
                                                                                  ccf_len= 46)
  # compute rms across all crossval slice
  rms_crossval = np.mean(avg_rms_list)
  rms_crossval_list.append(rms_crossval)
  alpha_list.append(alpha)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ________________________
# average rms = 1.0806684 m/s
# ________________________
# average rms = 1.0806518 m/s
# ________________________
# average rms = 1.0804646 m/s
# ________________________
# average rms = 1.0812771 m/s
# ________________________
# average rms = 1.0803189 m/s
# ________________________
# average rms = 1.0817534 m/s
# ________________________
# average rms = 1.0805019 m/s
# ________________________
# average rms = 1.0811146 m/s
# ________________________
# average rms = 1.0804687 m/s
# ________________________
# average rms = 1.0813707 m/s
# ________________________
# average rms = 1.080223 m/s
# ________________________
# average rms = 1.0803183 m/s
# ________________________
# average rms = 1.0805316 m/s
# ________________________
# average rms = 1.0817243 m/s
# ________________________
# average rms = 1.0802253 m/s
# ________________________
# average rms = 1.0810616 m/s
# ________________________
# average rms = 1.0802478 m/s
# ________________________
# average rms = 1.0807314 m/s
# ________________________
# average rms = 1.0805129 m/s
# ________________________
# average rms = 1.0802238 m/s
# ________________________
# average rms = 1.0805748 m/s
# ________________________
# average rms = 1.0802258 m/s
# ________________________
# average rms = 1.0803778 m/s
# ________________________
# average rms = 1.0814927 m/s
# ________________________
# average rms = 1.0807359 m/s
# ________________________
# average rms = 1.080331 m/s
# ________________________
# average rms = 1.0805173 m/s
# ________________________
# average rms = 1.0802922 m/s
# ________________________
# average rms = 1.0802295 m/s
# ________________________
# average rms = 1.0811745 m/s
# ________________________
# average rms = 1.0804696 m/s
# ________________________
# average rms = 1.0802411 m/s
# ________________________
# average rms = 1.0803182 m/s
# ________________________
# average rms = 1.0802366 m/s
# ________________________
# average rms = 1.0805284 m/s
# ________________________
# average rms = 1.0803167 m/s
# ________________________
# average rms = 1.0805602 m/s
# ________________________
# average rms = 1.081156 m/s
# ________________________
# average rms = 1.0811381 m/s
# ________________________
# average rms = 1.0808041 m/s
# ________________________
# average rms = 1.080605 m/s
# ________________________
# average rms = 1.0802732 m/s
# ________________________
# average rms = 1.0804154 m/s
# ________________________
# average rms = 1.0808657 m/s
# ________________________
# average rms = 1.0802304 m/s
# ________________________
# average rms = 1.0802234 m/s
# ________________________
# average rms = 1.0805148 m/s
# ________________________
# average rms = 1.0803378 m/s
# ________________________
# average rms = 1.0806884 m/s
# ________________________
# average rms = 1.081071 m/s
# ________________________
# average rms = 1.080873 m/s
# ________________________
# average rms = 1.0802314 m/s
# ________________________
# average rms = 1.0802425 m/s
# ________________________
# average rms = 1.0805539 m/s
# ________________________
# average rms = 1.0805047 m/s
# ________________________
# average rms = 1.0802236 m/s
# ________________________
# average rms = 1.0803022 m/s
# ________________________
# average rms = 1.0802379 m/s
# ________________________
# average rms = 1.0806971 m/s
# ________________________
# average rms = 1.0802231 m/s
# ________________________
# average rms = 1.0808526 m/s
# ________________________
# average rms = 1.0802977 m/s
# ________________________
# average rms = 1.0815223 m/s
# ________________________
# average rms = 1.080465 m/s
# ________________________
# average rms = 1.080951 m/s
# ________________________
# average rms = 1.0804262 m/s
# ________________________
# average rms = 1.0810313 m/s
# ________________________
# average rms = 1.080873 m/s
# ________________________
# average rms = 1.0802649 m/s
# ________________________
# average rms = 1.0804249 m/s
# ________________________
# average rms = 1.0805956 m/s
# ________________________
# average rms = 1.0805386 m/s
# ________________________
# average rms = 1.0807824 m/s
# ________________________
# average rms = 1.0805066 m/s
# ________________________
# average rms = 1.0817318 m/s
# ________________________
# average rms = 1.0803595 m/s
# ________________________
# average rms = 1.0803603 m/s
# ________________________
# average rms = 1.0811594 m/s
# ________________________
# average rms = 1.0805068 m/s
# ________________________
# average rms = 1.0808883 m/s
# ________________________
# average rms = 1.0804511 m/s
# ________________________
# average rms = 1.0815115 m/s
# ________________________
# average rms = 1.0804788 m/s
# ________________________
# average rms = 1.081099 m/s
# ________________________
# average rms = 1.0803294 m/s
# ________________________
# average rms = 1.0807437 m/s
# ________________________
# average rms = 1.0811436 m/s
# ________________________
# average rms = 1.0803543 m/s
# ________________________
# average rms = 1.0808276 m/s
# ________________________
# average rms = 1.0817925 m/s
# ________________________
# average rms = 1.0805283 m/s
# ________________________
# average rms = 1.0809523 m/s
# ________________________
# average rms = 1.0802712 m/s
# ________________________
# average rms = 1.080237 m/s
# ________________________
# average rms = 1.0802281 m/s
# ________________________
# average rms = 1.0807924 m/s
# ________________________
# average rms = 1.0818022 m/s
# ________________________
# average rms = 1.080561 m/s
# ________________________
# average rms = 1.0802234 m/s
# ________________________
# average rms = 1.0806419 m/s

# %%
df_rms = pd.DataFrame(list(zip(alpha_list, rms_crossval_list)), 
               columns =['alpha_list', 'avg_rms_list'])
df_rms_sorted = df_rms.sort_values(by=['avg_rms_list'])

folder = 'ridge_crossval_preds/'

if not os.path.isdir(folder):
        os.mkdir(folder)
        
df_rms_sorted.to_csv(folder+'alpha_rms_linear_12_6.csv', index = False)

# %%
df_rms_sorted =pd.read_csv(folder+'alpha_rms_linear_12_6.csv')

fig, ax = plt.subplots(1, 1, figsize=(8, 4))
plt.plot(df_rms_sorted["alpha_list"],df_rms_sorted["avg_rms_list"], ".", color='purple',
         markersize=9)
plt.title("Linear Model Performance as a Function of Alpha")
plt.xlabel("Alpha Value")
plt.ylabel("RMS (m/s)")
#plt.xlim(0, 20)
#plt.ylim(0.94, 0.95)

df_rms_sorted["alpha_list"][np.argmin(np.array(df_rms_sorted["avg_rms_list"]))]
# Out:
# 3.6602968950822814

# %%
# best alpha value
df_rms_sorted["alpha_list"][np.argmin(np.array(df_rms_sorted["avg_rms_list"]))]
# Out:
# 3.6602968950822814

# %% [markdown]
# ## FC NN Model Run

# %%
  # FC NN Model run

  # Cross validation Linear NN Model Run (10 times)
  rms_avg_list = []
  weight_decay_list_t = []
  gaussian_noise_list_t = []
  rms_x_list = []

  all_bjds_val = []
  all_pred_val = []
  all_labels_val = []
  all_mean_val_preds = []
  all_mean_val_bjds = []
  all_mean_val_labels = []
  all_mean_val_bjds = []

  for index in range(0, len(VAL_FILE_NAME_LIST)):
    TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
    VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]
    bjd_run_val = []
    pred_run_val = []
    labels_run_val = []
    for k in range(0,10): #should be 10 for a full run
      hparams = configdict.ConfigDict(dict(
          num_features=152,#161,
          learning_rate=0.0043815, #0.0095352,#0.0016077,
          momentum=0.9,
          batch_size=300,
          num_dense_units=500,#200,
          num_dense_layers=4,
          weight_decay=0.00024022,#0.00010000, #5e-4, #7e-2,
          gaussian_noise_scale=0,#1.5, 
      ))
      model = FCModel(hparams)
      train(model, hparams, plots="OFF",model_name="FC NN", num_epochs=50)
      print(model)
      print("________________________")
      print("Cross-val number: "+str(index+1)+", Run number: "+str(k+1))
    mean_val_preds = np.mean(pred_run_val, axis=0)
    mean_val_labels = np.mean(labels_run_val, axis=0)
    mean_val_bjds = np.mean(bjd_run_val, axis=0)
    all_mean_val_preds.append(mean_val_preds.tolist())
    all_mean_val_labels.append(mean_val_labels.tolist())
    all_mean_val_bjds.append(mean_val_bjds.tolist())
  avg = np.mean(rms_avg_list)
  print("________________________")
  print(avg)

  #flatten the lists
  all_mean_val_preds = [item for sublist in all_mean_val_preds for item in sublist]
  all_mean_val_labels = [item for sublist in all_mean_val_labels for item in sublist]
  all_mean_val_bjds = [item for sublist in all_mean_val_bjds for item in sublist]
# Out:
# 1: Train loss: 3.331, Train RMSE: 1.877, Val RMSE: 1.525
# 10: Train loss: 1.382, Train RMSE: 1.19, Val RMSE: 1.231
# 20: Train loss: 1.069, Train RMSE: 1.0, Val RMSE: 1.163
# 30: Train loss: 0.611, Train RMSE: 0.8142, Val RMSE: 1.203
# 40: Train loss: 0.4136, Train RMSE: 0.6298, Val RMSE: 1.181
# 50: Train loss: 0.2418, Train RMSE: 0.5083, Val RMSE: 1.207
# Raw scatter=1.590 m/s
# Corrected scatter=1.207 m/s
# Stellar Error Removed=1.035 m/s
# <__main__.FCModel object at 0x7fca0182b8d0>
# ________________________
# Cross-val number: 1, Run number: 1
# 1: Train loss: 3.543, Train RMSE: 1.872, Val RMSE: 1.536
# 10: Train loss: 1.435, Train RMSE: 1.197, Val RMSE: 1.176
# 20: Train loss: 0.9347, Train RMSE: 0.9583, Val RMSE: 1.167
# 30: Train loss: 0.7621, Train RMSE: 0.804, Val RMSE: 1.283
# 40: Train loss: 0.4106, Train RMSE: 0.6388, Val RMSE: 1.317
# 50: Train loss: 0.229, Train RMSE: 0.5008, Val RMSE: 1.279
# Raw scatter=1.590 m/s
# Corrected scatter=1.279 m/s
# Stellar Error Removed=0.945 m/s
# <__main__.FCModel object at 0x7fca01a9b450>
# ________________________
# Cross-val number: 1, Run number: 2
# 1: Train loss: 3.222, Train RMSE: 1.864, Val RMSE: 1.549
# 10: Train loss: 1.38, Train RMSE: 1.177, Val RMSE: 1.252
# 20: Train loss: 0.8957, Train RMSE: 0.9913, Val RMSE: 1.184
# 30: Train loss: 0.6974, Train RMSE: 0.828, Val RMSE: 1.198
# 40: Train loss: 0.4094, Train RMSE: 0.6301, Val RMSE: 1.188
# 50: Train loss: 0.239, Train RMSE: 0.4863, Val RMSE: 1.234
# Raw scatter=1.590 m/s
# Corrected scatter=1.234 m/s
# Stellar Error Removed=1.003 m/s
# <__main__.FCModel object at 0x7fca15a01e10>
# ________________________
# Cross-val number: 1, Run number: 3
# 1: Train loss: 3.314, Train RMSE: 1.856, Val RMSE: 1.522
# 10: Train loss: 1.484, Train RMSE: 1.183, Val RMSE: 1.192
# 20: Train loss: 0.9964, Train RMSE: 0.952, Val RMSE: 1.187
# 30: Train loss: 0.6374, Train RMSE: 0.7842, Val RMSE: 1.239
# 40: Train loss: 0.3936, Train RMSE: 0.6242, Val RMSE: 1.176
# 50: Train loss: 0.2298, Train RMSE: 0.4803, Val RMSE: 1.18
# Raw scatter=1.590 m/s
# Corrected scatter=1.180 m/s
# Stellar Error Removed=1.066 m/s
# <__main__.FCModel object at 0x7fca15a7ac50>
# ________________________
# Cross-val number: 1, Run number: 4
# 1: Train loss: 3.087, Train RMSE: 1.771, Val RMSE: 1.463
# 10: Train loss: 1.534, Train RMSE: 1.221, Val RMSE: 1.217
# 20: Train loss: 0.944, Train RMSE: 0.9752, Val RMSE: 1.22
# 30: Train loss: 0.6372, Train RMSE: 0.8159, Val RMSE: 1.23
# 40: Train loss: 0.3928, Train RMSE: 0.6313, Val RMSE: 1.262
# 50: Train loss: 0.2195, Train RMSE: 0.4901, Val RMSE: 1.221
# Raw scatter=1.590 m/s
# Corrected scatter=1.221 m/s
# Stellar Error Removed=1.019 m/s
# <__main__.FCModel object at 0x7fca15a4a790>
# ________________________
# Cross-val number: 1, Run number: 5
# 1: Train loss: 3.435, Train RMSE: 1.884, Val RMSE: 1.502
# 10: Train loss: 1.441, Train RMSE: 1.184, Val RMSE: 1.235
# 20: Train loss: 0.8805, Train RMSE: 0.9597, Val RMSE: 1.176
# 30: Train loss: 0.6322, Train RMSE: 0.7864, Val RMSE: 1.187
# 40: Train loss: 0.3551, Train RMSE: 0.6401, Val RMSE: 1.228
# 50: Train loss: 0.2598, Train RMSE: 0.5021, Val RMSE: 1.291
# Raw scatter=1.590 m/s
# Corrected scatter=1.291 m/s
# Stellar Error Removed=0.929 m/s
# <__main__.FCModel object at 0x7fca47f01910>
# ________________________
# Cross-val number: 1, Run number: 6
# 1: Train loss: 3.226, Train RMSE: 1.906, Val RMSE: 1.54
# 10: Train loss: 1.392, Train RMSE: 1.22, Val RMSE: 1.182
# 20: Train loss: 0.984, Train RMSE: 0.9717, Val RMSE: 1.177
# 30: Train loss: 0.5878, Train RMSE: 0.7902, Val RMSE: 1.222
# 40: Train loss: 0.3622, Train RMSE: 0.6164, Val RMSE: 1.199
# 50: Train loss: 0.2358, Train RMSE: 0.498, Val RMSE: 1.18
# Raw scatter=1.590 m/s
# Corrected scatter=1.180 m/s
# Stellar Error Removed=1.066 m/s
# <__main__.FCModel object at 0x7fca15ab2590>
# ________________________
# Cross-val number: 1, Run number: 7
# 1: Train loss: 3.327, Train RMSE: 1.827, Val RMSE: 1.486
# 10: Train loss: 1.317, Train RMSE: 1.17, Val RMSE: 1.192
# 20: Train loss: 0.8938, Train RMSE: 0.9536, Val RMSE: 1.211
# 30: Train loss: 0.6072, Train RMSE: 0.763, Val RMSE: 1.221
# 40: Train loss: 0.4056, Train RMSE: 0.6022, Val RMSE: 1.233
# 50: Train loss: 0.2139, Train RMSE: 0.452, Val RMSE: 1.257
# Raw scatter=1.590 m/s
# Corrected scatter=1.257 m/s
# Stellar Error Removed=0.975 m/s
# <__main__.FCModel object at 0x7fca77ae35d0>
# ________________________
# Cross-val number: 1, Run number: 8
# 1: Train loss: 3.319, Train RMSE: 1.89, Val RMSE: 1.515
# 10: Train loss: 1.492, Train RMSE: 1.218, Val RMSE: 1.254
# 20: Train loss: 0.9896, Train RMSE: 0.9992, Val RMSE: 1.15
# 30: Train loss: 0.6674, Train RMSE: 0.8205, Val RMSE: 1.223
# 40: Train loss: 0.4137, Train RMSE: 0.6565, Val RMSE: 1.226
# 50: Train loss: 0.2735, Train RMSE: 0.5149, Val RMSE: 1.168
# Raw scatter=1.590 m/s
# Corrected scatter=1.168 m/s
# Stellar Error Removed=1.080 m/s
# <__main__.FCModel object at 0x7fca15b8fe50>
# ________________________
# Cross-val number: 1, Run number: 9
# 1: Train loss: 3.52, Train RMSE: 1.892, Val RMSE: 1.514
# 10: Train loss: 1.321, Train RMSE: 1.176, Val RMSE: 1.183
# 20: Train loss: 0.8467, Train RMSE: 0.9601, Val RMSE: 1.14
# 30: Train loss: 0.5898, Train RMSE: 0.7821, Val RMSE: 1.165
# 40: Train loss: 0.4417, Train RMSE: 0.6935, Val RMSE: 1.34
# 50: Train loss: 0.246, Train RMSE: 0.4899, Val RMSE: 1.224
# Raw scatter=1.590 m/s
# Corrected scatter=1.224 m/s
# Stellar Error Removed=1.016 m/s
# <__main__.FCModel object at 0x7fca01acf890>
# ________________________
# Cross-val number: 1, Run number: 10
# 1: Train loss: 3.329, Train RMSE: 1.791, Val RMSE: 1.724
# 10: Train loss: 1.345, Train RMSE: 1.177, Val RMSE: 1.423
# 20: Train loss: 0.8929, Train RMSE: 0.9732, Val RMSE: 1.34
# 30: Train loss: 0.6583, Train RMSE: 0.827, Val RMSE: 1.316
# 40: Train loss: 0.4034, Train RMSE: 0.6767, Val RMSE: 1.288
# 50: Train loss: 0.3436, Train RMSE: 0.557, Val RMSE: 1.297
# Raw scatter=1.861 m/s
# Corrected scatter=1.297 m/s
# Stellar Error Removed=1.334 m/s
# <__main__.FCModel object at 0x7fca01b154d0>
# ________________________
# Cross-val number: 2, Run number: 1
# 1: Train loss: 3.47, Train RMSE: 1.813, Val RMSE: 1.712
# 10: Train loss: 1.303, Train RMSE: 1.172, Val RMSE: 1.436
# 20: Train loss: 0.9476, Train RMSE: 0.9619, Val RMSE: 1.313
# 30: Train loss: 0.6904, Train RMSE: 0.8176, Val RMSE: 1.258
# 40: Train loss: 0.4106, Train RMSE: 0.6526, Val RMSE: 1.268
# 50: Train loss: 0.3411, Train RMSE: 0.5382, Val RMSE: 1.209
# Raw scatter=1.861 m/s
# Corrected scatter=1.209 m/s
# Stellar Error Removed=1.414 m/s
# <__main__.FCModel object at 0x7fc9f00135d0>
# ________________________
# Cross-val number: 2, Run number: 2
# 1: Train loss: 3.545, Train RMSE: 1.871, Val RMSE: 1.742
# 10: Train loss: 1.372, Train RMSE: 1.19, Val RMSE: 1.421
# 20: Train loss: 0.9043, Train RMSE: 0.9623, Val RMSE: 1.379
# 30: Train loss: 0.658, Train RMSE: 0.8013, Val RMSE: 1.319
# 40: Train loss: 0.3864, Train RMSE: 0.6543, Val RMSE: 1.371
# 50: Train loss: 0.2634, Train RMSE: 0.5116, Val RMSE: 1.33
# Raw scatter=1.861 m/s
# Corrected scatter=1.330 m/s
# Stellar Error Removed=1.301 m/s
# <__main__.FCModel object at 0x7fca77beae10>
# ________________________
# Cross-val number: 2, Run number: 3
# 1: Train loss: 3.22, Train RMSE: 1.837, Val RMSE: 1.753
# 10: Train loss: 1.317, Train RMSE: 1.149, Val RMSE: 1.411
# 20: Train loss: 0.9381, Train RMSE: 0.9605, Val RMSE: 1.348
# 30: Train loss: 0.6353, Train RMSE: 0.8046, Val RMSE: 1.281
# 40: Train loss: 0.4153, Train RMSE: 0.6475, Val RMSE: 1.286
# 50: Train loss: 0.275, Train RMSE: 0.5109, Val RMSE: 1.298
# Raw scatter=1.861 m/s
# Corrected scatter=1.298 m/s
# Stellar Error Removed=1.333 m/s
# <__main__.FCModel object at 0x7fca01ba4bd0>
# ________________________
# Cross-val number: 2, Run number: 4
# 1: Train loss: 3.058, Train RMSE: 1.791, Val RMSE: 1.746
# 10: Train loss: 1.386, Train RMSE: 1.177, Val RMSE: 1.381
# 20: Train loss: 1.016, Train RMSE: 0.9753, Val RMSE: 1.33
# 30: Train loss: 0.6261, Train RMSE: 0.8172, Val RMSE: 1.227
# 40: Train loss: 0.5835, Train RMSE: 0.7657, Val RMSE: 1.273
# 50: Train loss: 0.2821, Train RMSE: 0.5399, Val RMSE: 1.205
# Raw scatter=1.861 m/s
# Corrected scatter=1.205 m/s
# Stellar Error Removed=1.417 m/s
# <__main__.FCModel object at 0x7fca15c14890>
# ________________________
# Cross-val number: 2, Run number: 5
# 1: Train loss: 3.498, Train RMSE: 1.869, Val RMSE: 1.799
# 10: Train loss: 1.316, Train RMSE: 1.175, Val RMSE: 1.448
# 20: Train loss: 0.881, Train RMSE: 0.9842, Val RMSE: 1.361
# 30: Train loss: 0.6467, Train RMSE: 0.829, Val RMSE: 1.292
# 40: Train loss: 0.4176, Train RMSE: 0.6742, Val RMSE: 1.339
# 50: Train loss: 0.4004, Train RMSE: 0.6069, Val RMSE: 1.278
# Raw scatter=1.861 m/s
# Corrected scatter=1.278 m/s
# Stellar Error Removed=1.352 m/s
# <__main__.FCModel object at 0x7fca15c22f50>
# ________________________
# Cross-val number: 2, Run number: 6
# 1: Train loss: 3.359, Train RMSE: 1.85, Val RMSE: 1.762
# 10: Train loss: 1.361, Train RMSE: 1.158, Val RMSE: 1.427
# 20: Train loss: 0.8855, Train RMSE: 0.9539, Val RMSE: 1.339
# 30: Train loss: 0.6142, Train RMSE: 0.814, Val RMSE: 1.274
# 40: Train loss: 0.4255, Train RMSE: 0.6521, Val RMSE: 1.286
# 50: Train loss: 0.2785, Train RMSE: 0.5241, Val RMSE: 1.3
# Raw scatter=1.861 m/s
# Corrected scatter=1.300 m/s
# Stellar Error Removed=1.331 m/s
# <__main__.FCModel object at 0x7fca15c45490>
# ________________________
# Cross-val number: 2, Run number: 7
# 1: Train loss: 3.146, Train RMSE: 1.77, Val RMSE: 1.707
# 10: Train loss: 1.353, Train RMSE: 1.168, Val RMSE: 1.381
# 20: Train loss: 0.9103, Train RMSE: 0.9572, Val RMSE: 1.359
# 30: Train loss: 0.6429, Train RMSE: 0.8031, Val RMSE: 1.369
# 40: Train loss: 0.46, Train RMSE: 0.6598, Val RMSE: 1.352
# 50: Train loss: 0.2607, Train RMSE: 0.5241, Val RMSE: 1.31
# Raw scatter=1.861 m/s
# Corrected scatter=1.310 m/s
# Stellar Error Removed=1.322 m/s
# <__main__.FCModel object at 0x7fca01bd3d90>
# ________________________
# Cross-val number: 2, Run number: 8
# 1: Train loss: 3.503, Train RMSE: 1.828, Val RMSE: 1.76
# 10: Train loss: 1.46, Train RMSE: 1.195, Val RMSE: 1.442
# 20: Train loss: 0.9069, Train RMSE: 0.9878, Val RMSE: 1.321
# 30: Train loss: 0.6671, Train RMSE: 0.8303, Val RMSE: 1.301
# 40: Train loss: 0.4947, Train RMSE: 0.683, Val RMSE: 1.258
# 50: Train loss: 0.3711, Train RMSE: 0.5911, Val RMSE: 1.291
# Raw scatter=1.861 m/s
# Corrected scatter=1.291 m/s
# Stellar Error Removed=1.340 m/s
# <__main__.FCModel object at 0x7fc9f0054c50>
# ________________________
# Cross-val number: 2, Run number: 9
# 1: Train loss: 2.986, Train RMSE: 1.805, Val RMSE: 1.732
# 10: Train loss: 1.489, Train RMSE: 1.165, Val RMSE: 1.42
# 20: Train loss: 1.0, Train RMSE: 0.9739, Val RMSE: 1.328
# 30: Train loss: 0.687, Train RMSE: 0.8106, Val RMSE: 1.253
# 40: Train loss: 0.4103, Train RMSE: 0.6516, Val RMSE: 1.294
# 50: Train loss: 0.256, Train RMSE: 0.5263, Val RMSE: 1.261
# Raw scatter=1.861 m/s
# Corrected scatter=1.261 m/s
# Stellar Error Removed=1.368 m/s
# <__main__.FCModel object at 0x7fca77c12150>
# ________________________
# Cross-val number: 2, Run number: 10
# 1: Train loss: 3.436, Train RMSE: 1.807, Val RMSE: 1.91
# 10: Train loss: 1.498, Train RMSE: 1.194, Val RMSE: 1.283
# 20: Train loss: 0.969, Train RMSE: 0.9957, Val RMSE: 1.07
# 30: Train loss: 0.5968, Train RMSE: 0.7992, Val RMSE: 0.9989
# 40: Train loss: 0.3927, Train RMSE: 0.6349, Val RMSE: 0.9994
# 50: Train loss: 0.2648, Train RMSE: 0.5172, Val RMSE: 0.9572
# Raw scatter=2.087 m/s
# Corrected scatter=0.957 m/s
# Stellar Error Removed=1.855 m/s
# <__main__.FCModel object at 0x7fc9f0163190>
# ________________________
# Cross-val number: 3, Run number: 1
# 1: Train loss: 2.762, Train RMSE: 1.75, Val RMSE: 1.891
# 10: Train loss: 1.503, Train RMSE: 1.192, Val RMSE: 1.249
# 20: Train loss: 0.8938, Train RMSE: 0.9869, Val RMSE: 1.073
# 30: Train loss: 0.6251, Train RMSE: 0.809, Val RMSE: 0.962
# 40: Train loss: 0.401, Train RMSE: 0.6397, Val RMSE: 0.9669
# 50: Train loss: 0.2497, Train RMSE: 0.4852, Val RMSE: 1.021
# Raw scatter=2.087 m/s
# Corrected scatter=1.021 m/s
# Stellar Error Removed=1.820 m/s
# <__main__.FCModel object at 0x7fca01cf1610>
# ________________________
# Cross-val number: 3, Run number: 2
# 1: Train loss: 2.931, Train RMSE: 1.784, Val RMSE: 1.896
# 10: Train loss: 1.306, Train RMSE: 1.171, Val RMSE: 1.222
# 20: Train loss: 0.9115, Train RMSE: 0.9691, Val RMSE: 1.025
# 30: Train loss: 0.6514, Train RMSE: 0.7835, Val RMSE: 1.045
# 40: Train loss: 0.4019, Train RMSE: 0.6639, Val RMSE: 1.043
# 50: Train loss: 0.1911, Train RMSE: 0.4528, Val RMSE: 1.007
# Raw scatter=2.087 m/s
# Corrected scatter=1.007 m/s
# Stellar Error Removed=1.828 m/s
# <__main__.FCModel object at 0x7fca15be2e10>
# ________________________
# Cross-val number: 3, Run number: 3
# 1: Train loss: 3.094, Train RMSE: 1.755, Val RMSE: 1.899
# 10: Train loss: 1.434, Train RMSE: 1.192, Val RMSE: 1.252
# 20: Train loss: 0.9358, Train RMSE: 0.9869, Val RMSE: 1.053
# 30: Train loss: 0.6405, Train RMSE: 0.8128, Val RMSE: 0.9765
# 40: Train loss: 0.4389, Train RMSE: 0.6729, Val RMSE: 1.047
# 50: Train loss: 0.3099, Train RMSE: 0.5445, Val RMSE: 1.055
# Raw scatter=2.087 m/s
# Corrected scatter=1.055 m/s
# Stellar Error Removed=1.801 m/s
# <__main__.FCModel object at 0x7fca01d12fd0>
# ________________________
# Cross-val number: 3, Run number: 4
# 1: Train loss: 3.035, Train RMSE: 1.783, Val RMSE: 1.9
# 10: Train loss: 1.393, Train RMSE: 1.182, Val RMSE: 1.252
# 20: Train loss: 0.9424, Train RMSE: 0.9913, Val RMSE: 1.073
# 30: Train loss: 0.705, Train RMSE: 0.8362, Val RMSE: 1.034
# 40: Train loss: 0.3748, Train RMSE: 0.6407, Val RMSE: 1.027
# 50: Train loss: 0.2567, Train RMSE: 0.4895, Val RMSE: 0.9857
# Raw scatter=2.087 m/s
# Corrected scatter=0.986 m/s
# Stellar Error Removed=1.840 m/s
# <__main__.FCModel object at 0x7fca01cfd650>
# ________________________
# Cross-val number: 3, Run number: 5
# 1: Train loss: 3.211, Train RMSE: 1.801, Val RMSE: 1.95
# 10: Train loss: 1.553, Train RMSE: 1.168, Val RMSE: 1.229
# 20: Train loss: 0.9506, Train RMSE: 0.9757, Val RMSE: 1.016
# 30: Train loss: 0.6762, Train RMSE: 0.8015, Val RMSE: 0.9804
# 40: Train loss: 0.3883, Train RMSE: 0.6502, Val RMSE: 1.105
# 50: Train loss: 0.2581, Train RMSE: 0.4933, Val RMSE: 0.9999
# Raw scatter=2.087 m/s
# Corrected scatter=1.000 m/s
# Stellar Error Removed=1.832 m/s
# <__main__.FCModel object at 0x7fca77d02e10>
# ________________________
# Cross-val number: 3, Run number: 6
# 1: Train loss: 3.063, Train RMSE: 1.779, Val RMSE: 1.911
# 10: Train loss: 1.335, Train RMSE: 1.169, Val RMSE: 1.231
# 20: Train loss: 0.9848, Train RMSE: 1.02, Val RMSE: 1.09
# 30: Train loss: 0.7615, Train RMSE: 0.8601, Val RMSE: 0.9752
# 40: Train loss: 0.4661, Train RMSE: 0.687, Val RMSE: 0.9444
# 50: Train loss: 0.3271, Train RMSE: 0.5384, Val RMSE: 0.9693
# Raw scatter=2.087 m/s
# Corrected scatter=0.969 m/s
# Stellar Error Removed=1.848 m/s
# <__main__.FCModel object at 0x7fca15cfced0>
# ________________________
# Cross-val number: 3, Run number: 7
# 1: Train loss: 3.024, Train RMSE: 1.809, Val RMSE: 1.895
# 10: Train loss: 1.489, Train RMSE: 1.189, Val RMSE: 1.238
# 20: Train loss: 0.988, Train RMSE: 0.9773, Val RMSE: 1.016
# 30: Train loss: 0.5975, Train RMSE: 0.8011, Val RMSE: 1.01
# 40: Train loss: 0.3744, Train RMSE: 0.6166, Val RMSE: 0.9523
# 50: Train loss: 0.2784, Train RMSE: 0.5051, Val RMSE: 0.9328
# Raw scatter=2.087 m/s
# Corrected scatter=0.933 m/s
# Stellar Error Removed=1.867 m/s
# <__main__.FCModel object at 0x7fca77d53910>
# ________________________
# Cross-val number: 3, Run number: 8
# 1: Train loss: 3.077, Train RMSE: 1.754, Val RMSE: 1.885
# 10: Train loss: 1.478, Train RMSE: 1.178, Val RMSE: 1.223
# 20: Train loss: 0.8604, Train RMSE: 0.9672, Val RMSE: 1.048
# 30: Train loss: 0.5452, Train RMSE: 0.7764, Val RMSE: 0.9789
# 40: Train loss: 0.3879, Train RMSE: 0.611, Val RMSE: 0.9631
# 50: Train loss: 0.213, Train RMSE: 0.4592, Val RMSE: 1.042
# Raw scatter=2.087 m/s
# Corrected scatter=1.042 m/s
# Stellar Error Removed=1.808 m/s
# <__main__.FCModel object at 0x7fca15d9cd90>
# ________________________
# Cross-val number: 3, Run number: 9
# 1: Train loss: 3.035, Train RMSE: 1.771, Val RMSE: 1.928
# 10: Train loss: 1.312, Train RMSE: 1.171, Val RMSE: 1.273
# 20: Train loss: 1.059, Train RMSE: 0.9932, Val RMSE: 1.032
# 30: Train loss: 0.7261, Train RMSE: 0.8223, Val RMSE: 1.022
# 40: Train loss: 0.4255, Train RMSE: 0.6421, Val RMSE: 0.9673
# 50: Train loss: 0.2208, Train RMSE: 0.4931, Val RMSE: 1.064
# Raw scatter=2.087 m/s
# Corrected scatter=1.064 m/s
# Stellar Error Removed=1.795 m/s
# <__main__.FCModel object at 0x7fc9f0298a90>
# ________________________
# Cross-val number: 3, Run number: 10
# 1: Train loss: 3.318, Train RMSE: 1.873, Val RMSE: 1.951
# 10: Train loss: 1.409, Train RMSE: 1.175, Val RMSE: 1.294
# 20: Train loss: 0.9992, Train RMSE: 1.005, Val RMSE: 1.191
# 30: Train loss: 0.6073, Train RMSE: 0.8167, Val RMSE: 1.119
# 40: Train loss: 0.444, Train RMSE: 0.6464, Val RMSE: 1.116
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/rn/06tzsshx6h542jl02_xd33t80000gn/T/ipykernel_79853/2868920555.py in <module>
#      33     ))
#      34     model = FCModel(hparams)
# ---> 35     train(model, hparams, plots="OFF",model_name="FC NN", num_epochs=50)
#      36     print(model)
#      37     print("________________________")
#
# /var/folders/rn/06tzsshx6h542jl02_xd33t80000gn/T/ipykernel_79853/2957102123.py in train(model, hparams, plots, model_name, num_epochs)
#      38         preds = model(features, training=True)
#      39         loss = loss_fn(labels, preds)
# ---> 40       grads = t.gradient(loss, model.trainable_variables)
#      41       optimizer.apply_gradients(zip(grads, model.trainable_variables))
#      42       # Update the metrics.
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1012         output_gradients=output_gradients,
#    1013         sources_raw=flat_sources_raw,
# -> 1014         unconnected_gradients=unconnected_gradients)
#    1015
#    1016     if not self._persistent:
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      74       output_gradients,
#      75       sources_raw,
# ---> 76       compat.as_str(unconnected_gradients.value))
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices)
#     136     return [None] * num_inputs
#     137
# --> 138   return grad_fn(mock_op, *out_grads)
#     139
#     140
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py in _MeanGrad(op, grad)
#     235 def _MeanGrad(op, grad):
#     236   """Gradient for Mean."""
# --> 237   sum_grad = _SumGrad(op, grad)[0]
#     238   input_shape = op.inputs[0]._shape_tuple()  # pylint: disable=protected-access
#     239   output_shape = op.outputs[0]._shape_tuple()  # pylint: disable=protected-access
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py in _SumGrad(op, grad)
#     198   with ops.colocate_with(input_shape):
#     199     output_shape_kept_dims = math_ops.reduced_shape(input_shape, op.inputs[1])
# --> 200     tile_scaling = _safe_shape_div(input_shape, output_shape_kept_dims)
#     201   grad = array_ops.reshape(grad, output_shape_kept_dims)
#     202   return [array_ops.tile(grad, tile_scaling), None]
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py in _safe_shape_div(x, y)
#      36 def _safe_shape_div(x, y):
#      37   """Divides `x / y` assuming `x, y >= 0`, treating `0 / 0 = 0`."""
# ---> 38   return x // math_ops.maximum(y, 1)
#      39
#      40
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_math_ops.py in maximum(x, y, name)
#    6280       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    6281         _ctx._context_handle, _ctx._thread_local_data.device_name, "Maximum",
# -> 6282         name, _ctx._post_execution_callbacks, x, y)
#    6283       return _result
#    6284     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(list(zip(all_mean_val_labels,all_mean_val_preds, all_mean_val_bjds)), 
               columns =['labels', 'preds', 'BJD']) 
df_sorted = df.sort_values(by=['BJD'])
#df_sorted.to_excel('gdrive/Shared drives/Exoplanet_RV/cross_val_preds/val_preds_FCNN_06_30_2021.xlsx', index = False)

# calculation of scatter removed
from astropy.stats import median_absolute_deviation

#df_sorted = df_from_excel
labels_68_percent_by_2 = (np.percentile(df_sorted["labels"], 84)-np.percentile(df_sorted["labels"], 16))/2
labels_median_absolute_deviation_norm = median_absolute_deviation(df_sorted["labels"])*1.4826
preds_68_percent_by_2 = (np.percentile(df_sorted["preds"], 84)-np.percentile(df_sorted["preds"], 16))/2

corrected_rvs = df_sorted["labels"]-df_sorted["preds"]
corrected_rvs_68_percent_by_2 = (np.percentile(corrected_rvs, 84)-np.percentile(corrected_rvs, 16))/2
corrected_rvs_median_absolute_deviation_norm = median_absolute_deviation(corrected_rvs)*1.4826

sd_labels = np.std(df_sorted["labels"], ddof=1)
sd_corrected_rv = np.std(corrected_rvs, ddof=1)
rms_x = np.sqrt(np.mean(np.square(df_sorted["labels"] - df_sorted["preds"])))


print("labels: sd: "+str(sd_labels))
print("corrected rv: sd: "+str(sd_corrected_rv))
print("____________________________________________")
print("labels: MAD*1.4826: "+str(labels_median_absolute_deviation_norm))
print("corrected rv: MAD*1.4826: "+str(corrected_rvs_median_absolute_deviation_norm))
print("____________________________________________")
print("labels: 68 percent/2: "+str(labels_68_percent_by_2))
print("corrected rv: 68 percent/2: "+str(corrected_rvs_68_percent_by_2))


# plot the average results
# Scatter reduction plot
rms_avg_list = []
sd_x = np.std(all_mean_val_labels, ddof=1)
rms_x = np.sqrt(np.mean(np.square(all_mean_val_labels - np.array(all_mean_val_preds))))
#rms_x_list.append(rms_x)
rms_avg_list.append(rms_x)
stel_removed = np.sqrt(np.abs(sd_x**2-rms_x**2))
x_range = np.linspace(-4,5.5, 17)
upper_bound = x_range+rms_x
lower_bound = x_range-rms_x

# plot the scatter reduction plot
fig, ax = plt.subplots(1, 2, figsize=(21, 6))
ax1 = ax[0]
ax1.plot(df_sorted["labels"], df_sorted["preds"], ".")
ax1.plot(x_range,x_range, color="blue", label="1:1 ratio")
#ax.plot(x_range,z[0]*x_range+z[1], color="blue")
rms_fill=rms_x#0.15
ax1.fill_between(x_range, x_range+rms_fill, x_range-rms_fill, facecolor='lightblue',
                alpha=0.5, label="1 standard deviation")
ax1.set_xlim(-4, 5);
ax1.set_ylim(-4, 5);
ax1.set_xlabel("HARPS-N Stellar Activity Signal (m/s)", size =16)
ax1.set_ylabel("Model Predicted Stellar Activity Signal (m/s)", size =16)
ax1.set_title("FC NN Predictions of Stellar Activity signal(m/s)") #, %d epochs, weight decay: %.2e, gauss noise: %.2e " %(num_epochs, 
#hparams.weight_decay, hparams.gaussian_noise_scale, size=16)
textstr = '\n'.join((
    r'Raw scatter=%.3f m/s' % (labels_68_percent_by_2, ),
    r'Corrected scatter=%.3f m/s' % (corrected_rvs_68_percent_by_2, ),
    r'Stellar Error Removed=%.3f m/s' % (stel_removed, )))
ax1.text(-3.8, 3.5, textstr, size=15,
        ha="left", va="top",
        bbox=dict(facecolor='#fdcf44',edgecolor='k',
                  boxstyle="square",
                  #ec=(1., 0.5, 0.5),
                  #fc=(1., 0.8, 0.8),
                  ))
ax1.legend(loc="lower right")

# plot predictions over time
ax2 = ax[1]
ax2.plot(df_sorted["BJD"], df_sorted["labels"], ".",color='k',
         markersize=10,label="labels")
ax2.plot(df_sorted["BJD"], df_sorted["preds"], ".", markersize=10,
         label="preds")
ax2.set_xlabel("Time (BJD)")
ax2.set_ylabel("RV (m/s)")
ax2.legend(loc="lower right")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rn/06tzsshx6h542jl02_xd33t80000gn/T/ipykernel_79853/2498495645.py in <module>
#       9 #df_sorted = df_from_excel
#      10 labels_68_percent_by_2 = (np.percentile(df_sorted["labels"], 84)-np.percentile(df_sorted["labels"], 16))/2
# ---> 11 labels_median_absolute_deviation_norm = median_absolute_deviation(df_sorted["labels"])*1.4826
#      12 preds_68_percent_by_2 = (np.percentile(df_sorted["preds"], 84)-np.percentile(df_sorted["preds"], 16))/2
#      13
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/astropy/stats/funcs.py in median_absolute_deviation(data, axis, func, ignore_nan)
#     848         data_median = _expand_dims(data_median, axis=axis)  # NUMPY_LT_1_18
#     849
# --> 850     result = func(np.abs(data - data_median), axis=axis, overwrite_input=True)
#     851
#     852     if axis is None and np.ma.isMaskedArray(result):
#
# ValueError: operands could not be broadcast together with shapes (3,) (42,)

# %% [markdown]
# ## CNN Model Run

# %%
# CNN Model run

# Cross validation CNN Model Run (10 times)
rms_avg_list = []
weight_decay_list_t = []
gaussian_noise_list_t = []
rms_x_list = []

all_bjds_val = []
all_pred_val = []
all_labels_val = []
all_mean_val_preds = []
all_mean_val_bjds = []
all_mean_val_labels = []
all_mean_val_bjds = []

for index in range(0, len(VAL_FILE_NAME_LIST)):
  TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
  VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]
  bjd_run_val = []
  pred_run_val = []
  labels_run_val = []
  for k in range(0,10): #should be 10 for a full run
    hparams = configdict.ConfigDict(dict(
        num_features=152,
        learning_rate=0.0050618, #1e-3,
        momentum=0.9,
        batch_size=300,
        conv_kernel_size=3,
        num_conv_filters=32,
        num_conv_layers=4,
        num_dense_units=500,
        num_dense_layers=1,
        weight_decay=0.0012341, #5e-4, #7e-2,
        gaussian_noise_scale=0,#1.5,
    ))
    model = CNNModel(hparams)
    train(model, hparams, plots="OFF",model_name="CNN", num_epochs=35)#65)
    print(model)
    print("________________________")
    print("Cross-val number: "+str(index+1)+", Run number: "+str(k+1))
  mean_val_preds = np.mean(pred_run_val, axis=0)
  mean_val_labels = np.mean(labels_run_val, axis=0)
  mean_val_bjds = np.mean(bjd_run_val, axis=0)
  all_mean_val_preds.append(mean_val_preds.tolist())
  all_mean_val_labels.append(mean_val_labels.tolist())
  all_mean_val_bjds.append(mean_val_bjds.tolist())
avg = np.mean(rms_avg_list)
print("________________________")
print(avg)

#flatten the lists
all_mean_val_preds = [item for sublist in all_mean_val_preds for item in sublist]
all_mean_val_labels = [item for sublist in all_mean_val_labels for item in sublist]
all_mean_val_bjds = [item for sublist in all_mean_val_bjds for item in sublist]

# %%
df = pd.DataFrame(list(zip(all_mean_val_labels,all_mean_val_preds, all_mean_val_bjds)), 
               columns =['labels', 'preds', 'BJD']) 
df_sorted = df.sort_values(by=['BJD'])
#df_sorted.to_excel('gdrive/Shared drives/Exoplanet_RV/cross_val_preds/val_preds_CNN_06_30_2021.xlsx', index = False)

# calculation of scatter removed
from astropy.stats import median_absolute_deviation

#df_sorted = df_from_excel
labels_68_percent_by_2 = (np.percentile(df_sorted["labels"], 84)-np.percentile(df_sorted["labels"], 16))/2
labels_median_absolute_deviation_norm = median_absolute_deviation(df_sorted["labels"])*1.4826
preds_68_percent_by_2 = (np.percentile(df_sorted["preds"], 84)-np.percentile(df_sorted["preds"], 16))/2

corrected_rvs = df_sorted["labels"]-df_sorted["preds"]
corrected_rvs_68_percent_by_2 = (np.percentile(corrected_rvs, 84)-np.percentile(corrected_rvs, 16))/2
corrected_rvs_median_absolute_deviation_norm = median_absolute_deviation(corrected_rvs)*1.4826

sd_labels = np.std(df_sorted["labels"], ddof=1)
sd_corrected_rv = np.std(corrected_rvs, ddof=1)
rms_x = np.sqrt(np.mean(np.square(df_sorted["labels"] - df_sorted["preds"])))


print("labels: sd: "+str(sd_labels))
print("corrected rv: sd: "+str(sd_corrected_rv))
print("____________________________________________")
print("labels: MAD*1.4826: "+str(labels_median_absolute_deviation_norm))
print("corrected rv: MAD*1.4826: "+str(corrected_rvs_median_absolute_deviation_norm))
print("____________________________________________")
print("labels: 68 percent/2: "+str(labels_68_percent_by_2))
print("corrected rv: 68 percent/2: "+str(corrected_rvs_68_percent_by_2))


# plot the average results
# Scatter reduction plot
rms_avg_list = []
sd_x = np.std(all_mean_val_labels, ddof=1)
rms_x = np.sqrt(np.mean(np.square(all_mean_val_labels - np.array(all_mean_val_preds))))
#rms_x_list.append(rms_x)
rms_avg_list.append(rms_x)
stel_removed = np.sqrt(np.abs(sd_x**2-rms_x**2))
x_range = np.linspace(-4,5.5, 17)
upper_bound = x_range+rms_x
lower_bound = x_range-rms_x

# plot the scatter reduction plot
fig, ax = plt.subplots(1, 2, figsize=(21, 6))
ax1 = ax[0]
ax1.plot(df_sorted["labels"], df_sorted["preds"], ".")
ax1.plot(x_range,x_range, color="blue", label="1:1 ratio")
#ax.plot(x_range,z[0]*x_range+z[1], color="blue")
rms_fill=rms_x#0.15
ax1.fill_between(x_range, x_range+rms_fill, x_range-rms_fill, facecolor='lightblue',
                alpha=0.5, label="1 standard deviation")
ax1.set_xlim(-4, 5);
ax1.set_ylim(-4, 5);
ax1.set_xlabel("HARPS-N Stellar Activity Signal (m/s)", size =16)
ax1.set_ylabel("Model Predicted Stellar Activity Signal (m/s)", size =16)
ax1.set_title("CNN Predictions of Stellar Activity signal(m/s)") #, %d epochs, weight decay: %.2e, gauss noise: %.2e " %(num_epochs, 
#hparams.weight_decay, hparams.gaussian_noise_scale, size=16)
textstr = '\n'.join((
    r'Raw scatter=%.3f m/s' % (labels_68_percent_by_2, ),
    r'Corrected scatter=%.3f m/s' % (corrected_rvs_68_percent_by_2, ),
    r'Stellar Error Removed=%.3f m/s' % (stel_removed, )))
ax1.text(-3.8, 3.5, textstr, size=15,
        ha="left", va="top",
        bbox=dict(facecolor='#fdcf44',edgecolor='k',
                  boxstyle="square",
                  #ec=(1., 0.5, 0.5),
                  #fc=(1., 0.8, 0.8),
                  ))
ax1.legend(loc="lower right")

# plot predictions over time
ax2 = ax[1]
ax2.plot(df_sorted["BJD"], df_sorted["labels"], ".",color='k',
         markersize=10,label="labels")
ax2.plot(df_sorted["BJD"], df_sorted["preds"], ".", markersize=10,
         label="preds")
ax2.set_xlabel("Time (BJD)")
ax2.set_ylabel("RV (m/s)")
ax2.legend(loc="lower right")

# %% [markdown]
# # FC NN Optimize Hyperparameters (08.31.21)

# %%
from tensorboard.plugins.hparams import api as hp
import shutil
import time

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Define the ranges of values that each hyperparameter can take

x = np.random.uniform(1,5, 1000)
learning_rate_list = [10**-x][0]

dense_units_list = [100, 200, 500, 1000]
num_dense_layers_list = [4, 8, 12, 16] #[1, 2, 4, 8, 12, 16]
weight_decay_list = np.geomspace(0.0001, 0.008, 6)

num_epochs_list = [30, 35, 40, 45, 50] #[50, 55, 65, 70, 80, 90, 100]

# %%
# series code

LOG_DIR_1 = "gdrive/Shareddrives/Exoplanet_RV/logs/" + time.strftime("%Y%m%d-%H%M%S", time.localtime())
print(LOG_DIR_1)

# Log the hparam config. This is optional but makes tensorboard show the right ranges.
with tf.summary.create_file_writer(LOG_DIR_1).as_default():
  hp.hparams_config(
    hparams=[
             hp.HParam('learning_rate', hp.RealInterval(1e-4, 1e-2)),
             hp.HParam('num_dense_units', hp.Discrete([100, 200, 500, 1000])),
             hp.HParam('num_dense_layers', hp.Discrete([4, 8, 12, 16])),
             hp.HParam('weight_decay', hp.RealInterval(5e-4,5e-2))],
    metrics=[hp.Metric("val_rmse", display_name='RMSE'),
             hp.Metric("original_rmse", display_name="OG RMSE"),
             hp.Metric("difference_rmse", display_name="diff RMSE"),
            ],
  )

model_num = 1
RMSE_list = []
all_pred_bjd_val = []

rms_avg_list = []
weight_decay_list_t = []
gaussian_noise_list_t = []
rms_x_list = []

all_bjds_val = []
all_pred_val = []
all_labels_val = []
all_mean_val_preds = []
all_mean_val_bjds = []
all_mean_val_labels = []

for s in range(0, 1):#len(VAL_FILE_NAME_LIST)):
  #TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
  #VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]
  ts = time.time()
  for i in range(0,60):#30):
      hparams = configdict.ConfigDict(dict(
          num_features=46,
          learning_rate=np.random.choice(learning_rate_list),
          momentum=0.9,
          batch_size=1024,
          num_dense_units=int(np.random.choice(dense_units_list)),
          num_dense_layers=int(np.random.choice(num_dense_layers_list)),
          weight_decay=np.random.choice(weight_decay_list), #5e-4, #7e-2,
          gaussian_noise_scale=0,#1.5,
      ))
      epochs = np.random.choice(num_epochs_list)
      for index in range(0, len(VAL_FILE_NAME_LIST)):
        TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
        VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]

        bjd_run_val = []
        pred_run_val = []
        labels_run_val = []
        k=0
        #for k in range(0,1):
        print("Model {}. Learning_rate: {:.5f}. Dense units: {}. Dense layers {}. Weight decay: {:.5f}".format(
              model_num, hparams.learning_rate, hparams.num_dense_units, hparams.num_dense_layers, hparams.weight_decay))
        print("Cross-val number: "+str(index+1)+", Model archictect. num: "+str(i+1)+", Run number: "+str(k+1))
        model = FCModel(hparams)
        run_dir = LOG_DIR_1 + "/{}/".format(model_num)
        with tf.summary.create_file_writer(run_dir).as_default():
          hp.hparams(hparams)  # record the values used in this trial
          metric_values = train(model, hparams, plots="OFF", model_name = "FC NN",num_epochs=epochs)
          final_metrics = metric_values[-1]

        print("________________________")
        print()
        mean_val_preds = np.mean(pred_run_val, axis=0)
        mean_val_labels = np.mean(labels_run_val, axis=0)
        mean_val_bjds = np.mean(bjd_run_val, axis=0)

        all_mean_val_preds.append(mean_val_preds)
        all_mean_val_labels.append(mean_val_labels)
        all_mean_val_bjds.append(mean_val_bjds)

        all_pred_val.append(pred_run_val)
        all_labels_val.append(labels_run_val)
        all_bjds_val.append(bjd_run_val)
      model_num += 1

print('Time in series:', time.time() - ts)
# Out:
# gdrive/Shareddrives/Exoplanet_RV/logs/20211207-073733
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 1, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.43, Train RMSE: 1.852, Val RMSE: 1.584
# 10: Train loss: 3.358, Train RMSE: 1.833, Val RMSE: 1.582
# 20: Train loss: 3.093, Train RMSE: 1.759, Val RMSE: 1.523
# 30: Train loss: 2.088, Train RMSE: 1.445, Val RMSE: 1.427
# Raw scatter=1.590 m/s
# Corrected scatter=1.427 m/s
# Stellar Error Removed=0.703 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 2, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.339, Train RMSE: 1.827, Val RMSE: 1.839
# 10: Train loss: 3.285, Train RMSE: 1.813, Val RMSE: 1.826
# 20: Train loss: 3.111, Train RMSE: 1.764, Val RMSE: 1.786
# 30: Train loss: 2.27, Train RMSE: 1.507, Val RMSE: 1.634
# Raw scatter=1.861 m/s
# Corrected scatter=1.634 m/s
# Stellar Error Removed=0.890 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 3, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.238, Train RMSE: 1.799, Val RMSE: 2.067
# 10: Train loss: 3.195, Train RMSE: 1.788, Val RMSE: 2.05
# 20: Train loss: 3.069, Train RMSE: 1.752, Val RMSE: 2.0
# 30: Train loss: 2.532, Train RMSE: 1.591, Val RMSE: 1.743
# Raw scatter=2.087 m/s
# Corrected scatter=1.743 m/s
# Stellar Error Removed=1.147 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 4, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.933
# 10: Train loss: 3.242, Train RMSE: 1.801, Val RMSE: 1.937
# 20: Train loss: 3.086, Train RMSE: 1.757, Val RMSE: 1.895
# 30: Train loss: 2.303, Train RMSE: 1.518, Val RMSE: 1.639
# Raw scatter=1.944 m/s
# Corrected scatter=1.639 m/s
# Stellar Error Removed=1.046 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 5, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.385, Train RMSE: 1.84, Val RMSE: 1.727
# 10: Train loss: 3.336, Train RMSE: 1.827, Val RMSE: 1.708
# 20: Train loss: 3.171, Train RMSE: 1.781, Val RMSE: 1.657
# 30: Train loss: 2.399, Train RMSE: 1.549, Val RMSE: 1.418
# Raw scatter=1.737 m/s
# Corrected scatter=1.418 m/s
# Stellar Error Removed=1.003 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 6, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.965
# 10: Train loss: 3.239, Train RMSE: 1.8, Val RMSE: 1.944
# 20: Train loss: 3.087, Train RMSE: 1.757, Val RMSE: 1.894
# 30: Train loss: 2.522, Train RMSE: 1.588, Val RMSE: 1.694
# Raw scatter=1.954 m/s
# Corrected scatter=1.694 m/s
# Stellar Error Removed=0.974 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 7, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.519, Train RMSE: 1.876, Val RMSE: 1.322
# 10: Train loss: 3.463, Train RMSE: 1.861, Val RMSE: 1.336
# 20: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.31
# 30: Train loss: 2.54, Train RMSE: 1.594, Val RMSE: 1.209
# Raw scatter=1.312 m/s
# Corrected scatter=1.209 m/s
# Stellar Error Removed=0.510 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 8, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.321, Train RMSE: 1.822, Val RMSE: 1.873
# 10: Train loss: 3.259, Train RMSE: 1.805, Val RMSE: 1.857
# 20: Train loss: 3.05, Train RMSE: 1.746, Val RMSE: 1.789
# 30: Train loss: 2.139, Train RMSE: 1.463, Val RMSE: 1.433
# Raw scatter=1.897 m/s
# Corrected scatter=1.433 m/s
# Stellar Error Removed=1.242 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 9, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.302, Train RMSE: 1.817, Val RMSE: 1.919
# 10: Train loss: 3.258, Train RMSE: 1.805, Val RMSE: 1.898
# 20: Train loss: 3.112, Train RMSE: 1.764, Val RMSE: 1.841
# 30: Train loss: 2.562, Train RMSE: 1.601, Val RMSE: 1.597
# Raw scatter=1.846 m/s
# Corrected scatter=1.597 m/s
# Stellar Error Removed=0.926 m/s
# ________________________
#
# Model 1. Learning_rate: 0.00618. Dense units: 1000. Dense layers 12. Weight decay: 0.00333
# Cross-val number: 10, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.3, Train RMSE: 1.817, Val RMSE: 1.927
# 10: Train loss: 3.249, Train RMSE: 1.803, Val RMSE: 1.912
# 20: Train loss: 3.083, Train RMSE: 1.756, Val RMSE: 1.859
# 30: Train loss: 2.344, Train RMSE: 1.531, Val RMSE: 1.609
# Raw scatter=1.947 m/s
# Corrected scatter=1.609 m/s
# Stellar Error Removed=1.096 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 1, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.436, Train RMSE: 1.854, Val RMSE: 1.586
# 10: Train loss: 2.937, Train RMSE: 1.714, Val RMSE: 1.38
# 20: Train loss: 3.454, Train RMSE: 1.859, Val RMSE: 1.621
# 30: Train loss: 3.424, Train RMSE: 1.851, Val RMSE: 1.623
# 35: Train loss: 3.423, Train RMSE: 1.85, Val RMSE: 1.602
# Raw scatter=1.590 m/s
# Corrected scatter=1.602 m/s
# Stellar Error Removed=0.195 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 2, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.34, Train RMSE: 1.828, Val RMSE: 1.837
# 10: Train loss: 2.925, Train RMSE: 1.71, Val RMSE: 1.739
# 20: Train loss: 3.333, Train RMSE: 1.826, Val RMSE: 1.842
# 30: Train loss: 3.348, Train RMSE: 1.83, Val RMSE: 1.84
# 35: Train loss: 3.332, Train RMSE: 1.825, Val RMSE: 1.842
# Raw scatter=1.861 m/s
# Corrected scatter=1.842 m/s
# Stellar Error Removed=0.260 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 3, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.237, Train RMSE: 1.799, Val RMSE: 2.065
# 10: Train loss: 2.182, Train RMSE: 1.477, Val RMSE: 1.38
# 20: Train loss: 3.274, Train RMSE: 1.809, Val RMSE: 2.062
# 30: Train loss: 3.228, Train RMSE: 1.797, Val RMSE: 2.06
# 35: Train loss: 3.216, Train RMSE: 1.793, Val RMSE: 2.056
# Raw scatter=2.087 m/s
# Corrected scatter=2.056 m/s
# Stellar Error Removed=0.357 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 4, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.292, Train RMSE: 1.814, Val RMSE: 1.939
# 10: Train loss: 2.425, Train RMSE: 1.557, Val RMSE: 1.828
# 20: Train loss: 3.324, Train RMSE: 1.823, Val RMSE: 2.025
# 30: Train loss: 3.285, Train RMSE: 1.813, Val RMSE: 1.941
# 35: Train loss: 3.181, Train RMSE: 1.784, Val RMSE: 1.869
# Raw scatter=1.944 m/s
# Corrected scatter=1.869 m/s
# Stellar Error Removed=0.535 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 5, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.385, Train RMSE: 1.84, Val RMSE: 1.724
# 10: Train loss: 3.087, Train RMSE: 1.757, Val RMSE: 1.596
# 20: Train loss: 3.48, Train RMSE: 1.866, Val RMSE: 1.718
# 30: Train loss: 3.382, Train RMSE: 1.839, Val RMSE: 1.717
# 35: Train loss: 3.386, Train RMSE: 1.84, Val RMSE: 1.719
# Raw scatter=1.737 m/s
# Corrected scatter=1.719 m/s
# Stellar Error Removed=0.251 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 6, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.285, Train RMSE: 1.812, Val RMSE: 1.959
# 10: Train loss: 3.05, Train RMSE: 1.746, Val RMSE: 1.825
# 20: Train loss: 3.405, Train RMSE: 1.845, Val RMSE: 1.931
# 30: Train loss: 3.305, Train RMSE: 1.818, Val RMSE: 1.972
# 35: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.939
# Raw scatter=1.954 m/s
# Corrected scatter=1.939 m/s
# Stellar Error Removed=0.241 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 7, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.519, Train RMSE: 1.876, Val RMSE: 1.328
# 10: Train loss: 2.823, Train RMSE: 1.68, Val RMSE: 1.269
# 20: Train loss: 2.151e+07, Train RMSE: 4.638e+03, Val RMSE: nan
# 30: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# 35: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# Raw scatter=1.312 m/s
# Corrected scatter=nan m/s
# Stellar Error Removed=nan m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 8, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.323, Train RMSE: 1.823, Val RMSE: 1.872
# 10: Train loss: 2.447, Train RMSE: 1.564, Val RMSE: 1.518
# 20: Train loss: 38.37, Train RMSE: 6.194, Val RMSE: 7.264
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/ipykernel_launcher.py:53: RuntimeWarning: overflow encountered in square
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: overflow encountered in square
# 30: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# 35: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# Raw scatter=1.897 m/s
# Corrected scatter=nan m/s
# Stellar Error Removed=nan m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 9, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.302, Train RMSE: 1.817, Val RMSE: 1.918
# 10: Train loss: 2.819, Train RMSE: 1.679, Val RMSE: 1.656
# 20: Train loss: 3.33, Train RMSE: 1.825, Val RMSE: 1.868
# 30: Train loss: 3.312, Train RMSE: 1.82, Val RMSE: 1.884
# 35: Train loss: 3.309, Train RMSE: 1.819, Val RMSE: 1.938
# Raw scatter=1.846 m/s
# Corrected scatter=1.938 m/s
# Stellar Error Removed=0.590 m/s
# ________________________
#
# Model 2. Learning_rate: 0.05866. Dense units: 200. Dense layers 16. Weight decay: 0.00333
# Cross-val number: 10, Model archictect. num: 2, Run number: 1
# 1: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.924
# 10: Train loss: 2.647, Train RMSE: 1.627, Val RMSE: 2.028
# 20: Train loss: 3.365, Train RMSE: 1.834, Val RMSE: 1.927
# 30: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.922
# 35: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.921
# Raw scatter=1.947 m/s
# Corrected scatter=1.921 m/s
# Stellar Error Removed=0.315 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 1, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.434, Train RMSE: 1.853, Val RMSE: 1.584
# 10: Train loss: 3.434, Train RMSE: 1.853, Val RMSE: 1.584
# 20: Train loss: 3.433, Train RMSE: 1.853, Val RMSE: 1.584
# 30: Train loss: 3.432, Train RMSE: 1.853, Val RMSE: 1.584
# 40: Train loss: 3.431, Train RMSE: 1.852, Val RMSE: 1.584
# 45: Train loss: 3.431, Train RMSE: 1.852, Val RMSE: 1.584
# Raw scatter=1.590 m/s
# Corrected scatter=1.584 m/s
# Stellar Error Removed=0.138 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 2, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.339, Train RMSE: 1.827, Val RMSE: 1.839
# 10: Train loss: 3.339, Train RMSE: 1.827, Val RMSE: 1.839
# 20: Train loss: 3.338, Train RMSE: 1.827, Val RMSE: 1.839
# 30: Train loss: 3.337, Train RMSE: 1.827, Val RMSE: 1.839
# 40: Train loss: 3.336, Train RMSE: 1.827, Val RMSE: 1.839
# 45: Train loss: 3.336, Train RMSE: 1.826, Val RMSE: 1.838
# Raw scatter=1.861 m/s
# Corrected scatter=1.838 m/s
# Stellar Error Removed=0.286 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 3, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.238, Train RMSE: 1.799, Val RMSE: 2.069
# 10: Train loss: 3.238, Train RMSE: 1.799, Val RMSE: 2.069
# 20: Train loss: 3.237, Train RMSE: 1.799, Val RMSE: 2.069
# 30: Train loss: 3.237, Train RMSE: 1.799, Val RMSE: 2.069
# 40: Train loss: 3.236, Train RMSE: 1.799, Val RMSE: 2.069
# 45: Train loss: 3.236, Train RMSE: 1.799, Val RMSE: 2.068
# Raw scatter=2.087 m/s
# Corrected scatter=2.068 m/s
# Stellar Error Removed=0.278 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 4, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.935
# 10: Train loss: 3.298, Train RMSE: 1.816, Val RMSE: 1.935
# 20: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.935
# 30: Train loss: 3.296, Train RMSE: 1.816, Val RMSE: 1.935
# 40: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.935
# 45: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.936
# Raw scatter=1.944 m/s
# Corrected scatter=1.936 m/s
# Stellar Error Removed=0.182 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 5, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.383, Train RMSE: 1.839, Val RMSE: 1.727
# 10: Train loss: 3.383, Train RMSE: 1.839, Val RMSE: 1.727
# 20: Train loss: 3.382, Train RMSE: 1.839, Val RMSE: 1.727
# 30: Train loss: 3.382, Train RMSE: 1.839, Val RMSE: 1.726
# 40: Train loss: 3.381, Train RMSE: 1.839, Val RMSE: 1.726
# 45: Train loss: 3.38, Train RMSE: 1.839, Val RMSE: 1.726
# Raw scatter=1.737 m/s
# Corrected scatter=1.726 m/s
# Stellar Error Removed=0.194 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 6, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.287, Train RMSE: 1.813, Val RMSE: 1.964
# 10: Train loss: 3.286, Train RMSE: 1.813, Val RMSE: 1.964
# 20: Train loss: 3.286, Train RMSE: 1.813, Val RMSE: 1.964
# 30: Train loss: 3.285, Train RMSE: 1.813, Val RMSE: 1.963
# 40: Train loss: 3.285, Train RMSE: 1.812, Val RMSE: 1.963
# 45: Train loss: 3.284, Train RMSE: 1.812, Val RMSE: 1.963
# Raw scatter=1.954 m/s
# Corrected scatter=1.963 m/s
# Stellar Error Removed=0.188 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 7, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.519, Train RMSE: 1.876, Val RMSE: 1.321
# 10: Train loss: 3.518, Train RMSE: 1.876, Val RMSE: 1.321
# 20: Train loss: 3.517, Train RMSE: 1.875, Val RMSE: 1.322
# 30: Train loss: 3.515, Train RMSE: 1.875, Val RMSE: 1.322
# 40: Train loss: 3.513, Train RMSE: 1.874, Val RMSE: 1.322
# 45: Train loss: 3.513, Train RMSE: 1.874, Val RMSE: 1.322
# Raw scatter=1.312 m/s
# Corrected scatter=1.322 m/s
# Stellar Error Removed=0.159 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 8, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.322, Train RMSE: 1.823, Val RMSE: 1.874
# 10: Train loss: 3.322, Train RMSE: 1.823, Val RMSE: 1.874
# 20: Train loss: 3.321, Train RMSE: 1.822, Val RMSE: 1.873
# 30: Train loss: 3.32, Train RMSE: 1.822, Val RMSE: 1.873
# 40: Train loss: 3.319, Train RMSE: 1.822, Val RMSE: 1.873
# 45: Train loss: 3.319, Train RMSE: 1.822, Val RMSE: 1.873
# Raw scatter=1.897 m/s
# Corrected scatter=1.873 m/s
# Stellar Error Removed=0.299 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 9, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.305, Train RMSE: 1.818, Val RMSE: 1.924
# 10: Train loss: 3.305, Train RMSE: 1.818, Val RMSE: 1.924
# 20: Train loss: 3.304, Train RMSE: 1.818, Val RMSE: 1.924
# 30: Train loss: 3.303, Train RMSE: 1.818, Val RMSE: 1.923
# 40: Train loss: 3.303, Train RMSE: 1.817, Val RMSE: 1.923
# 45: Train loss: 3.302, Train RMSE: 1.817, Val RMSE: 1.922
# Raw scatter=1.846 m/s
# Corrected scatter=1.922 m/s
# Stellar Error Removed=0.534 m/s
# ________________________
#
# Model 3. Learning_rate: 0.00004. Dense units: 500. Dense layers 16. Weight decay: 0.00010
# Cross-val number: 10, Model archictect. num: 3, Run number: 1
# 1: Train loss: 3.302, Train RMSE: 1.817, Val RMSE: 1.928
# 10: Train loss: 3.301, Train RMSE: 1.817, Val RMSE: 1.928
# 20: Train loss: 3.3, Train RMSE: 1.817, Val RMSE: 1.928
# 30: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.928
# 40: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.927
# 45: Train loss: 3.298, Train RMSE: 1.816, Val RMSE: 1.927
# Raw scatter=1.947 m/s
# Corrected scatter=1.927 m/s
# Stellar Error Removed=0.276 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 1, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.434, Train RMSE: 1.853, Val RMSE: 1.582
# 10: Train loss: 3.431, Train RMSE: 1.852, Val RMSE: 1.582
# 20: Train loss: 3.426, Train RMSE: 1.851, Val RMSE: 1.582
# 30: Train loss: 3.421, Train RMSE: 1.85, Val RMSE: 1.582
# 35: Train loss: 3.418, Train RMSE: 1.849, Val RMSE: 1.582
# Raw scatter=1.590 m/s
# Corrected scatter=1.582 m/s
# Stellar Error Removed=0.161 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 2, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.337, Train RMSE: 1.827, Val RMSE: 1.839
# 10: Train loss: 3.335, Train RMSE: 1.826, Val RMSE: 1.838
# 20: Train loss: 3.329, Train RMSE: 1.825, Val RMSE: 1.837
# 30: Train loss: 3.323, Train RMSE: 1.823, Val RMSE: 1.836
# 35: Train loss: 3.32, Train RMSE: 1.822, Val RMSE: 1.836
# Raw scatter=1.861 m/s
# Corrected scatter=1.836 m/s
# Stellar Error Removed=0.304 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 3, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.243, Train RMSE: 1.801, Val RMSE: 2.072
# 10: Train loss: 3.24, Train RMSE: 1.8, Val RMSE: 2.071
# 20: Train loss: 3.233, Train RMSE: 1.798, Val RMSE: 2.068
# 30: Train loss: 3.225, Train RMSE: 1.796, Val RMSE: 2.065
# 35: Train loss: 3.221, Train RMSE: 1.795, Val RMSE: 2.063
# Raw scatter=2.087 m/s
# Corrected scatter=2.063 m/s
# Stellar Error Removed=0.314 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 4, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.936
# 10: Train loss: 3.292, Train RMSE: 1.814, Val RMSE: 1.936
# 20: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.936
# 30: Train loss: 3.285, Train RMSE: 1.812, Val RMSE: 1.937
# 35: Train loss: 3.283, Train RMSE: 1.812, Val RMSE: 1.937
# Raw scatter=1.944 m/s
# Corrected scatter=1.937 m/s
# Stellar Error Removed=0.168 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 5, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.381, Train RMSE: 1.839, Val RMSE: 1.725
# 10: Train loss: 3.379, Train RMSE: 1.838, Val RMSE: 1.725
# 20: Train loss: 3.374, Train RMSE: 1.837, Val RMSE: 1.723
# 30: Train loss: 3.368, Train RMSE: 1.835, Val RMSE: 1.721
# 35: Train loss: 3.366, Train RMSE: 1.835, Val RMSE: 1.721
# Raw scatter=1.737 m/s
# Corrected scatter=1.721 m/s
# Stellar Error Removed=0.237 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 6, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.278, Train RMSE: 1.81, Val RMSE: 1.96
# 10: Train loss: 3.275, Train RMSE: 1.81, Val RMSE: 1.959
# 20: Train loss: 3.27, Train RMSE: 1.808, Val RMSE: 1.957
# 30: Train loss: 3.264, Train RMSE: 1.807, Val RMSE: 1.955
# 35: Train loss: 3.261, Train RMSE: 1.806, Val RMSE: 1.954
# Raw scatter=1.954 m/s
# Corrected scatter=1.954 m/s
# Stellar Error Removed=0.030 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 7, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.508, Train RMSE: 1.873, Val RMSE: 1.325
# 10: Train loss: 3.506, Train RMSE: 1.872, Val RMSE: 1.325
# 20: Train loss: 3.501, Train RMSE: 1.871, Val RMSE: 1.326
# 30: Train loss: 3.495, Train RMSE: 1.87, Val RMSE: 1.326
# 35: Train loss: 3.492, Train RMSE: 1.869, Val RMSE: 1.326
# Raw scatter=1.312 m/s
# Corrected scatter=1.326 m/s
# Stellar Error Removed=0.192 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 8, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.322, Train RMSE: 1.823, Val RMSE: 1.876
# 10: Train loss: 3.32, Train RMSE: 1.822, Val RMSE: 1.876
# 20: Train loss: 3.316, Train RMSE: 1.821, Val RMSE: 1.875
# 30: Train loss: 3.312, Train RMSE: 1.82, Val RMSE: 1.874
# 35: Train loss: 3.309, Train RMSE: 1.819, Val RMSE: 1.873
# Raw scatter=1.897 m/s
# Corrected scatter=1.873 m/s
# Stellar Error Removed=0.296 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 9, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.303, Train RMSE: 1.817, Val RMSE: 1.919
# 10: Train loss: 3.3, Train RMSE: 1.817, Val RMSE: 1.919
# 20: Train loss: 3.296, Train RMSE: 1.816, Val RMSE: 1.917
# 30: Train loss: 3.291, Train RMSE: 1.814, Val RMSE: 1.916
# 35: Train loss: 3.289, Train RMSE: 1.814, Val RMSE: 1.915
# Raw scatter=1.846 m/s
# Corrected scatter=1.915 m/s
# Stellar Error Removed=0.508 m/s
# ________________________
#
# Model 4. Learning_rate: 0.00015. Dense units: 200. Dense layers 12. Weight decay: 0.00024
# Cross-val number: 10, Model archictect. num: 4, Run number: 1
# 1: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.927
# 10: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.927
# 20: Train loss: 3.292, Train RMSE: 1.814, Val RMSE: 1.926
# 30: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.924
# 35: Train loss: 3.286, Train RMSE: 1.813, Val RMSE: 1.924
# Raw scatter=1.947 m/s
# Corrected scatter=1.924 m/s
# Stellar Error Removed=0.298 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 1, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.411, Train RMSE: 1.847, Val RMSE: 1.57
# 10: Train loss: 1.736, Train RMSE: 1.318, Val RMSE: 1.339
# 20: Train loss: 1.389, Train RMSE: 1.179, Val RMSE: 1.203
# 30: Train loss: 1.046, Train RMSE: 1.023, Val RMSE: 1.159
# 40: Train loss: 0.8595, Train RMSE: 0.9271, Val RMSE: 1.176
# 50: Train loss: 0.6617, Train RMSE: 0.8135, Val RMSE: 1.196
# Raw scatter=1.590 m/s
# Corrected scatter=1.196 m/s
# Stellar Error Removed=1.048 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 2, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.263, Train RMSE: 1.806, Val RMSE: 1.799
# 10: Train loss: 1.606, Train RMSE: 1.267, Val RMSE: 1.631
# 20: Train loss: 1.345, Train RMSE: 1.16, Val RMSE: 1.398
# 30: Train loss: 1.072, Train RMSE: 1.035, Val RMSE: 1.394
# 40: Train loss: 0.8542, Train RMSE: 0.9242, Val RMSE: 1.327
# 50: Train loss: 0.6946, Train RMSE: 0.8334, Val RMSE: 1.275
# Raw scatter=1.861 m/s
# Corrected scatter=1.275 m/s
# Stellar Error Removed=1.355 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 3, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.244, Train RMSE: 1.801, Val RMSE: 2.001
# 10: Train loss: 1.696, Train RMSE: 1.302, Val RMSE: 1.195
# 20: Train loss: 1.384, Train RMSE: 1.177, Val RMSE: 1.248
# 30: Train loss: 1.117, Train RMSE: 1.057, Val RMSE: 1.05
# 40: Train loss: 0.9054, Train RMSE: 0.9515, Val RMSE: 1.024
# 50: Train loss: 0.7401, Train RMSE: 0.8603, Val RMSE: 1.03
# Raw scatter=2.087 m/s
# Corrected scatter=1.030 m/s
# Stellar Error Removed=1.815 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 4, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.316, Train RMSE: 1.821, Val RMSE: 1.871
# 10: Train loss: 1.672, Train RMSE: 1.293, Val RMSE: 1.252
# 20: Train loss: 1.38, Train RMSE: 1.175, Val RMSE: 1.312
# 30: Train loss: 1.092, Train RMSE: 1.045, Val RMSE: 1.113
# 40: Train loss: 0.8693, Train RMSE: 0.9324, Val RMSE: 1.116
# 50: Train loss: 0.6963, Train RMSE: 0.8344, Val RMSE: 1.124
# Raw scatter=1.944 m/s
# Corrected scatter=1.124 m/s
# Stellar Error Removed=1.586 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 5, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.342, Train RMSE: 1.828, Val RMSE: 1.666
# 10: Train loss: 1.772, Train RMSE: 1.331, Val RMSE: 1.357
# 20: Train loss: 1.363, Train RMSE: 1.168, Val RMSE: 1.22
# 30: Train loss: 1.057, Train RMSE: 1.028, Val RMSE: 1.214
# 40: Train loss: 0.8896, Train RMSE: 0.9432, Val RMSE: 1.191
# 50: Train loss: 0.7044, Train RMSE: 0.8393, Val RMSE: 1.16
# Raw scatter=1.737 m/s
# Corrected scatter=1.160 m/s
# Stellar Error Removed=1.293 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 6, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.27, Train RMSE: 1.808, Val RMSE: 1.933
# 10: Train loss: 1.669, Train RMSE: 1.292, Val RMSE: 1.463
# 20: Train loss: 1.356, Train RMSE: 1.164, Val RMSE: 1.285
# 30: Train loss: 1.045, Train RMSE: 1.022, Val RMSE: 1.255
# 40: Train loss: 0.8599, Train RMSE: 0.9273, Val RMSE: 1.266
# 50: Train loss: 0.6856, Train RMSE: 0.828, Val RMSE: 1.237
# Raw scatter=1.954 m/s
# Corrected scatter=1.237 m/s
# Stellar Error Removed=1.513 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 7, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.499, Train RMSE: 1.871, Val RMSE: 1.299
# 10: Train loss: 1.746, Train RMSE: 1.321, Val RMSE: 1.28
# 20: Train loss: 1.438, Train RMSE: 1.199, Val RMSE: 1.187
# 30: Train loss: 1.145, Train RMSE: 1.07, Val RMSE: 1.195
# 40: Train loss: 0.9412, Train RMSE: 0.9701, Val RMSE: 1.153
# 50: Train loss: 0.7871, Train RMSE: 0.8872, Val RMSE: 1.116
# Raw scatter=1.312 m/s
# Corrected scatter=1.116 m/s
# Stellar Error Removed=0.691 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 8, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.437, Train RMSE: 1.854, Val RMSE: 1.885
# 10: Train loss: 1.676, Train RMSE: 1.295, Val RMSE: 1.299
# 20: Train loss: 1.401, Train RMSE: 1.183, Val RMSE: 1.26
# 30: Train loss: 1.094, Train RMSE: 1.046, Val RMSE: 1.134
# 40: Train loss: 0.8698, Train RMSE: 0.9326, Val RMSE: 1.106
# 50: Train loss: 0.6894, Train RMSE: 0.8303, Val RMSE: 1.132
# Raw scatter=1.897 m/s
# Corrected scatter=1.132 m/s
# Stellar Error Removed=1.522 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 9, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.371, Train RMSE: 1.836, Val RMSE: 1.869
# 10: Train loss: 1.705, Train RMSE: 1.306, Val RMSE: 1.246
# 20: Train loss: 1.412, Train RMSE: 1.188, Val RMSE: 1.084
# 30: Train loss: 1.103, Train RMSE: 1.05, Val RMSE: 1.057
# 40: Train loss: 0.9038, Train RMSE: 0.9507, Val RMSE: 1.061
# 50: Train loss: 0.7103, Train RMSE: 0.8428, Val RMSE: 1.036
# Raw scatter=1.846 m/s
# Corrected scatter=1.036 m/s
# Stellar Error Removed=1.529 m/s
# ________________________
#
# Model 5. Learning_rate: 0.00476. Dense units: 1000. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 10, Model archictect. num: 5, Run number: 1
# 1: Train loss: 3.246, Train RMSE: 1.802, Val RMSE: 1.858
# 10: Train loss: 1.695, Train RMSE: 1.302, Val RMSE: 1.312
# 20: Train loss: 1.409, Train RMSE: 1.187, Val RMSE: 1.291
# 30: Train loss: 1.101, Train RMSE: 1.049, Val RMSE: 1.147
# 40: Train loss: 0.9275, Train RMSE: 0.9631, Val RMSE: 1.106
# 50: Train loss: 0.7625, Train RMSE: 0.8732, Val RMSE: 1.085
# Raw scatter=1.947 m/s
# Corrected scatter=1.085 m/s
# Stellar Error Removed=1.616 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 1, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.459, Train RMSE: 1.86, Val RMSE: 1.577
# 10: Train loss: 3.37, Train RMSE: 1.836, Val RMSE: 1.559
# 20: Train loss: 3.19, Train RMSE: 1.786, Val RMSE: 1.527
# 30: Train loss: 3.006, Train RMSE: 1.734, Val RMSE: 1.494
# 40: Train loss: 2.835, Train RMSE: 1.684, Val RMSE: 1.461
# 50: Train loss: 2.677, Train RMSE: 1.636, Val RMSE: 1.43
# Raw scatter=1.590 m/s
# Corrected scatter=1.430 m/s
# Stellar Error Removed=0.696 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 2, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.378, Train RMSE: 1.838, Val RMSE: 1.835
# 10: Train loss: 3.217, Train RMSE: 1.793, Val RMSE: 1.796
# 20: Train loss: 2.938, Train RMSE: 1.714, Val RMSE: 1.741
# 30: Train loss: 2.704, Train RMSE: 1.644, Val RMSE: 1.698
# 40: Train loss: 2.523, Train RMSE: 1.588, Val RMSE: 1.666
# 50: Train loss: 2.379, Train RMSE: 1.542, Val RMSE: 1.64
# Raw scatter=1.861 m/s
# Corrected scatter=1.640 m/s
# Stellar Error Removed=0.879 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 3, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.123, Train RMSE: 1.767, Val RMSE: 2.013
# 10: Train loss: 3.053, Train RMSE: 1.747, Val RMSE: 1.984
# 20: Train loss: 2.913, Train RMSE: 1.707, Val RMSE: 1.932
# 30: Train loss: 2.768, Train RMSE: 1.664, Val RMSE: 1.875
# 40: Train loss: 2.634, Train RMSE: 1.623, Val RMSE: 1.82
# 50: Train loss: 2.517, Train RMSE: 1.586, Val RMSE: 1.768
# Raw scatter=2.087 m/s
# Corrected scatter=1.768 m/s
# Stellar Error Removed=1.108 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 4, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.334, Train RMSE: 1.826, Val RMSE: 1.88
# 10: Train loss: 3.227, Train RMSE: 1.797, Val RMSE: 1.857
# 20: Train loss: 3.022, Train RMSE: 1.738, Val RMSE: 1.817
# 30: Train loss: 2.824, Train RMSE: 1.68, Val RMSE: 1.774
# 40: Train loss: 2.653, Train RMSE: 1.629, Val RMSE: 1.733
# 50: Train loss: 2.506, Train RMSE: 1.583, Val RMSE: 1.692
# Raw scatter=1.944 m/s
# Corrected scatter=1.692 m/s
# Stellar Error Removed=0.956 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 5, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.69, Train RMSE: 1.921, Val RMSE: 1.818
# 10: Train loss: 3.497, Train RMSE: 1.87, Val RMSE: 1.76
# 20: Train loss: 3.173, Train RMSE: 1.781, Val RMSE: 1.668
# 30: Train loss: 2.905, Train RMSE: 1.704, Val RMSE: 1.591
# 40: Train loss: 2.698, Train RMSE: 1.643, Val RMSE: 1.53
# 50: Train loss: 2.529, Train RMSE: 1.59, Val RMSE: 1.479
# Raw scatter=1.737 m/s
# Corrected scatter=1.479 m/s
# Stellar Error Removed=0.911 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 6, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.417, Train RMSE: 1.848, Val RMSE: 1.964
# 10: Train loss: 3.316, Train RMSE: 1.821, Val RMSE: 1.933
# 20: Train loss: 3.116, Train RMSE: 1.765, Val RMSE: 1.877
# 30: Train loss: 2.913, Train RMSE: 1.707, Val RMSE: 1.821
# 40: Train loss: 2.73, Train RMSE: 1.652, Val RMSE: 1.768
# 50: Train loss: 2.569, Train RMSE: 1.603, Val RMSE: 1.721
# Raw scatter=1.954 m/s
# Corrected scatter=1.721 m/s
# Stellar Error Removed=0.926 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 7, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.722, Train RMSE: 1.929, Val RMSE: 1.32
# 10: Train loss: 3.601, Train RMSE: 1.898, Val RMSE: 1.301
# 20: Train loss: 3.374, Train RMSE: 1.837, Val RMSE: 1.27
# 30: Train loss: 3.15, Train RMSE: 1.775, Val RMSE: 1.24
# 40: Train loss: 2.953, Train RMSE: 1.719, Val RMSE: 1.214
# 50: Train loss: 2.78, Train RMSE: 1.667, Val RMSE: 1.191
# Raw scatter=1.312 m/s
# Corrected scatter=1.191 m/s
# Stellar Error Removed=0.552 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 8, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.698, Train RMSE: 1.923, Val RMSE: 1.955
# 10: Train loss: 3.536, Train RMSE: 1.88, Val RMSE: 1.909
# 20: Train loss: 3.241, Train RMSE: 1.8, Val RMSE: 1.83
# 30: Train loss: 2.964, Train RMSE: 1.722, Val RMSE: 1.753
# 40: Train loss: 2.733, Train RMSE: 1.653, Val RMSE: 1.684
# 50: Train loss: 2.539, Train RMSE: 1.593, Val RMSE: 1.621
# Raw scatter=1.897 m/s
# Corrected scatter=1.621 m/s
# Stellar Error Removed=0.985 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 9, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.388, Train RMSE: 1.841, Val RMSE: 1.964
# 10: Train loss: 3.251, Train RMSE: 1.803, Val RMSE: 1.883
# 20: Train loss: 3.003, Train RMSE: 1.733, Val RMSE: 1.749
# 30: Train loss: 2.778, Train RMSE: 1.667, Val RMSE: 1.63
# 40: Train loss: 2.592, Train RMSE: 1.61, Val RMSE: 1.532
# 50: Train loss: 2.434, Train RMSE: 1.56, Val RMSE: 1.454
# Raw scatter=1.846 m/s
# Corrected scatter=1.454 m/s
# Stellar Error Removed=1.139 m/s
# ________________________
#
# Model 6. Learning_rate: 0.00009. Dense units: 200. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 10, Model archictect. num: 6, Run number: 1
# 1: Train loss: 3.482, Train RMSE: 1.866, Val RMSE: 1.957
# 10: Train loss: 3.377, Train RMSE: 1.838, Val RMSE: 1.928
# 20: Train loss: 3.168, Train RMSE: 1.78, Val RMSE: 1.876
# 30: Train loss: 2.957, Train RMSE: 1.72, Val RMSE: 1.823
# 40: Train loss: 2.767, Train RMSE: 1.663, Val RMSE: 1.773
# 50: Train loss: 2.599, Train RMSE: 1.612, Val RMSE: 1.728
# Raw scatter=1.947 m/s
# Corrected scatter=1.728 m/s
# Stellar Error Removed=0.897 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 1, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.472, Train RMSE: 1.863, Val RMSE: 1.565
# 10: Train loss: 3.327, Train RMSE: 1.824, Val RMSE: 1.546
# 20: Train loss: 3.201, Train RMSE: 1.789, Val RMSE: 1.532
# 30: Train loss: 3.168, Train RMSE: 1.78, Val RMSE: 1.531
# 40: Train loss: 3.186, Train RMSE: 1.785, Val RMSE: 1.537
# 50: Train loss: 3.222, Train RMSE: 1.795, Val RMSE: 1.545
# Raw scatter=1.590 m/s
# Corrected scatter=1.545 m/s
# Stellar Error Removed=0.378 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 2, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.326, Train RMSE: 1.824, Val RMSE: 1.864
# 10: Train loss: 3.164, Train RMSE: 1.779, Val RMSE: 1.817
# 20: Train loss: 3.027, Train RMSE: 1.74, Val RMSE: 1.784
# 30: Train loss: 3.0, Train RMSE: 1.732, Val RMSE: 1.776
# 40: Train loss: 3.028, Train RMSE: 1.74, Val RMSE: 1.78
# 50: Train loss: 3.074, Train RMSE: 1.753, Val RMSE: 1.788
# Raw scatter=1.861 m/s
# Corrected scatter=1.788 m/s
# Stellar Error Removed=0.514 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 3, Model archictect. num: 7, Run number: 1
# 1: Train loss: 2.998, Train RMSE: 1.731, Val RMSE: 1.931
# 10: Train loss: 2.958, Train RMSE: 1.72, Val RMSE: 1.935
# 20: Train loss: 2.92, Train RMSE: 1.709, Val RMSE: 1.935
# 30: Train loss: 2.926, Train RMSE: 1.71, Val RMSE: 1.945
# 40: Train loss: 2.958, Train RMSE: 1.72, Val RMSE: 1.961
# 50: Train loss: 3.002, Train RMSE: 1.733, Val RMSE: 1.98
# Raw scatter=2.087 m/s
# Corrected scatter=1.980 m/s
# Stellar Error Removed=0.661 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 4, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.166, Train RMSE: 1.779, Val RMSE: 1.86
# 10: Train loss: 3.08, Train RMSE: 1.755, Val RMSE: 1.858
# 20: Train loss: 3.002, Train RMSE: 1.732, Val RMSE: 1.856
# 30: Train loss: 2.997, Train RMSE: 1.731, Val RMSE: 1.863
# 40: Train loss: 3.03, Train RMSE: 1.741, Val RMSE: 1.874
# 50: Train loss: 3.073, Train RMSE: 1.753, Val RMSE: 1.885
# Raw scatter=1.944 m/s
# Corrected scatter=1.885 m/s
# Stellar Error Removed=0.475 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 5, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.45, Train RMSE: 1.857, Val RMSE: 1.754
# 10: Train loss: 3.284, Train RMSE: 1.812, Val RMSE: 1.704
# 20: Train loss: 3.144, Train RMSE: 1.773, Val RMSE: 1.668
# 30: Train loss: 3.109, Train RMSE: 1.763, Val RMSE: 1.658
# 40: Train loss: 3.126, Train RMSE: 1.768, Val RMSE: 1.662
# 50: Train loss: 3.162, Train RMSE: 1.778, Val RMSE: 1.671
# Raw scatter=1.737 m/s
# Corrected scatter=1.671 m/s
# Stellar Error Removed=0.474 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 6, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.257, Train RMSE: 1.805, Val RMSE: 1.973
# 10: Train loss: 3.126, Train RMSE: 1.768, Val RMSE: 1.926
# 20: Train loss: 3.007, Train RMSE: 1.734, Val RMSE: 1.889
# 30: Train loss: 2.981, Train RMSE: 1.726, Val RMSE: 1.879
# 40: Train loss: 3.004, Train RMSE: 1.733, Val RMSE: 1.885
# 50: Train loss: 3.046, Train RMSE: 1.745, Val RMSE: 1.897
# Raw scatter=1.954 m/s
# Corrected scatter=1.897 m/s
# Stellar Error Removed=0.469 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 7, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.612, Train RMSE: 1.901, Val RMSE: 1.34
# 10: Train loss: 3.418, Train RMSE: 1.849, Val RMSE: 1.316
# 20: Train loss: 3.261, Train RMSE: 1.806, Val RMSE: 1.299
# 30: Train loss: 3.224, Train RMSE: 1.795, Val RMSE: 1.293
# 40: Train loss: 3.243, Train RMSE: 1.801, Val RMSE: 1.295
# 50: Train loss: 3.282, Train RMSE: 1.812, Val RMSE: 1.298
# Raw scatter=1.312 m/s
# Corrected scatter=1.298 m/s
# Stellar Error Removed=0.191 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 8, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.406, Train RMSE: 1.846, Val RMSE: 1.902
# 10: Train loss: 3.301, Train RMSE: 1.817, Val RMSE: 1.87
# 20: Train loss: 3.207, Train RMSE: 1.791, Val RMSE: 1.844
# 30: Train loss: 3.177, Train RMSE: 1.782, Val RMSE: 1.836
# 40: Train loss: 3.181, Train RMSE: 1.784, Val RMSE: 1.837
# 50: Train loss: 3.2, Train RMSE: 1.789, Val RMSE: 1.841
# Raw scatter=1.897 m/s
# Corrected scatter=1.841 m/s
# Stellar Error Removed=0.454 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 9, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.372, Train RMSE: 1.836, Val RMSE: 1.931
# 10: Train loss: 3.265, Train RMSE: 1.807, Val RMSE: 1.891
# 20: Train loss: 3.173, Train RMSE: 1.781, Val RMSE: 1.859
# 30: Train loss: 3.146, Train RMSE: 1.774, Val RMSE: 1.853
# 40: Train loss: 3.154, Train RMSE: 1.776, Val RMSE: 1.859
# 50: Train loss: 3.176, Train RMSE: 1.782, Val RMSE: 1.87
# Raw scatter=1.846 m/s
# Corrected scatter=1.870 m/s
# Stellar Error Removed=0.293 m/s
# ________________________
#
# Model 7. Learning_rate: 0.00016. Dense units: 200. Dense layers 4. Weight decay: 0.00800
# Cross-val number: 10, Model archictect. num: 7, Run number: 1
# 1: Train loss: 3.575, Train RMSE: 1.891, Val RMSE: 1.999
# 10: Train loss: 3.35, Train RMSE: 1.83, Val RMSE: 1.942
# 20: Train loss: 3.167, Train RMSE: 1.78, Val RMSE: 1.9
# 30: Train loss: 3.104, Train RMSE: 1.762, Val RMSE: 1.885
# 40: Train loss: 3.103, Train RMSE: 1.762, Val RMSE: 1.884
# 50: Train loss: 3.126, Train RMSE: 1.768, Val RMSE: 1.889
# Raw scatter=1.947 m/s
# Corrected scatter=1.889 m/s
# Stellar Error Removed=0.471 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 1, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.478, Train RMSE: 1.865, Val RMSE: 1.578
# 10: Train loss: 3.413, Train RMSE: 1.847, Val RMSE: 1.565
# 20: Train loss: 3.28, Train RMSE: 1.811, Val RMSE: 1.54
# 30: Train loss: 3.138, Train RMSE: 1.771, Val RMSE: 1.513
# 35: Train loss: 3.069, Train RMSE: 1.752, Val RMSE: 1.501
# Raw scatter=1.590 m/s
# Corrected scatter=1.501 m/s
# Stellar Error Removed=0.527 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 2, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.294, Train RMSE: 1.815, Val RMSE: 1.833
# 10: Train loss: 3.224, Train RMSE: 1.796, Val RMSE: 1.815
# 20: Train loss: 3.084, Train RMSE: 1.756, Val RMSE: 1.783
# 30: Train loss: 2.937, Train RMSE: 1.714, Val RMSE: 1.75
# 35: Train loss: 2.867, Train RMSE: 1.693, Val RMSE: 1.734
# Raw scatter=1.861 m/s
# Corrected scatter=1.734 m/s
# Stellar Error Removed=0.674 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 3, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.328, Train RMSE: 1.824, Val RMSE: 2.054
# 10: Train loss: 3.277, Train RMSE: 1.81, Val RMSE: 2.036
# 20: Train loss: 3.172, Train RMSE: 1.781, Val RMSE: 2.001
# 30: Train loss: 3.056, Train RMSE: 1.748, Val RMSE: 1.962
# 35: Train loss: 2.999, Train RMSE: 1.732, Val RMSE: 1.943
# Raw scatter=2.087 m/s
# Corrected scatter=1.943 m/s
# Stellar Error Removed=0.763 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 4, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.396, Train RMSE: 1.843, Val RMSE: 1.945
# 10: Train loss: 3.304, Train RMSE: 1.818, Val RMSE: 1.925
# 20: Train loss: 3.125, Train RMSE: 1.768, Val RMSE: 1.89
# 30: Train loss: 2.949, Train RMSE: 1.717, Val RMSE: 1.854
# 35: Train loss: 2.87, Train RMSE: 1.694, Val RMSE: 1.837
# Raw scatter=1.944 m/s
# Corrected scatter=1.837 m/s
# Stellar Error Removed=0.636 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 5, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.357, Train RMSE: 1.832, Val RMSE: 1.704
# 10: Train loss: 3.294, Train RMSE: 1.815, Val RMSE: 1.685
# 20: Train loss: 3.166, Train RMSE: 1.779, Val RMSE: 1.651
# 30: Train loss: 3.029, Train RMSE: 1.741, Val RMSE: 1.614
# 35: Train loss: 2.964, Train RMSE: 1.721, Val RMSE: 1.596
# Raw scatter=1.737 m/s
# Corrected scatter=1.596 m/s
# Stellar Error Removed=0.685 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 6, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.313, Train RMSE: 1.82, Val RMSE: 1.975
# 10: Train loss: 3.249, Train RMSE: 1.803, Val RMSE: 1.952
# 20: Train loss: 3.123, Train RMSE: 1.767, Val RMSE: 1.91
# 30: Train loss: 2.991, Train RMSE: 1.729, Val RMSE: 1.867
# 35: Train loss: 2.928, Train RMSE: 1.711, Val RMSE: 1.847
# Raw scatter=1.954 m/s
# Corrected scatter=1.847 m/s
# Stellar Error Removed=0.638 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 7, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.725, Train RMSE: 1.93, Val RMSE: 1.358
# 10: Train loss: 3.619, Train RMSE: 1.902, Val RMSE: 1.344
# 20: Train loss: 3.413, Train RMSE: 1.847, Val RMSE: 1.322
# 30: Train loss: 3.21, Train RMSE: 1.792, Val RMSE: 1.3
# 35: Train loss: 3.118, Train RMSE: 1.766, Val RMSE: 1.29
# Raw scatter=1.312 m/s
# Corrected scatter=1.290 m/s
# Stellar Error Removed=0.244 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 8, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.256, Train RMSE: 1.805, Val RMSE: 1.865
# 10: Train loss: 3.197, Train RMSE: 1.788, Val RMSE: 1.845
# 20: Train loss: 3.075, Train RMSE: 1.753, Val RMSE: 1.809
# 30: Train loss: 2.943, Train RMSE: 1.715, Val RMSE: 1.77
# 35: Train loss: 2.879, Train RMSE: 1.697, Val RMSE: 1.751
# Raw scatter=1.897 m/s
# Corrected scatter=1.751 m/s
# Stellar Error Removed=0.730 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 9, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.346, Train RMSE: 1.829, Val RMSE: 1.98
# 10: Train loss: 3.274, Train RMSE: 1.809, Val RMSE: 1.944
# 20: Train loss: 3.129, Train RMSE: 1.769, Val RMSE: 1.878
# 30: Train loss: 2.977, Train RMSE: 1.725, Val RMSE: 1.809
# 35: Train loss: 2.905, Train RMSE: 1.705, Val RMSE: 1.777
# Raw scatter=1.846 m/s
# Corrected scatter=1.777 m/s
# Stellar Error Removed=0.501 m/s
# ________________________
#
# Model 8. Learning_rate: 0.00006. Dense units: 500. Dense layers 4. Weight decay: 0.00024
# Cross-val number: 10, Model archictect. num: 8, Run number: 1
# 1: Train loss: 3.222, Train RMSE: 1.795, Val RMSE: 1.903
# 10: Train loss: 3.156, Train RMSE: 1.777, Val RMSE: 1.885
# 20: Train loss: 3.02, Train RMSE: 1.738, Val RMSE: 1.851
# 30: Train loss: 2.875, Train RMSE: 1.696, Val RMSE: 1.814
# 35: Train loss: 2.806, Train RMSE: 1.675, Val RMSE: 1.796
# Raw scatter=1.947 m/s
# Corrected scatter=1.796 m/s
# Stellar Error Removed=0.751 m/s
# ________________________
#
# Model 9. Learning_rate: 0.00568. Dense units: 200. Dense layers 16. Weight decay: 0.00139
# Cross-val number: 1, Model archictect. num: 9, Run number: 1
# 1: Train loss: 3.437, Train RMSE: 1.854, Val RMSE: 1.584
# 10: Train loss: 3.414, Train RMSE: 1.848, Val RMSE: 1.592
# 20: Train loss: 3.371, Train RMSE: 1.836, Val RMSE: 1.59
# 30: Train loss: 3.247, Train RMSE: 1.802, Val RMSE: 1.552
# 35: Train loss: 3.113, Train RMSE: 1.764, Val RMSE: 1.51
# Raw scatter=1.590 m/s
# Corrected scatter=1.510 m/s
# Stellar Error Removed=0.500 m/s
# ________________________
#
# Model 9. Learning_rate: 0.00568. Dense units: 200. Dense layers 16. Weight decay: 0.00139
# Cross-val number: 2, Model archictect. num: 9, Run number: 1
# 1: Train loss: 3.338, Train RMSE: 1.827, Val RMSE: 1.838
# 10: Train loss: 3.32, Train RMSE: 1.822, Val RMSE: 1.835
# 20: Train loss: 3.275, Train RMSE: 1.81, Val RMSE: 1.825
# 30: Train loss: 3.126, Train RMSE: 1.768, Val RMSE: 1.796
# 35: Train loss: 2.955, Train RMSE: 1.719, Val RMSE: 1.767
# Raw scatter=1.861 m/s
# Corrected scatter=1.767 m/s
# Stellar Error Removed=0.583 m/s
# ________________________
#
# Model 9. Learning_rate: 0.00568. Dense units: 200. Dense layers 16. Weight decay: 0.00139
# Cross-val number: 3, Model archictect. num: 9, Run number: 1
# 1: Train loss: 3.237, Train RMSE: 1.799, Val RMSE: 2.069
# 10: Train loss: 3.216, Train RMSE: 1.793, Val RMSE: 2.059
# 20: Train loss: 3.159, Train RMSE: 1.777, Val RMSE: 2.037
# 30: Train loss: 2.987, Train RMSE: 1.728, Val RMSE: 1.972
# 35: Train loss: 2.775, Train RMSE: 1.666, Val RMSE: 1.885
# Raw scatter=2.087 m/s
# Corrected scatter=1.885 m/s
# Stellar Error Removed=0.896 m/s
# ________________________
#
# Model 9. Learning_rate: 0.00568. Dense units: 200. Dense layers 16. Weight decay: 0.00139
# Cross-val number: 4, Model archictect. num: 9, Run number: 1
# 1: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.936
# 10: Train loss: 3.275, Train RMSE: 1.81, Val RMSE: 1.947
# 20: Train loss: 3.256, Train RMSE: 1.805, Val RMSE: 1.951
# 30: Train loss: 3.199, Train RMSE: 1.789, Val RMSE: 1.931
# 35: Train loss: 3.131, Train RMSE: 1.769, Val RMSE: 1.909
# Raw scatter=1.944 m/s
# Corrected scatter=1.909 m/s
# Stellar Error Removed=0.368 m/s
# ________________________
#
# ...
# 10: Train loss: 2.895, Train RMSE: 1.702, Val RMSE: 1.471
# 20: Train loss: 3.377, Train RMSE: 1.838, Val RMSE: 1.717
# 30: Train loss: 3.694, Train RMSE: 1.922, Val RMSE: 1.741
# 40: Train loss: 3.439, Train RMSE: 1.854, Val RMSE: 1.778
# 50: Train loss: 3.435, Train RMSE: 1.853, Val RMSE: 1.718
# Raw scatter=1.737 m/s
# Corrected scatter=1.718 m/s
# Stellar Error Removed=0.253 m/s
# ________________________
#
# Model 39. Learning_rate: 0.08499. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 6, Model archictect. num: 39, Run number: 1
# 1: Train loss: 3.286, Train RMSE: 1.813, Val RMSE: 1.957
# 10: Train loss: 3.104, Train RMSE: 1.762, Val RMSE: 1.855
# 20: Train loss: 3.376, Train RMSE: 1.837, Val RMSE: 1.931
# 30: Train loss: 3.285, Train RMSE: 1.812, Val RMSE: 1.941
# 40: Train loss: 3.289, Train RMSE: 1.814, Val RMSE: 1.963
# 50: Train loss: 3.284, Train RMSE: 1.812, Val RMSE: 1.962
# Raw scatter=1.954 m/s
# Corrected scatter=1.962 m/s
# Stellar Error Removed=0.174 m/s
# ________________________
#
# Model 39. Learning_rate: 0.08499. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 7, Model archictect. num: 39, Run number: 1
# 1: Train loss: 3.52, Train RMSE: 1.876, Val RMSE: 1.33
# 10: Train loss: 3.319, Train RMSE: 1.822, Val RMSE: 1.288
# 20: Train loss: 3.554, Train RMSE: 1.885, Val RMSE: 1.446
# 30: Train loss: 3.498, Train RMSE: 1.87, Val RMSE: 1.379
# 40: Train loss: 259.8, Train RMSE: 16.12, Val RMSE: 19.53
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/ipykernel_launcher.py:53: RuntimeWarning: overflow encountered in square
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: overflow encountered in square
# 50: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# Raw scatter=1.312 m/s
# Corrected scatter=nan m/s
# Stellar Error Removed=nan m/s
# ________________________
#
# Model 39. Learning_rate: 0.08499. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 8, Model archictect. num: 39, Run number: 1
# 1: Train loss: 3.326, Train RMSE: 1.824, Val RMSE: 1.874
# 10: Train loss: 3.25, Train RMSE: 1.803, Val RMSE: 1.846
# 20: Train loss: 3.892, Train RMSE: 1.973, Val RMSE: 2.075
# 30: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# 40: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# 50: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# Raw scatter=1.897 m/s
# Corrected scatter=nan m/s
# Stellar Error Removed=nan m/s
# ________________________
#
# Model 39. Learning_rate: 0.08499. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 9, Model archictect. num: 39, Run number: 1
# 1: Train loss: 3.304, Train RMSE: 1.818, Val RMSE: 1.919
# 10: Train loss: 3.245, Train RMSE: 1.801, Val RMSE: 1.887
# 20: Train loss: 3.243e+32, Train RMSE: 1.801e+16, Val RMSE: nan
# 30: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# 40: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# 50: Train loss: nan, Train RMSE: nan, Val RMSE: nan
# Raw scatter=1.846 m/s
# Corrected scatter=nan m/s
# Stellar Error Removed=nan m/s
# ________________________
#
# Model 39. Learning_rate: 0.08499. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 10, Model archictect. num: 39, Run number: 1
# 1: Train loss: 3.301, Train RMSE: 1.817, Val RMSE: 1.926
# 10: Train loss: 3.121, Train RMSE: 1.767, Val RMSE: 1.844
# 20: Train loss: 1.992, Train RMSE: 1.411, Val RMSE: 1.788
# 30: Train loss: 2.417, Train RMSE: 1.555, Val RMSE: 1.655
# 40: Train loss: 2.842, Train RMSE: 1.686, Val RMSE: 1.671
# 50: Train loss: 3.624, Train RMSE: 1.904, Val RMSE: 1.988
# Raw scatter=1.947 m/s
# Corrected scatter=1.988 m/s
# Stellar Error Removed=0.403 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 1, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.428, Train RMSE: 1.851, Val RMSE: 1.579
# 10: Train loss: 3.427, Train RMSE: 1.851, Val RMSE: 1.581
# 20: Train loss: 3.427, Train RMSE: 1.851, Val RMSE: 1.582
# 30: Train loss: 3.429, Train RMSE: 1.852, Val RMSE: 1.583
# 35: Train loss: 3.429, Train RMSE: 1.852, Val RMSE: 1.583
# Raw scatter=1.590 m/s
# Corrected scatter=1.583 m/s
# Stellar Error Removed=0.151 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 2, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.337, Train RMSE: 1.827, Val RMSE: 1.839
# 10: Train loss: 3.335, Train RMSE: 1.826, Val RMSE: 1.838
# 20: Train loss: 3.334, Train RMSE: 1.826, Val RMSE: 1.838
# 30: Train loss: 3.334, Train RMSE: 1.826, Val RMSE: 1.838
# 35: Train loss: 3.334, Train RMSE: 1.826, Val RMSE: 1.838
# Raw scatter=1.861 m/s
# Corrected scatter=1.838 m/s
# Stellar Error Removed=0.289 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 3, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.231, Train RMSE: 1.798, Val RMSE: 2.062
# 10: Train loss: 3.232, Train RMSE: 1.798, Val RMSE: 2.065
# 20: Train loss: 3.233, Train RMSE: 1.798, Val RMSE: 2.066
# 30: Train loss: 3.234, Train RMSE: 1.798, Val RMSE: 2.067
# 35: Train loss: 3.235, Train RMSE: 1.799, Val RMSE: 2.068
# Raw scatter=2.087 m/s
# Corrected scatter=2.068 m/s
# Stellar Error Removed=0.284 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 4, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.935
# 10: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.935
# 20: Train loss: 3.291, Train RMSE: 1.814, Val RMSE: 1.935
# 30: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.935
# 35: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.935
# Raw scatter=1.944 m/s
# Corrected scatter=1.935 m/s
# Stellar Error Removed=0.188 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 5, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.381, Train RMSE: 1.839, Val RMSE: 1.728
# 10: Train loss: 3.379, Train RMSE: 1.838, Val RMSE: 1.727
# 20: Train loss: 3.378, Train RMSE: 1.838, Val RMSE: 1.726
# 30: Train loss: 3.379, Train RMSE: 1.838, Val RMSE: 1.726
# 35: Train loss: 3.379, Train RMSE: 1.838, Val RMSE: 1.726
# Raw scatter=1.737 m/s
# Corrected scatter=1.726 m/s
# Stellar Error Removed=0.194 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 6, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.26, Train RMSE: 1.806, Val RMSE: 1.952
# 10: Train loss: 3.27, Train RMSE: 1.808, Val RMSE: 1.957
# 20: Train loss: 3.275, Train RMSE: 1.81, Val RMSE: 1.96
# 30: Train loss: 3.279, Train RMSE: 1.811, Val RMSE: 1.961
# 35: Train loss: 3.28, Train RMSE: 1.811, Val RMSE: 1.962
# Raw scatter=1.954 m/s
# Corrected scatter=1.962 m/s
# Stellar Error Removed=0.175 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 7, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.528, Train RMSE: 1.878, Val RMSE: 1.314
# 10: Train loss: 3.52, Train RMSE: 1.876, Val RMSE: 1.317
# 20: Train loss: 3.516, Train RMSE: 1.875, Val RMSE: 1.32
# 30: Train loss: 3.515, Train RMSE: 1.875, Val RMSE: 1.321
# 35: Train loss: 3.515, Train RMSE: 1.875, Val RMSE: 1.321
# Raw scatter=1.312 m/s
# Corrected scatter=1.321 m/s
# Stellar Error Removed=0.154 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 8, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.338, Train RMSE: 1.827, Val RMSE: 1.878
# 10: Train loss: 3.328, Train RMSE: 1.824, Val RMSE: 1.875
# 20: Train loss: 3.323, Train RMSE: 1.823, Val RMSE: 1.874
# 30: Train loss: 3.321, Train RMSE: 1.822, Val RMSE: 1.873
# 35: Train loss: 3.321, Train RMSE: 1.822, Val RMSE: 1.873
# Raw scatter=1.897 m/s
# Corrected scatter=1.873 m/s
# Stellar Error Removed=0.296 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 9, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.301, Train RMSE: 1.817, Val RMSE: 1.914
# 10: Train loss: 3.3, Train RMSE: 1.817, Val RMSE: 1.917
# 20: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.919
# 30: Train loss: 3.3, Train RMSE: 1.816, Val RMSE: 1.92
# 35: Train loss: 3.3, Train RMSE: 1.817, Val RMSE: 1.92
# Raw scatter=1.846 m/s
# Corrected scatter=1.920 m/s
# Stellar Error Removed=0.526 m/s
# ________________________
#
# Model 40. Learning_rate: 0.00005. Dense units: 1000. Dense layers 8. Weight decay: 0.00800
# Cross-val number: 10, Model archictect. num: 40, Run number: 1
# 1: Train loss: 3.325, Train RMSE: 1.824, Val RMSE: 1.931
# 10: Train loss: 3.309, Train RMSE: 1.819, Val RMSE: 1.928
# 20: Train loss: 3.301, Train RMSE: 1.817, Val RMSE: 1.927
# 30: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.927
# 35: Train loss: 3.298, Train RMSE: 1.816, Val RMSE: 1.927
# Raw scatter=1.947 m/s
# Corrected scatter=1.927 m/s
# Stellar Error Removed=0.276 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 1, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.437, Train RMSE: 1.854, Val RMSE: 1.582
# 10: Train loss: 3.434, Train RMSE: 1.853, Val RMSE: 1.582
# 20: Train loss: 3.427, Train RMSE: 1.851, Val RMSE: 1.581
# 30: Train loss: 3.419, Train RMSE: 1.849, Val RMSE: 1.58
# Raw scatter=1.590 m/s
# Corrected scatter=1.580 m/s
# Stellar Error Removed=0.182 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 2, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.359, Train RMSE: 1.833, Val RMSE: 1.843
# 10: Train loss: 3.356, Train RMSE: 1.832, Val RMSE: 1.842
# 20: Train loss: 3.351, Train RMSE: 1.831, Val RMSE: 1.841
# 30: Train loss: 3.344, Train RMSE: 1.829, Val RMSE: 1.84
# Raw scatter=1.861 m/s
# Corrected scatter=1.840 m/s
# Stellar Error Removed=0.277 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 3, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.245, Train RMSE: 1.801, Val RMSE: 2.073
# 10: Train loss: 3.243, Train RMSE: 1.801, Val RMSE: 2.072
# 20: Train loss: 3.238, Train RMSE: 1.799, Val RMSE: 2.07
# 30: Train loss: 3.232, Train RMSE: 1.798, Val RMSE: 2.068
# Raw scatter=2.087 m/s
# Corrected scatter=2.068 m/s
# Stellar Error Removed=0.282 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 4, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.307, Train RMSE: 1.819, Val RMSE: 1.931
# 10: Train loss: 3.304, Train RMSE: 1.818, Val RMSE: 1.93
# 20: Train loss: 3.298, Train RMSE: 1.816, Val RMSE: 1.929
# 30: Train loss: 3.291, Train RMSE: 1.814, Val RMSE: 1.929
# Raw scatter=1.944 m/s
# Corrected scatter=1.929 m/s
# Stellar Error Removed=0.245 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 5, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.394, Train RMSE: 1.842, Val RMSE: 1.731
# 10: Train loss: 3.392, Train RMSE: 1.842, Val RMSE: 1.73
# 20: Train loss: 3.387, Train RMSE: 1.84, Val RMSE: 1.729
# 30: Train loss: 3.381, Train RMSE: 1.839, Val RMSE: 1.728
# Raw scatter=1.737 m/s
# Corrected scatter=1.728 m/s
# Stellar Error Removed=0.179 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 6, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.275, Train RMSE: 1.81, Val RMSE: 1.963
# 10: Train loss: 3.273, Train RMSE: 1.809, Val RMSE: 1.962
# 20: Train loss: 3.267, Train RMSE: 1.808, Val RMSE: 1.96
# 30: Train loss: 3.261, Train RMSE: 1.806, Val RMSE: 1.958
# Raw scatter=1.954 m/s
# Corrected scatter=1.958 m/s
# Stellar Error Removed=0.123 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 7, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.509, Train RMSE: 1.873, Val RMSE: 1.312
# 10: Train loss: 3.505, Train RMSE: 1.872, Val RMSE: 1.312
# 20: Train loss: 3.496, Train RMSE: 1.87, Val RMSE: 1.311
# 30: Train loss: 3.486, Train RMSE: 1.867, Val RMSE: 1.311
# Raw scatter=1.312 m/s
# Corrected scatter=1.311 m/s
# Stellar Error Removed=0.066 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 8, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.328, Train RMSE: 1.824, Val RMSE: 1.875
# 10: Train loss: 3.325, Train RMSE: 1.824, Val RMSE: 1.874
# 20: Train loss: 3.319, Train RMSE: 1.822, Val RMSE: 1.872
# 30: Train loss: 3.312, Train RMSE: 1.82, Val RMSE: 1.871
# Raw scatter=1.897 m/s
# Corrected scatter=1.871 m/s
# Stellar Error Removed=0.313 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 9, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.311, Train RMSE: 1.82, Val RMSE: 1.913
# 10: Train loss: 3.309, Train RMSE: 1.819, Val RMSE: 1.913
# 20: Train loss: 3.305, Train RMSE: 1.818, Val RMSE: 1.911
# 30: Train loss: 3.3, Train RMSE: 1.817, Val RMSE: 1.91
# Raw scatter=1.846 m/s
# Corrected scatter=1.910 m/s
# Stellar Error Removed=0.488 m/s
# ________________________
#
# Model 41. Learning_rate: 0.00003. Dense units: 1000. Dense layers 8. Weight decay: 0.00010
# Cross-val number: 10, Model archictect. num: 41, Run number: 1
# 1: Train loss: 3.308, Train RMSE: 1.819, Val RMSE: 1.931
# 10: Train loss: 3.305, Train RMSE: 1.818, Val RMSE: 1.93
# 20: Train loss: 3.301, Train RMSE: 1.817, Val RMSE: 1.929
# 30: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.928
# Raw scatter=1.947 m/s
# Corrected scatter=1.928 m/s
# Stellar Error Removed=0.270 m/s
# ________________________
#
# Model 42. Learning_rate: 0.01314. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 1, Model archictect. num: 42, Run number: 1
# 1: Train loss: 3.437, Train RMSE: 1.854, Val RMSE: 1.584
# 10: Train loss: 3.412, Train RMSE: 1.847, Val RMSE: 1.603
# 20: Train loss: 3.407, Train RMSE: 1.846, Val RMSE: 1.601
# 30: Train loss: 3.403, Train RMSE: 1.845, Val RMSE: 1.595
# 40: Train loss: 3.404, Train RMSE: 1.845, Val RMSE: 1.599
# Raw scatter=1.590 m/s
# Corrected scatter=1.599 m/s
# Stellar Error Removed=0.163 m/s
# ________________________
#
# Model 42. Learning_rate: 0.01314. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 2, Model archictect. num: 42, Run number: 1
# 1: Train loss: 3.336, Train RMSE: 1.826, Val RMSE: 1.838
# 10: Train loss: 3.312, Train RMSE: 1.82, Val RMSE: 1.836
# 20: Train loss: 3.281, Train RMSE: 1.811, Val RMSE: 1.829
# 30: Train loss: 3.222, Train RMSE: 1.795, Val RMSE: 1.818
# 40: Train loss: 3.008, Train RMSE: 1.734, Val RMSE: 1.781
# Raw scatter=1.861 m/s
# Corrected scatter=1.781 m/s
# Stellar Error Removed=0.538 m/s
# ________________________
#
# Model 42. Learning_rate: 0.01314. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 3, Model archictect. num: 42, Run number: 1
# 1: Train loss: 3.239, Train RMSE: 1.8, Val RMSE: 2.069
# 10: Train loss: 3.225, Train RMSE: 1.796, Val RMSE: 2.06
# 20: Train loss: 3.217, Train RMSE: 1.794, Val RMSE: 2.059
# 30: Train loss: 3.213, Train RMSE: 1.792, Val RMSE: 2.058
# 40: Train loss: 3.213, Train RMSE: 1.792, Val RMSE: 2.058
# Raw scatter=2.087 m/s
# Corrected scatter=2.058 m/s
# Stellar Error Removed=0.346 m/s
# ________________________
#
# Model 42. Learning_rate: 0.01314. Dense units: 100. Dense layers 16. Weight decay: 0.00800
# Cross-val number: 4, Model archictect. num: 42, Run number: 1
# 1: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.936
# 10: Train loss: 3.277, Train RMSE: 1.81, Val RMSE: 1.954

# %%
# !ls $LOG_DIR_1

# %%
# %tensorboard --logdir $LOG_DIR_1
# Out:
#       <iframe id="tensorboard-frame-d0bd9155ba320963" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d0bd9155ba320963");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# parallelize code

import multiprocess as mp
import time

# Define a function that compiles the global results
def get_result(result):
    global results
    results.append(result)

def my_fc_nn_optimizer(learning_rate_list, dense_units_list, num_dense_layers_list, weight_decay_list, LOG_DIR_1, model_num):
    #model_num = 1
    result = []
    val_rmse_list = []
    
    rms_avg_list = []
    weight_decay_list_t = []
    gaussian_noise_list_t = []
    rms_x_list = []

    all_bjds_val = []
    all_pred_val = []
    all_labels_val = []
    all_mean_val_preds = []
    all_mean_val_bjds = []
    all_mean_val_labels = []
    all_mean_val_bjds = []
    
    
    hparams = configdict.ConfigDict(dict(
          num_features=46,
          learning_rate=np.random.choice(learning_rate_list),
          momentum=0.9,
          batch_size=1024,
          num_dense_units=int(np.random.choice(dense_units_list)),
          num_dense_layers=int(np.random.choice(num_dense_layers_list)),
          weight_decay=np.random.choice(weight_decay_list), #5e-4, #7e-2,
          gaussian_noise_scale=0,#1.5,
      ))
    epochs = np.random.choice(num_epochs_list)
    for index in range(0, len(VAL_FILE_NAME_LIST)):
        TRAIN_FILE_NAME = TRAIN_FILE_NAME_LIST[index]
        VAL_FILE_NAME = VAL_FILE_NAME_LIST[index]

        bjd_run_val = []
        pred_run_val = []
        labels_run_val = []
        k=0
        #for k in range(0,1):
        print("Model {}. Learning_rate: {:.5f}. Dense units: {}. Dense layers {}. Weight decay: {:.5f}".format(
              model_num, hparams.learning_rate, hparams.num_dense_units, hparams.num_dense_layers, hparams.weight_decay))
        print("Cross-val number: "+str(index+1)+", Model archictect. num: "+str(i+1)+", Run number: "+str(k+1))
        model = FCModel(hparams)
        run_dir = LOG_DIR_1 + "/{}/".format(model_num)
        with tf.summary.create_file_writer(run_dir).as_default():
            hp.hparams(hparams)  # record the values used in this trial
            metric_values = train(model, hparams, plots="OFF", model_name = "FC NN",num_epochs=epochs)
            final_metrics = metric_values[-1]
            print("val_rmse: "+str(final_metrics['val_rmse']))

        print("________________________")
        print()
        mean_val_preds = np.mean(pred_run_val, axis=0)
        mean_val_labels = np.mean(labels_run_val, axis=0)
        mean_val_bjds = np.mean(bjd_run_val, axis=0)

        all_mean_val_preds.append(mean_val_preds)
        all_mean_val_labels.append(mean_val_labels)
        all_mean_val_bjds.append(mean_val_bjds)

        all_pred_val.append(pred_run_val)
        all_labels_val.append(labels_run_val)
        all_bjds_val.append(bjd_run_val)
        val_rmse_list.append(final_metrics['val_rmse'])
  
    result1 = np.mean(val_rmse_list)
    #result.append([1])
    model_num += 1

    return result

# %%
# Define a function that compiles the global results
def get_result(result):
    global results
    results.append(result)

# temp simple function
def temp_my_fc_nn_optimizer(learning_rate_list, dense_units_list, num_dense_layers_list, weight_decay_list, LOG_DIR_1, model_num):
    result = []
    result.append([1])
    return result

# %%
from multiprocess import get_context
sys.modules['__main__'].__file__ = 'ipython'

# %%
if __name__ == '__main__':
    folder = 'logs/'
    if not os.path.isdir(folder):
            os.mkdir(folder)

    LOG_DIR_1 = folder + time.strftime("%Y%m%d-%H%M%S", time.localtime())
    print(LOG_DIR_1)

    # Log the hparam config. This is optional but makes tensorboard show the right ranges.
    with tf.summary.create_file_writer(LOG_DIR_1).as_default():
      hp.hparams_config(
        hparams=[
                 hp.HParam('learning_rate', hp.RealInterval(1e-4, 1e-2)),
                 hp.HParam('num_dense_units', hp.Discrete([100, 200, 500, 1000])),
                 hp.HParam('num_dense_layers', hp.Discrete([4, 8, 12, 16])),
                 hp.HParam('weight_decay', hp.RealInterval(5e-4,5e-2))],
        metrics=[hp.Metric("val_rmse", display_name='RMSE'),
                 hp.Metric("original_rmse", display_name="OG RMSE"),
                 hp.Metric("difference_rmse", display_name="diff RMSE"),
                ],
      )

    results = []


    ts = time.time()
    # count the number of cpus present on your machine
    num_cpus = 2#mp.cpu_count()
    print("Number of CPUs used: "+str(num_cpus))

    # Pool class represents a pool of worker processes
    pool = mp.Pool(num_cpus)
    #pool = get_context("spawn").Pool(num_cpus)
    for model_num in range(1):
        # apply_async is applying the process asynchronously - meaning that it will start as soon as computing resources become available.
        # it will not wait for a task to finish to start a new one
        pool.apply_async(my_fc_nn_optimizer, args=(learning_rate_list, dense_units_list, num_dense_layers_list, weight_decay_list, LOG_DIR_1, model_num), callback=get_result)
    pool.close()

    pool.join()

    print('Time in parallel:', time.time() - ts)
# Out:
# logs/20211206-231820
# Number of CPUs used: 2
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 1, Model archictect. num: 2, Run number: 1
# Process ForkPoolWorker-106:
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process SpawnPoolWorker-102:
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-101:
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 354, in get
#     with self._rlock:
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-100:
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process SpawnPoolWorker-99:
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ipython in <module>
#      38     pool.close()
#      39
# ---> 40     pool.join()
#      41
#      42     print('Time in parallel:', time.time() - ts)
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py in join(self)
#     554         elif self._state not in (CLOSE, TERMINATE):
#     555             raise ValueError("In unknown state")
# --> 556         self._worker_handler.join()
#     557         self._task_handler.join()
#     558         self._result_handler.join()
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# ~/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-109:
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/pool.py", line 110, in worker
#     task = get()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/queues.py", line 355, in get
#     res = self._reader.recv_bytes()
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
results
# Out:
# []

# %%
LOG_DIR_1
# Out:
# 'logs/20211206-173838'

# %%
# !ls $LOG_DIR_1
# Out:
# 0
# events.out.tfevents.1638830466.dhcp-10-29-86-57.dyn.mit.edu.79853.1646176.v2

# %%
# %tensorboard --logdir $LOG_DIR_1
# Out:
#       <iframe id="tensorboard-frame-101a2cf7394d81df" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-101a2cf7394d81df");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# Record time before running the code in series

folder = 'logs/'
if not os.path.isdir(folder):
        os.mkdir(folder)

LOG_DIR_1 = folder + time.strftime("%Y%m%d-%H%M%S", time.localtime())
print(LOG_DIR_1)

# Log the hparam config. This is optional but makes tensorboard show the right ranges.
with tf.summary.create_file_writer(LOG_DIR_1).as_default():
  hp.hparams_config(
    hparams=[
             hp.HParam('learning_rate', hp.RealInterval(1e-4, 1e-2)),
             hp.HParam('num_dense_units', hp.Discrete([100, 200, 500, 1000])),
             hp.HParam('num_dense_layers', hp.Discrete([4, 8, 12, 16])),
             hp.HParam('weight_decay', hp.RealInterval(5e-4,5e-2))],
    metrics=[hp.Metric("val_rmse", display_name='RMSE'),
             hp.Metric("original_rmse", display_name="OG RMSE"),
             hp.Metric("difference_rmse", display_name="diff RMSE"),
            ],
  )


RMSE_list = []
all_pred_bjd_val = []

rms_avg_list = []
weight_decay_list_t = []
gaussian_noise_list_t = []
rms_x_list = []

all_bjds_val = []
all_pred_val = []
all_labels_val = []
all_mean_val_preds = []
all_mean_val_bjds = []
all_mean_val_labels = []


ts = time.time()

for i in range(1):
      my_fc_nn_optimizer(learning_rate_list, dense_units_list, num_dense_layers_list, weight_decay_list, LOG_DIR_1, i)
        
print('Time in serial:', time.time() - ts)
# Out:
# logs/20211206-231840
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 1, Model archictect. num: 1, Run number: 1
# 1: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.937
# 10: Train loss: 3.294, Train RMSE: 1.815, Val RMSE: 1.937
# 20: Train loss: 3.292, Train RMSE: 1.814, Val RMSE: 1.937
# 30: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.937
# 40: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.937
# Raw scatter=1.944 m/s
# Corrected scatter=1.937 m/s
# Stellar Error Removed=0.167 m/s
# val_rmse: 1.9367962
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 2, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.294, Train RMSE: 1.815, Val RMSE: 1.936
# 10: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.936
# 20: Train loss: 3.291, Train RMSE: 1.814, Val RMSE: 1.936
# 30: Train loss: 3.289, Train RMSE: 1.814, Val RMSE: 1.936
# 40: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.936
# Raw scatter=1.944 m/s
# Corrected scatter=1.936 m/s
# Stellar Error Removed=0.175 m/s
# val_rmse: 1.9361453
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 3, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.933
# 10: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.933
# 20: Train loss: 3.291, Train RMSE: 1.814, Val RMSE: 1.933
# 30: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.934
# 40: Train loss: 3.285, Train RMSE: 1.812, Val RMSE: 1.934
# Raw scatter=1.944 m/s
# Corrected scatter=1.934 m/s
# Stellar Error Removed=0.199 m/s
# val_rmse: 1.933838
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 4, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.298, Train RMSE: 1.816, Val RMSE: 1.934
# 10: Train loss: 3.296, Train RMSE: 1.816, Val RMSE: 1.935
# 20: Train loss: 3.294, Train RMSE: 1.815, Val RMSE: 1.935
# 30: Train loss: 3.292, Train RMSE: 1.814, Val RMSE: 1.935
# 40: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.936
# Raw scatter=1.944 m/s
# Corrected scatter=1.936 m/s
# Stellar Error Removed=0.178 m/s
# val_rmse: 1.9358609
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 5, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.302, Train RMSE: 1.817, Val RMSE: 1.933
# 10: Train loss: 3.299, Train RMSE: 1.816, Val RMSE: 1.934
# 20: Train loss: 3.296, Train RMSE: 1.815, Val RMSE: 1.934
# 30: Train loss: 3.292, Train RMSE: 1.815, Val RMSE: 1.934
# 40: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.935
# Raw scatter=1.944 m/s
# Corrected scatter=1.935 m/s
# Stellar Error Removed=0.189 m/s
# val_rmse: 1.9347628
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 6, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.302, Train RMSE: 1.817, Val RMSE: 1.935
# 10: Train loss: 3.3, Train RMSE: 1.816, Val RMSE: 1.935
# 20: Train loss: 3.296, Train RMSE: 1.816, Val RMSE: 1.935
# 30: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.935
# 40: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.936
# Raw scatter=1.944 m/s
# Corrected scatter=1.936 m/s
# Stellar Error Removed=0.179 m/s
# val_rmse: 1.9357165
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 7, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.936
# 10: Train loss: 3.292, Train RMSE: 1.814, Val RMSE: 1.935
# 20: Train loss: 3.289, Train RMSE: 1.814, Val RMSE: 1.935
# 30: Train loss: 3.286, Train RMSE: 1.813, Val RMSE: 1.935
# 40: Train loss: 3.284, Train RMSE: 1.812, Val RMSE: 1.935
# Raw scatter=1.944 m/s
# Corrected scatter=1.935 m/s
# Stellar Error Removed=0.184 m/s
# val_rmse: 1.9352895
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 8, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.936
# 10: Train loss: 3.296, Train RMSE: 1.815, Val RMSE: 1.936
# 20: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.936
# 30: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.936
# 40: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.936
# Raw scatter=1.944 m/s
# Corrected scatter=1.936 m/s
# Stellar Error Removed=0.180 m/s
# val_rmse: 1.9356406
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 9, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.297, Train RMSE: 1.816, Val RMSE: 1.934
# 10: Train loss: 3.296, Train RMSE: 1.815, Val RMSE: 1.934
# 20: Train loss: 3.293, Train RMSE: 1.815, Val RMSE: 1.934
# 30: Train loss: 3.29, Train RMSE: 1.814, Val RMSE: 1.934
# 40: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.935
# Raw scatter=1.944 m/s
# Corrected scatter=1.935 m/s
# Stellar Error Removed=0.189 m/s
# val_rmse: 1.9347588
# ________________________
#
# Model 0. Learning_rate: 0.00010. Dense units: 1000. Dense layers 12. Weight decay: 0.00139
# Cross-val number: 10, Model archictect. num: 1, Run number: 1
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1: Train loss: 3.295, Train RMSE: 1.815, Val RMSE: 1.937
# 10: Train loss: 3.294, Train RMSE: 1.815, Val RMSE: 1.936
# 20: Train loss: 3.291, Train RMSE: 1.814, Val RMSE: 1.936
# 30: Train loss: 3.288, Train RMSE: 1.813, Val RMSE: 1.936
# 40: Train loss: 3.287, Train RMSE: 1.813, Val RMSE: 1.936
# Raw scatter=1.944 m/s
# Corrected scatter=1.936 m/s
# Stellar Error Removed=0.176 m/s
# val_rmse: 1.9360467
# ________________________
#
# Time in serial: 232.7624146938324
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/zdebeurs/opt/anaconda3/envs/tensorflow_env2/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
LOG_DIR_1
# Out:
# 'logs/20211206-225742'

# %%
# !ls $LOG_DIR_1
# Out:
# 0
# events.out.tfevents.1638850720.dhcp-10-29-86-57.dyn.mit.edu.79853.2415682.v2

# %%
# %tensorboard --logdir $LOG_DIR_1
# Out:
#       <iframe id="tensorboard-frame-b8cee31a47a21558" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b8cee31a47a21558");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
