# %%
import tensorflow as tf
#tf.enable_eager_execution()
import tensorflow_addons as tfa
print(tf.__version__)

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-196cfddf3ddf> in <module>
# ----> 1 import tensorflow as tf
#       2 #tf.enable_eager_execution()
#       3 import tensorflow_addons as tfa
#       4 print(tf.__version__)
#       5
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !ls "CCN_tensorlogs/20211208-154321/"
# Out:
# 1
# 10
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 11
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 12
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 13
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 14
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 15
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 16
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 17
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 18
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 19
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 2
# 20
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 21
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 22
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 23
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 24
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 25
# 250
# 26
# ...

# %%
# specify location of log files
LOG_DIR_1 = "CCN_tensorlogs/20211208-154321/"
#'supercloud_logs/20211208-122446'#'tensorlogs/20211207-164616'

# %%
# %tensorboard --logdir $LOG_DIR_1
# Out:
#       <iframe id="tensorboard-frame-f6dc6afb32d6ac0d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f6dc6afb32d6ac0d");
#           const url = new URL("/", window.location);
#           url.port = 6009;
#           frame.src = url;
#         })();
#       </script>
